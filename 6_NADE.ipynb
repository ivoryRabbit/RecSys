# %% [markdown]
# <a href="https://colab.research.google.com/github/ivoryRabbit/RecSys/blob/master/6_NADE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # NADE
#
# - [A Neural Autoregressive Approach to Collaborative Filtering](https://arxiv.org/pdf/1605.09477.pdf)
# - [Neural Autoregressive Collaborative Filtering for Implicit Feedback](https://arxiv.org/pdf/1606.07674.pdf)
#
# ## Experiment

# %%
import glob
import numpy as np
import pandas as pd
from typing import Callable, Tuple, List
from tqdm.notebook import tqdm

import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

from sklearn.model_selection import train_test_split

import tensorflow as tf
import tensorflow.keras.backend as K

from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2

from tensorflow.keras.utils import get_file
import zipfile

np.random.seed(777)
tf.random.set_seed(777)

# %%
def load_data(data_size : str) -> pd.DataFrame:
    ''' load Movie Lens data '''

    if data_size == '1m':
        fname = 'ml-1m.zip'
        data = 'ml-1m/ratings.dat'
    elif data_size == '10m':
        fname = 'ml-10m.zip'
        data = 'ml-10M100K/ratings.dat'
    elif data_size == '20m':
        fname = 'ml-20m.zip'
        data = 'ml-20m/ratings.csv'
    elif data_size == '25m':
        fname = 'ml-25m.zip'
        data = 'ml-25m/ratings.csv'
    if not glob.glob(data):
        origin = f'http://files.grouplens.org/datasets/movielens/{fname}'
        file = get_file(fname, origin)
        zip_ref = zipfile.ZipFile(file, 'r')
        zip_ref.extractall()

    col_names = ['user_id', 'movie_id', 'rating', 'timestamp']
    if data_size in ['20m', '25m']:
        ratings = pd.read_csv(data, engine = 'python')
    else:
        ratings = pd.read_csv(data, sep = '|', delimiter = '::', names = col_names, engine = 'python')
    print(ratings.shape)
    return ratings

# %%
ratings = load_data('1m')
ratings.head()
# Out:
# (1000209, 4)
#    user_id  movie_id  rating  timestamp
# 0        1      1193       5  978300760
# 1        1       661       3  978302109
# 2        1       914       3  978301968
# 3        1      3408       4  978300275
# 4        1      2355       5  978824291

# %%
user_list = ratings.user_id.unique()
user_idx_map = {e: i for i, e in enumerate(user_list)}
n_user = len(user_list)
print(f'# of user = {n_user}')

item_list = ratings.movie_id.unique()
item_idx_map = {e: i for i, e in enumerate(item_list)}
n_item = len(item_list)
print(f'# of item = {n_item}')
# Out:
# # of user = 6040
# # of item = 3706

# %%
ratings = ratings.sort_values(['user_id', 'timestamp'])
ratings = ratings.assign(
    user_id = ratings.user_id.map(user_idx_map),
    movie_id = ratings.movie_id.map(item_idx_map)
)
ratings.head()
# Out:
#    user_id  movie_id  rating  timestamp
# 0        0         0       5  978300760
# 1        0         1       3  978302109
# 2        0         2       3  978301968
# 3        0         3       4  978300275
# 4        0         4       5  978824291

# %%
def binarizer(df: pd.DataFrame, threshold = 4) -> pd.DataFrame:
    df = df.assign(rating = np.where(df.rating >= threshold, 1, 0))
    return df[df.rating > 0.0].reset_index(drop = True)

def make_warm(df: pd.DataFrame, threshold = 5) -> pd.DataFrame: # remove cold starters
    positive = df.groupby('user_id')['movie_id'].count()
    positive = positive.index[positive >= threshold]
    return df[df.user_id.isin(positive)].reset_index(drop = True)

def train_valid_test_split(df: pd.DataFrame, size: float) -> pd.DataFrame:
    train_user, test_user = train_test_split(df.user_id.unique(), test_size = 2 * size, random_state = 777)
    valid_user, test_user = train_test_split(test_user, test_size = 0.5, random_state = 777)
    train, valid, test = map(lambda x: df[df.user_id.isin(x)], (train_user, valid_user, test_user))
    train, valid, test = map(lambda df: df.reset_index(drop = True), (train, valid, test))
    return train, valid, test

def query_relev_split(df: pd.DataFrame, size: float) -> pd.DataFrame:
    timeorder = df.groupby('user_id')['timestamp'].rank(method = 'first', ascending = True)
    seen_cnts = df.groupby('user_id')['movie_id'].transform('count')
    df = df.assign(seen_cnts = seen_cnts, timeorder = timeorder)
    query = df[df.timeorder < df.seen_cnts * (1-size)]
    relev = df[df.timeorder >= df.seen_cnts * (1-size)]
    relev = relev[relev.user_id.isin(query.user_id.unique())]
    query, relev = map(lambda df: df.drop(columns = ['timeorder', 'seen_cnts']), (query, relev))
    query, relev = map(lambda df: df.reset_index(drop = True), (query, relev))
    return query, relev

def list_agg(df: pd.DataFrame) -> pd.DataFrame:
    return df.groupby('user_id', as_index = False)[['movie_id']].agg(list)

# %%
data = binarizer(ratings)
data = make_warm(data)
data.head()
# Out:
#    user_id  movie_id  rating  timestamp
# 0        0         0       1  978300760
# 1        0         3       1  978300275
# 2        0         4       1  978824291
# 3        0         6       1  978302039
# 4        0         7       1  978300719

# %%
train, valid, test = train_valid_test_split(data, size = 0.1)
valid_q, valid_r = query_relev_split(valid, size = 0.2)
test_q, test_r = query_relev_split(test, size = 0.2)

# %%
def train_generator(train: pd.DataFrame, 
                    n_item: int, 
                    batch_size: int) -> np.ndarray:

    train = list_agg(train)
    
    n_data = train.index.size
    ids = np.arange(n_data)
    profile = train['movie_id']

    n_batch = int(np.ceil(n_data / batch_size))
    while True:
        np.random.shuffle(ids)
        for batch_step in range(n_batch):     
            lower = batch_size * batch_step
            upper = batch_size + lower
            
            batch_id = ids[lower: upper]
            batch = np.zeros(shape = (batch_id.size, n_item), dtype = np.float32)
            for i, idx in enumerate(batch_id):
                batch[i, profile[idx]] = 1.0
            
            yield batch

# %%
def valid_generator(query: pd.DataFrame,
                    relev: pd.DataFrame,
                    n_item: int,
                    batch_size: int) -> Tuple[np.ndarray]:

    query = list_agg(query)
    relev = list_agg(relev)

    n_data = query.index.size
    ids = np.arange(n_data)
    profile_q = query['movie_id']
    profile_r = relev['movie_id']

    n_batch = int(np.ceil(n_data / batch_size))
    while True:
        np.random.shuffle(ids)
        for batch_step in range(n_batch):
            lower = batch_size * batch_step
            upper = batch_size + lower
            
            batch_id = ids[lower: upper]
            batch_q = np.zeros(shape = (batch_id.size, n_item), dtype = np.float32)
            batch_r = np.zeros(shape = (batch_id.size, n_item), dtype = np.float32)
            for i, idx in enumerate(batch_id):
                batch_q[i, profile_q[idx]] = 1.0 # seen
                batch_r[i, profile_r[idx]] = 1.0 # unseen

            yield batch_q, batch_r

# %%
def binary_cross_entropy(true: tf.Tensor, pred: tf.Tensor) -> tf.Tensor:
    ce = tf.math.reduce_sum(K.binary_crossentropy(true, pred), axis = 1)
    return tf.math.reduce_mean(ce, axis = 0)

def multinomial(true: tf.Tensor, pred: tf.Tensor) -> tf.Tensor:
    ll = tf.math.reduce_sum(true * K.log(pred), axis = 1)
    return -tf.math.reduce_mean(ll, axis = 0)

def batch_ndcg(query: tf.Tensor, 
               relev: tf.Tensor,
               pred: tf.Tensor, 
               weight: tf.Tensor,
               k = 100) -> tf.Tensor: # only for validation

    rec = tf.where(query == 1.0, -1.0, pred) # leave only unseen-data
    rec = tf.argsort(rec, axis = 1, direction = 'DESCENDING')[:, :k]
    shape = tf.shape(rec)

    row = tf.repeat(tf.range(shape[0]), shape[1])
    row = tf.expand_dims(row, axis = 1)
    col = tf.reshape(rec, shape = [-1])
    col = tf.expand_dims(col, axis = 1)
    loc = tf.concat([row, col], axis = 1)

    top_k = tf.reshape(tf.gather_nd(relev, loc), shape = shape)
    ideal = tf.sort(relev, axis = 1, direction = 'DESCENDING')[:, :k]
    weight = weight[:shape[1]]

    dcg = tf.reduce_sum(top_k * weight, axis = 1)
    idcg = tf.reduce_sum(ideal * weight, axis = 1)
    return tf.reduce_mean(dcg / idcg, axis = 0)

# %%
class Encoder(tf.keras.layers.Layer):
    def __init__(self, units):
        super(Encoder, self).__init__()
        self.units = units

    def build(self, input_shape):
        self.W = self.add_weight(
            shape = (input_shape[-1], self.units),
            initializer = 'glorot_uniform',
            regularizer = l2(1e-3),
            trainable = True,
            name = 'W'
        )
        # self.b = self.add_weight(
        #     shape = (1, self.units),
        #     initializer = 'zeros',
        #     trainable = True,
        #     name = 'b'
        # )
    def call(self, inputs):
        r = tf.einsum('nm,mh->nmh', inputs, self.W)
        logit_h = tf.math.cumsum(r, axis = 1, exclusive = True)# + self.b
        return tf.nn.sigmoid(logit_h)

# %%
class Decoder(tf.keras.layers.Layer):
    def __init__(self, units):
        super(Decoder, self).__init__()
        self.units = units

    def build(self, input_shape):
        self.V = self.add_weight(
            shape = (input_shape[-1], self.units),
            initializer = 'glorot_uniform',
            regularizer = l2(1e-3),
            trainable = True,
            name = 'V'
        )
        self.c = self.add_weight(
            shape = (1, self.units),
            initializer = 'zeros',
            trainable = True,
            name = 'c'
        )
    def call(self, inputs):
        logit_o = tf.einsum('nmh,hm->nm', inputs, self.V) + self.c
        return tf.nn.sigmoid(logit_o)

# %%
class NADE(tf.keras.models.Model):
    def __init__(self, input_dim, latent_dim):
        super(NADE, self).__init__()

        self.input_dim = input_dim
        self.latent_dim = latent_dim
        self.beta = 0.01

        self.encoder = Encoder(self.latent_dim)
        self.decoder = Decoder(self.input_dim)

        _ = self.call(Input(shape = (self.input_dim, )))
        self.build(input_shape = (None, self.input_dim))

    def call(self, inputs):
        h = self.encoder(inputs)
        return self.decoder(h)

    def train_step(self, inputs):
        with tf.GradientTape() as tape:
            outputs = self(inputs)
            loss = self.loss(inputs, outputs)
        gradients = tape.gradient(loss, self.trainable_variables)
        self.optimizer.apply_gradients(zip(gradients, self.trainable_variables))
        return {'loss': loss}

    def test_step(self, data):
        query, relev = data
        pred = self(query)

        weight = tf.range(2, self.input_dim, dtype = 'float32')
        weight = tf.math.reciprocal(tf.math.log(weight))
        ndcg = batch_ndcg(query, relev, pred, weight)
        return {'ndcg': ndcg}

# %%
def show_history(hist, loss: str, metric: str) -> None:
    fig, (ax1, ax2) = plt.subplots(2, 1, figsize = (8, 6))

    ax1.plot(hist.history[f'{loss}'])
    ax1.set_title(loss, fontsize = 20)
    ax1.set_ylabel(loss)
    ax1.set_xlabel('epoch')

    ax2.plot(hist.history[f'val_{metric}'])
    ax2.set_title(metric, fontsize = 20)
    ax2.set_ylabel(metric)
    ax2.set_xlabel('epoch')
    plt.tight_layout()

# %%
epochs = 100
batch_size = 128

train_gen = train_generator(train, n_item, batch_size)
valid_gen = valid_generator(valid_q, valid_r, n_item, batch_size)

steps_per_epoch = train.user_id.nunique() // batch_size + 1
validation_steps = valid.user_id.nunique() // batch_size + 1

# %% [markdown]
# ## 1. Bernoulli

# %%
model = NADE(n_item, 256)
model.compile(optimizer = Adam(lr = 1e-4), loss = binary_cross_entropy)

model.summary()
# Out:
# Model: "nade_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# encoder_4 (Encoder)          (None, 3706, 256)         948736
# _________________________________________________________________
# decoder_4 (Decoder)          (None, 3706)              952442
# =================================================================
# Total params: 1,901,178
# Trainable params: 1,901,178
# Non-trainable params: 0
# _________________________________________________________________

# %%
# %%time
early_stopping = EarlyStopping(monitor = 'val_ndcg', mode = 'max', verbose = 1, patience = epochs // 10)
model_checkpoint = ModelCheckpoint('NADE-CF.h5', monitor = 'val_ndcg', mode = 'max', save_best_only = True)

hist = model.fit(x = train_gen, validation_data = valid_gen, epochs = epochs,
                 steps_per_epoch = steps_per_epoch, validation_steps = validation_steps, 
                 verbose = 1, callbacks = [early_stopping, model_checkpoint])
show_history(hist, 'loss', 'ndcg')
# Out:
# Epoch 1/100
# 38/38 [==============================] - 4s 105ms/step - loss: 2179.7251 - val_ndcg: 0.0106
# Epoch 2/100
# 38/38 [==============================] - 4s 100ms/step - loss: 1463.2621 - val_ndcg: 0.0606
# Epoch 3/100
# 38/38 [==============================] - 4s 100ms/step - loss: 1002.7834 - val_ndcg: 0.1120
# Epoch 4/100
# 38/38 [==============================] - 4s 100ms/step - loss: 758.1731 - val_ndcg: 0.1312
# Epoch 5/100
# 38/38 [==============================] - 4s 101ms/step - loss: 631.4660 - val_ndcg: 0.1579
# Epoch 6/100
# 38/38 [==============================] - 4s 100ms/step - loss: 557.7472 - val_ndcg: 0.1732
# Epoch 7/100
# 38/38 [==============================] - 4s 100ms/step - loss: 512.9387 - val_ndcg: 0.1643
# Epoch 8/100
# 38/38 [==============================] - 4s 104ms/step - loss: 484.6541 - val_ndcg: 0.1329
# Epoch 9/100
# 38/38 [==============================] - 4s 99ms/step - loss: 465.6647 - val_ndcg: 0.1498
# Epoch 10/100
# 38/38 [==============================] - 4s 99ms/step - loss: 450.4045 - val_ndcg: 0.1296
# Epoch 11/100
# 38/38 [==============================] - 4s 98ms/step - loss: 438.1939 - val_ndcg: 0.1465
# Epoch 12/100
# 38/38 [==============================] - 4s 98ms/step - loss: 431.6799 - val_ndcg: 0.1374
# Epoch 13/100
# 38/38 [==============================] - 4s 98ms/step - loss: 425.2772 - val_ndcg: 0.1473
# Epoch 14/100
# 38/38 [==============================] - 4s 98ms/step - loss: 420.7956 - val_ndcg: 0.1532
# Epoch 15/100
# 38/38 [==============================] - 4s 98ms/step - loss: 416.1252 - val_ndcg: 0.1547
# Epoch 16/100
# 38/38 [==============================] - 4s 98ms/step - loss: 412.4987 - val_ndcg: 0.1478
# Epoch 00016: early stopping
# CPU times: user 25.9 s, sys: 14.1 s, total: 40 s
# Wall time: 1min 1s

# %%
def test_predictor(query: pd.DataFrame, 
                   model: Callable,
                   n_item: int, 
                   batch_size: int, 
                   N = 100) -> float:

    query = list_agg(query)

    n_data = query.index.size
    ids = np.arange(n_data)
    profile = query['movie_id']

    pred = []
    n_batch = int(np.ceil(n_data / batch_size))
    for batch_step in range(n_batch):
        lower = batch_size * batch_step
        upper = batch_size + lower

        batch_id = ids[lower: upper]
        batch = np.zeros(shape = (batch_id.size, n_item))
        for i, idx in enumerate(batch_id):
            batch[i, profile[idx]] = 1.0

        pred_batch = model.predict(batch, verbose = 0)
        
        rec = np.argsort(np.where(batch == 1.0, -1.0, pred_batch), axis = 1)[:, :-N-1:-1]
        pred.append(rec)
    pred = np.concatenate(pred)
    pred = [{'user_id': query.at[i, 'user_id'], 'movie_id': pred[i]} for i in range(n_data)]
    return pd.DataFrame(pred)

# %%
class evaluate:
    def __init__(self, true: pd.DataFrame, pred: pd.DataFrame):
        self.true = true
        self.pred = pred
        self.max_K = 10000
        self.idcg = np.cumsum([1.0 / np.log(i+2) for i in range(self.max_K)])

    def _recall(self, gt: List, rec: List, K = None) -> float:
        K = K if K else self.max_K
        res = [r for r in rec[:K] if r in gt]
        return len(res) / np.min([K, len(gt)])
    
    def _precision(self, gt: List, rec: List, K = None) -> float:
        K = K if K else self.max_K
        res = [r for r in rec[:K] if r in gt]
        return len(res) / len(rec[:K])

    def _AP(self, gt: List, rec: List, K = None) -> float: # Average Precision
        K = K if K else self.max_K
        res = 0.0
        for i, r in enumerate(rec[:K]):
            if r in gt:
                res += self._precision(gt, rec[:K], i+1)
        return res / np.min([K, len(gt)])

    def _RR(self, gt: List, rec: List, K = None) -> float: # Reciprocal Rank
        K = K if K else self.max_K
        for i, r in enumerate(rec[:K]):
            if r in gt:
                return  1.0 / (i+1)
        return 0

    def _nDCG(self, gt: List, rec: List, K = None) -> float: # normalized Discounted Cumulative Gain
        K = K if K else self.max_K
        dcg = 0.0
        for i, r in enumerate(rec[:K]):
            if r in gt:
                dcg += 1.0 / np.log(i+2)
        idcg = self.idcg[min([len(gt), K])-1]
        return dcg / idcg
    
    def __call__(self, K = None):
        self.K = K
        self.recall = 0
        self.precision = 0
        self.MAP = 0
        self.MRR = 0
        self.nDCG = 0
        n = self.true.index.size
        for gt, rec in zip(tqdm(self.true.movie_id), self.pred.movie_id):
            self.recall += self._recall(gt, rec, K) / n
            self.precision += self._precision(gt, rec, K) / n
            self.MAP += self._AP(gt, rec, K) / n
            self.MRR += self._RR(gt, rec, K) / n
            self.nDCG += self._nDCG(gt, rec, K) / n

    def print_all(self):
        K = '@' + str(self.K) if self.K else ''
        print(f'{"Recall":>12}{K} : {self.recall:.5f}',
              f'\n{"Precision":>12}{K} : {self.precision:.5f}',
              f'\n{"MAP":>12}{K} : {self.MAP:.5f}',
              f'\n{"MRR":>12}{K} : {self.MRR:.5f}',
              f'\n{"nDCG":>12}{K} : {self.nDCG:.5f}')

# %%
true = list_agg(test_r)
true.head(5)
# Out:
#    user_id                                           movie_id
# 0        2              [177, 179, 183, 84, 4, 198, 199, 207]
# 1        8  [59, 438, 93, 123, 463, 525, 30, 288, 534, 322...
# 2       41  [175, 182, 563, 184, 1176, 116, 128, 1037, 104...
# 3       78                             [1258, 305, 500, 2230]
# 4       91  [558, 1176, 195, 587, 592, 74, 1904, 186, 647,...

# %%
pred = test_predictor(test_q, model, n_item, batch_size, N = 100)
pred.head(5)
# Out:
#    user_id                                           movie_id
# 0        2  [217, 246, 209, 244, 669, 259, 273, 210, 48, 3...
# 1        8  [44, 124, 127, 97, 92, 5, 22, 134, 0, 184, 68,...
# 2       41  [104, 132, 128, 669, 167, 189, 38, 246, 92, 48...
# 3       78  [104, 5, 38, 23, 44, 0, 48, 22, 9, 51, 184, 4,...
# 4       91  [44, 48, 51, 124, 104, 64, 127, 23, 97, 39, 11...

# %%
scores = evaluate(true, pred)

scores(K = 20)
scores.print_all()

scores(K = 100)
scores.print_all()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=604.0), HTML(value='')))
#       Recall@20 : 0.10120
#    Precision@20 : 0.06606
#          MAP@20 : 0.03256
#          MRR@20 : 0.18759
#         nDCG@20 : 0.09040
# HBox(children=(FloatProgress(value=0.0, max=604.0), HTML(value='')))
#       Recall@100 : 0.26826
#    Precision@100 : 0.04387
#          MAP@100 : 0.03937
#          MRR@100 : 0.19534
#         nDCG@100 : 0.15364

# %% [markdown]
# ## 2. Multinomial

# %%
model = NADE(n_item, 256)
model.compile(optimizer = Adam(lr = 1e-4), loss = multinomial)

model.summary()
# Out:
# Model: "nade_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# encoder_1 (Encoder)          (None, 3706, 256)         948992
# _________________________________________________________________
# decoder_1 (Decoder)          (None, 3706)              952442
# =================================================================
# Total params: 1,901,434
# Trainable params: 1,901,434
# Non-trainable params: 0
# _________________________________________________________________

# %%
# %%time
early_stopping = EarlyStopping(monitor = 'val_ndcg', mode = 'max', verbose = 1, patience = epochs)
model_checkpoint = ModelCheckpoint('NADE-CF.h5', monitor = 'val_ndcg', mode = 'max', save_best_only = True)

hist = model.fit(x = train_gen, validation_data = valid_gen, epochs = epochs,
                 steps_per_epoch = steps_per_epoch, validation_steps = validation_steps, 
                 verbose = 1, callbacks = [early_stopping, model_checkpoint])
show_history(hist, 'loss', 'ndcg')
# Out:
# Epoch 1/100
# 38/38 [==============================] - 4s 107ms/step - loss: 56.5036 - val_ndcg: 0.0359
# Epoch 2/100
# 38/38 [==============================] - 4s 103ms/step - loss: 36.7079 - val_ndcg: 0.0356
# Epoch 3/100
# 38/38 [==============================] - 4s 103ms/step - loss: 22.8636 - val_ndcg: 0.0367
# Epoch 4/100
# 38/38 [==============================] - 4s 103ms/step - loss: 15.0324 - val_ndcg: 0.0438
# Epoch 5/100
# 38/38 [==============================] - 4s 106ms/step - loss: 10.4505 - val_ndcg: 0.0456
# Epoch 6/100
# 38/38 [==============================] - 4s 103ms/step - loss: 7.7520 - val_ndcg: 0.0498
# Epoch 7/100
# 38/38 [==============================] - 4s 103ms/step - loss: 6.0038 - val_ndcg: 0.0577
# Epoch 8/100
# 38/38 [==============================] - 4s 103ms/step - loss: 4.8252 - val_ndcg: 0.0477
# Epoch 9/100
# 38/38 [==============================] - 4s 103ms/step - loss: 3.9556 - val_ndcg: 0.0504
# Epoch 10/100
# 38/38 [==============================] - 4s 103ms/step - loss: 3.3091 - val_ndcg: 0.0547
# Epoch 11/100
# 38/38 [==============================] - 4s 104ms/step - loss: 2.8505 - val_ndcg: 0.0610
# Epoch 12/100
# 38/38 [==============================] - 4s 103ms/step - loss: 2.4339 - val_ndcg: 0.0644
# Epoch 13/100
# 38/38 [==============================] - 4s 103ms/step - loss: 2.1355 - val_ndcg: 0.0578
# Epoch 14/100
# 38/38 [==============================] - 4s 104ms/step - loss: 1.8905 - val_ndcg: 0.0468
# Epoch 15/100
# 38/38 [==============================] - 4s 103ms/step - loss: 1.6758 - val_ndcg: 0.0553
# Epoch 16/100
# 38/38 [==============================] - 4s 103ms/step - loss: 1.5074 - val_ndcg: 0.0506
# Epoch 17/100
# 38/38 [==============================] - 4s 103ms/step - loss: 1.3585 - val_ndcg: 0.0474
# Epoch 18/100
# 38/38 [==============================] - 4s 103ms/step - loss: 1.2339 - val_ndcg: 0.0587
# Epoch 19/100
# 38/38 [==============================] - 4s 103ms/step - loss: 1.1246 - val_ndcg: 0.0587
# Epoch 20/100
# 38/38 [==============================] - 4s 106ms/step - loss: 1.0377 - val_ndcg: 0.0457
# Epoch 21/100
# 38/38 [==============================] - 4s 103ms/step - loss: 0.9488 - val_ndcg: 0.0522
# Epoch 22/100
# 38/38 [==============================] - 4s 104ms/step - loss: 0.8742 - val_ndcg: 0.0533
# Epoch 23/100
# 38/38 [==============================] - 4s 103ms/step - loss: 0.8152 - val_ndcg: 0.0530
# Epoch 24/100
# 38/38 [==============================] - 4s 104ms/step - loss: 0.7566 - val_ndcg: 0.0473
# Epoch 25/100
# 38/38 [==============================] - 4s 104ms/step - loss: 0.7045 - val_ndcg: 0.0611
# Epoch 26/100
# 38/38 [==============================] - 4s 103ms/step - loss: 0.6560 - val_ndcg: 0.0536
# Epoch 27/100
# 38/38 [==============================] - 4s 103ms/step - loss: 0.6154 - val_ndcg: 0.0562
# Epoch 28/100
# 38/38 [==============================] - 4s 104ms/step - loss: 0.5797 - val_ndcg: 0.0525
# Epoch 29/100
# 38/38 [==============================] - 4s 103ms/step - loss: 0.5442 - val_ndcg: 0.0593
# Epoch 30/100
# 38/38 [==============================] - 4s 103ms/step - loss: 0.5119 - val_ndcg: 0.0579
# Epoch 31/100
# 38/38 [==============================] - 4s 103ms/step - loss: 0.4846 - val_ndcg: 0.0480
# Epoch 32/100
# 38/38 [==============================] - 4s 103ms/step - loss: 0.4558 - val_ndcg: 0.0595
# Epoch 33/100
# 38/38 [==============================] - 4s 103ms/step - loss: 0.4321 - val_ndcg: 0.0469
# Epoch 34/100
# 38/38 [==============================] - 4s 103ms/step - loss: 0.4098 - val_ndcg: 0.0624
# Epoch 35/100
# 38/38 [==============================] - 4s 106ms/step - loss: 0.3903 - val_ndcg: 0.0572
# Epoch 36/100
# 38/38 [==============================] - 4s 103ms/step - loss: 0.3706 - val_ndcg: 0.0601
# Epoch 37/100
# 38/38 [==============================] - 4s 103ms/step - loss: 0.3527 - val_ndcg: 0.0569
# Epoch 38/100
# 38/38 [==============================] - 4s 104ms/step - loss: 0.3350 - val_ndcg: 0.0569
# Epoch 39/100
# 38/38 [==============================] - 4s 103ms/step - loss: 0.3202 - val_ndcg: 0.0531
# Epoch 40/100
# 38/38 [==============================] - 4s 103ms/step - loss: 0.3060 - val_ndcg: 0.0549
# Epoch 41/100
# 38/38 [==============================] - 4s 103ms/step - loss: 0.2917 - val_ndcg: 0.0553
# Epoch 42/100
# 38/38 [==============================] - 4s 103ms/step - loss: 0.2794 - val_ndcg: 0.0576
# Epoch 43/100
# 38/38 [==============================] - 4s 103ms/step - loss: 0.2678 - val_ndcg: 0.0483
# Epoch 44/100
# 38/38 [==============================] - 4s 103ms/step - loss: 0.2565 - val_ndcg: 0.0620
# Epoch 45/100
# 38/38 [==============================] - 4s 103ms/step - loss: 0.2458 - val_ndcg: 0.0445
# Epoch 46/100
# 38/38 [==============================] - 4s 103ms/step - loss: 0.2358 - val_ndcg: 0.0457
# Epoch 47/100
# 38/38 [==============================] - 4s 103ms/step - loss: 0.2273 - val_ndcg: 0.0481
# Epoch 48/100
# 38/38 [==============================] - 4s 103ms/step - loss: 0.2181 - val_ndcg: 0.0486
# Epoch 49/100
# 38/38 [==============================] - 4s 103ms/step - loss: 0.2091 - val_ndcg: 0.0517
# Epoch 50/100
# 38/38 [==============================] - 4s 106ms/step - loss: 0.2011 - val_ndcg: 0.0598
# Epoch 51/100
# 38/38 [==============================] - 4s 103ms/step - loss: 0.1937 - val_ndcg: 0.0458
# Epoch 52/100
# 38/38 [==============================] - 4s 103ms/step - loss: 0.1873 - val_ndcg: 0.0511
# Epoch 53/100
# 38/38 [==============================] - 4s 103ms/step - loss: 0.1793 - val_ndcg: 0.0555
# Epoch 54/100
# 38/38 [==============================] - 4s 103ms/step - loss: 0.1742 - val_ndcg: 0.0411
# Epoch 55/100
# 38/38 [==============================] - 4s 103ms/step - loss: 0.1680 - val_ndcg: 0.0523
# Epoch 56/100
# 38/38 [==============================] - 4s 103ms/step - loss: 0.1615 - val_ndcg: 0.0501
# Epoch 57/100
# 38/38 [==============================] - 4s 103ms/step - loss: 0.1553 - val_ndcg: 0.0540
# Epoch 58/100
# 38/38 [==============================] - 4s 103ms/step - loss: 0.1512 - val_ndcg: 0.0419
# Epoch 59/100
# 38/38 [==============================] - 4s 103ms/step - loss: 0.1460 - val_ndcg: 0.0498
# Epoch 60/100
# 38/38 [==============================] - 4s 103ms/step - loss: 0.1410 - val_ndcg: 0.0545
# Epoch 61/100
# 38/38 [==============================] - 4s 103ms/step - loss: 0.1366 - val_ndcg: 0.0534
# Epoch 62/100
# 38/38 [==============================] - 4s 103ms/step - loss: 0.1318 - val_ndcg: 0.0552
# Epoch 63/100
# 38/38 [==============================] - 4s 103ms/step - loss: 0.1276 - val_ndcg: 0.0524
# Epoch 64/100
# 38/38 [==============================] - 4s 103ms/step - loss: 0.1237 - val_ndcg: 0.0540
# Epoch 65/100
# 38/38 [==============================] - 4s 106ms/step - loss: 0.1203 - val_ndcg: 0.0530
# Epoch 66/100
# 38/38 [==============================] - 4s 103ms/step - loss: 0.1161 - val_ndcg: 0.0627
# Epoch 67/100
# 38/38 [==============================] - 4s 104ms/step - loss: 0.1122 - val_ndcg: 0.0508
# Epoch 68/100
# 38/38 [==============================] - 4s 103ms/step - loss: 0.1094 - val_ndcg: 0.0510
# Epoch 69/100
# 38/38 [==============================] - 4s 103ms/step - loss: 0.1060 - val_ndcg: 0.0497
# Epoch 70/100
# 38/38 [==============================] - 4s 103ms/step - loss: 0.1026 - val_ndcg: 0.0481
# Epoch 71/100
# 38/38 [==============================] - 4s 103ms/step - loss: 0.0999 - val_ndcg: 0.0474
# Epoch 72/100
# 38/38 [==============================] - 4s 103ms/step - loss: 0.0968 - val_ndcg: 0.0564
# Epoch 73/100
# 38/38 [==============================] - 4s 103ms/step - loss: 0.0939 - val_ndcg: 0.0563
# Epoch 74/100
# 38/38 [==============================] - 4s 102ms/step - loss: 0.0915 - val_ndcg: 0.0548
# Epoch 75/100
# 38/38 [==============================] - 4s 103ms/step - loss: 0.0884 - val_ndcg: 0.0584
# Epoch 76/100
# 38/38 [==============================] - 4s 103ms/step - loss: 0.0860 - val_ndcg: 0.0487
# Epoch 77/100
# 38/38 [==============================] - 4s 103ms/step - loss: 0.0840 - val_ndcg: 0.0563
# Epoch 78/100
# 38/38 [==============================] - 4s 104ms/step - loss: 0.0815 - val_ndcg: 0.0522
# Epoch 79/100
# 38/38 [==============================] - 4s 103ms/step - loss: 0.0792 - val_ndcg: 0.0422
# Epoch 80/100
# 38/38 [==============================] - 4s 106ms/step - loss: 0.0770 - val_ndcg: 0.0554
# Epoch 81/100
# 38/38 [==============================] - 4s 103ms/step - loss: 0.0751 - val_ndcg: 0.0607
# Epoch 82/100
# 38/38 [==============================] - 4s 104ms/step - loss: 0.0727 - val_ndcg: 0.0465
# Epoch 83/100
# 38/38 [==============================] - 4s 104ms/step - loss: 0.0709 - val_ndcg: 0.0457
# Epoch 84/100
# 38/38 [==============================] - 4s 104ms/step - loss: 0.0691 - val_ndcg: 0.0437
# Epoch 85/100
# 38/38 [==============================] - 4s 103ms/step - loss: 0.0675 - val_ndcg: 0.0555
# Epoch 86/100
# 38/38 [==============================] - 4s 103ms/step - loss: 0.0655 - val_ndcg: 0.0686
# Epoch 87/100
# 38/38 [==============================] - 4s 104ms/step - loss: 0.0636 - val_ndcg: 0.0565
# Epoch 88/100
# 38/38 [==============================] - 4s 103ms/step - loss: 0.0620 - val_ndcg: 0.0608
# Epoch 89/100
# 38/38 [==============================] - 4s 103ms/step - loss: 0.0604 - val_ndcg: 0.0552
# Epoch 90/100
# 38/38 [==============================] - 4s 103ms/step - loss: 0.0590 - val_ndcg: 0.0444
# Epoch 91/100
# 38/38 [==============================] - 4s 103ms/step - loss: 0.0576 - val_ndcg: 0.0582
# Epoch 92/100
# 38/38 [==============================] - 4s 103ms/step - loss: 0.0559 - val_ndcg: 0.0522
# Epoch 93/100
# 38/38 [==============================] - 4s 103ms/step - loss: 0.0545 - val_ndcg: 0.0575
# Epoch 94/100
# 38/38 [==============================] - 4s 103ms/step - loss: 0.0533 - val_ndcg: 0.0475
# Epoch 95/100
# 38/38 [==============================] - 4s 106ms/step - loss: 0.0520 - val_ndcg: 0.0509
# Epoch 96/100
# 38/38 [==============================] - 4s 103ms/step - loss: 0.0506 - val_ndcg: 0.0491
# Epoch 97/100
# 38/38 [==============================] - 4s 103ms/step - loss: 0.0494 - val_ndcg: 0.0523
# Epoch 98/100
# 38/38 [==============================] - 4s 103ms/step - loss: 0.0482 - val_ndcg: 0.0516
# Epoch 99/100
# 38/38 [==============================] - 4s 103ms/step - loss: 0.0469 - val_ndcg: 0.0508
# Epoch 100/100
# 38/38 [==============================] - 4s 103ms/step - loss: 0.0459 - val_ndcg: 0.0537
# CPU times: user 2min 39s, sys: 1min 30s, total: 4min 9s
# Wall time: 6min 32s

# %%
def test_predictor(query: pd.DataFrame, 
                   model: Callable,
                   n_item: int, 
                   batch_size: int, 
                   N = 100) -> float:

    query = list_agg(query)

    n_data = query.index.size
    ids = np.arange(n_data)
    profile = query['movie_id']

    pred = []
    n_batch = int(np.ceil(n_data / batch_size))
    for batch_step in range(n_batch):
        lower = batch_size * batch_step
        upper = batch_size + lower

        batch_id = ids[lower: upper]
        batch = np.zeros(shape = (batch_id.size, n_item))
        for i, idx in enumerate(batch_id):
            batch[i, profile[idx]] = 1.0

        pred_batch = model.predict(batch, verbose = 0)
        
        rec = np.argsort(np.where(batch == 1.0, -1.0, pred_batch), axis = 1)[:, :-N-1:-1]
        pred.append(rec)
    pred = np.concatenate(pred)
    pred = [{'user_id': query.at[i, 'user_id'], 'movie_id': pred[i]} for i in range(n_data)]
    return pd.DataFrame(pred)

# %%
class evaluate:
    def __init__(self, true: pd.DataFrame, pred: pd.DataFrame):
        self.true = true
        self.pred = pred
        self.max_K = 10000
        self.idcg = np.cumsum([1.0 / np.log(i+2) for i in range(self.max_K)])

    def _recall(self, gt: List, rec: List, K = None) -> float:
        K = K if K else self.max_K
        res = [r for r in rec[:K] if r in gt]
        return len(res) / np.min([K, len(gt)])
    
    def _precision(self, gt: List, rec: List, K = None) -> float:
        K = K if K else self.max_K
        res = [r for r in rec[:K] if r in gt]
        return len(res) / len(rec[:K])

    def _AP(self, gt: List, rec: List, K = None) -> float: # Average Precision
        K = K if K else self.max_K
        res = 0.0
        for i, r in enumerate(rec[:K]):
            if r in gt:
                res += self._precision(gt, rec[:K], i+1)
        return res / np.min([K, len(gt)])

    def _RR(self, gt: List, rec: List, K = None) -> float: # Reciprocal Rank
        K = K if K else self.max_K
        for i, r in enumerate(rec[:K]):
            if r in gt:
                return  1.0 / (i+1)
        return 0

    def _nDCG(self, gt: List, rec: List, K = None) -> float: # normalized Discounted Cumulative Gain
        K = K if K else self.max_K
        dcg = 0.0
        for i, r in enumerate(rec[:K]):
            if r in gt:
                dcg += 1.0 / np.log(i+2)
        idcg = self.idcg[min([len(gt), K])-1]
        return dcg / idcg
    
    def __call__(self, K = None):
        self.K = K
        self.recall = 0
        self.precision = 0
        self.MAP = 0
        self.MRR = 0
        self.nDCG = 0
        n = self.true.index.size
        for gt, rec in zip(tqdm(self.true.movie_id), self.pred.movie_id):
            self.recall += self._recall(gt, rec, K) / n
            self.precision += self._precision(gt, rec, K) / n
            self.MAP += self._AP(gt, rec, K) / n
            self.MRR += self._RR(gt, rec, K) / n
            self.nDCG += self._nDCG(gt, rec, K) / n

    def print_all(self):
        K = '@' + str(self.K) if self.K else ''
        print(f'{"Recall":>12}{K} : {self.recall:.5f}',
              f'\n{"Precision":>12}{K} : {self.precision:.5f}',
              f'\n{"MAP":>12}{K} : {self.MAP:.5f}',
              f'\n{"MRR":>12}{K} : {self.MRR:.5f}',
              f'\n{"nDCG":>12}{K} : {self.nDCG:.5f}')

# %%
true = list_agg(test_r)
true.head(5)
# Out:
#    user_id                                           movie_id
# 0        2              [177, 179, 183, 84, 4, 198, 199, 207]
# 1        8  [59, 438, 93, 123, 463, 525, 30, 288, 534, 322...
# 2       41  [175, 182, 563, 184, 1176, 116, 128, 1037, 104...
# 3       78                             [1258, 305, 500, 2230]
# 4       91  [558, 1176, 195, 587, 592, 74, 1904, 186, 647,...

# %%
pred = test_predictor(test_q, model, n_item, batch_size, N = 100)
pred.head(5)
# Out:
#    user_id                                           movie_id
# 0        2  [237, 267, 283, 219, 294, 338, 541, 263, 244, ...
# 1        8  [960, 860, 873, 533, 585, 544, 651, 831, 669, ...
# 2       41  [960, 860, 873, 1244, 2036, 1691, 985, 1278, 9...
# 3       78  [0, 2, 4, 5, 9, 1, 3, 6, 22, 7, 26, 12, 13, 23...
# 4       91  [960, 860, 873, 541, 1244, 985, 533, 831, 908,...

# %%
scores = evaluate(true, pred)

scores(K = 20)
scores.print_all()

scores(K = 100)
scores.print_all()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=604.0), HTML(value='')))
#       Recall@20 : 0.02872
#    Precision@20 : 0.01623
#          MAP@20 : 0.00537
#          MRR@20 : 0.04689
#         nDCG@20 : 0.02138
# HBox(children=(FloatProgress(value=0.0, max=604.0), HTML(value='')))
#       Recall@100 : 0.11153
#    Precision@100 : 0.01709
#          MAP@100 : 0.00791
#          MRR@100 : 0.05658
#         nDCG@100 : 0.05287
