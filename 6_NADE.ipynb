# %% [markdown]
# <a href="https://colab.research.google.com/github/ivoryRabbit/RecSys/blob/master/6_NADE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # NADE
#
# - [A Neural Autoregressive Approach to Collaborative Filtering](https://arxiv.org/pdf/1605.09477.pdf)
# - [Neural Autoregressive Collaborative Filtering for Implicit Feedback](https://arxiv.org/pdf/1606.07674.pdf)
#
# ## Experiment

# %%
import glob
import numpy as np
import pandas as pd
from typing import Callable, Tuple, List
from tqdm.notebook import tqdm

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

from sklearn.model_selection import train_test_split

import tensorflow as tf
import tensorflow.keras.backend as K

from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.initializers import TruncatedNormal
from tensorflow.keras.regularizers import l2

from tensorflow.keras.utils import get_file
import zipfile

np.random.seed(777)
tf.random.set_seed(777)

# %%
def load_data(data_size : str) -> pd.DataFrame:
    ''' load Movie Lens data '''

    if data_size == '1m':
        fname = 'ml-1m.zip'
        data = 'ml-1m/ratings.dat'
    elif data_size == '10m':
        fname = 'ml-10m.zip'
        data = 'ml-10M100K/ratings.dat'
    elif data_size == '20m':
        fname = 'ml-20m.zip'
        data = 'ml-20m/ratings.csv'
    elif data_size == '25m':
        fname = 'ml-25m.zip'
        data = 'ml-25m/ratings.csv'
    if not glob.glob(data):
        origin = f'http://files.grouplens.org/datasets/movielens/{fname}'
        file = get_file(fname, origin)
        zip_ref = zipfile.ZipFile(file, 'r')
        zip_ref.extractall()

    col_names = ['user_id', 'movie_id', 'rating', 'timestamp']
    if data_size in ['20m', '25m']:
        ratings = pd.read_csv(data, engine = 'python')
    else:
        ratings = pd.read_csv(data, sep = '|', delimiter = '::', names = col_names, engine = 'python')
    print(ratings.shape)
    return ratings

# %%
ratings = load_data('1m')
ratings.head()
# Out:
# (1000209, 4)
#    user_id  movie_id  rating  timestamp
# 0        1      1193       5  978300760
# 1        1       661       3  978302109
# 2        1       914       3  978301968
# 3        1      3408       4  978300275
# 4        1      2355       5  978824291

# %%
user_list = ratings.user_id.unique()
user_idx_map = {e: i for i, e in enumerate(user_list)}
n_user = len(user_list)
print(f'# of user = {n_user}')

item_list = ratings.movie_id.unique()
item_idx_map = {e: i for i, e in enumerate(item_list)}
n_item = len(item_list)
print(f'# of item = {n_item}')
# Out:
# # of user = 6040
# # of item = 3706

# %%
ratings = ratings.assign(
    user_id = ratings.user_id.map(user_idx_map),
    movie_id = ratings.movie_id.map(item_idx_map)
)
ratings.head()
# Out:
#    user_id  movie_id  rating  timestamp
# 0        0         0       5  978300760
# 1        0         1       3  978302109
# 2        0         2       3  978301968
# 3        0         3       4  978300275
# 4        0         4       5  978824291

# %%
def binarizer(df: pd.DataFrame, threshold = 4) -> pd.DataFrame:
    df = df.assign(rating = np.where(df.rating >= threshold, 1, 0))
    return df[df.rating > 0.0].reset_index(drop = True)

def make_warm(df: pd.DataFrame, threshold = 5) -> pd.DataFrame: # remove cold starters
    positive = df.groupby('user_id')['movie_id'].count()
    positive = positive.index[positive >= threshold]
    return df[df.user_id.isin(positive)].reset_index(drop = True)

def train_valid_test_split(df: pd.DataFrame, size: float) -> pd.DataFrame:
    train_user, test_user = train_test_split(df.user_id.unique(), test_size = 2 * size, random_state = 777)
    valid_user, test_user = train_test_split(test_user, test_size = 0.5, random_state = 777)
    train, valid, test = map(lambda x: df[df.user_id.isin(x)], (train_user, valid_user, test_user))
    train, valid, test = map(lambda df: df.reset_index(drop = True), (train, valid, test))
    return train, valid, test

def query_relev_split(df: pd.DataFrame, size: float) -> pd.DataFrame:
    timeorder = df.groupby('user_id')['timestamp'].rank(method = 'first', ascending = True)
    seen_cnts = df.groupby('user_id')['movie_id'].transform('count')
    df = df.assign(seen_cnts = seen_cnts, timeorder = timeorder)
    query = df[df.timeorder < df.seen_cnts * (1-size)]
    relev = df[df.timeorder >= df.seen_cnts * (1-size)]
    relev = relev[relev.user_id.isin(query.user_id.unique())]
    query, relev = map(lambda df: df.drop(columns = ['timeorder', 'seen_cnts']), (query, relev))
    query, relev = map(lambda df: df.reset_index(drop = True), (query, relev))
    return query, relev

def list_agg(df: pd.DataFrame) -> pd.DataFrame:
    return df.groupby('user_id', as_index = False)[['movie_id']].agg(list)

# %%
data = binarizer(ratings)
data = make_warm(data)
data.head()
# Out:
#    user_id  movie_id  rating  timestamp
# 0        0         0       1  978300760
# 1        0         3       1  978300275
# 2        0         4       1  978824291
# 3        0         6       1  978302039
# 4        0         7       1  978300719

# %%
train, valid, test = train_valid_test_split(data, size = 0.1)
valid_q, valid_r = query_relev_split(valid, size = 0.2)
test_q, test_r = query_relev_split(test, size = 0.2)

# %%
def train_generator(train: pd.DataFrame, 
                    n_item: int, 
                    batch_size: int) -> np.ndarray:

    train = list_agg(train)
    
    n_data = train.index.size
    ids = np.arange(n_data)
    profile = train['movie_id']

    n_batch = int(np.ceil(n_data / batch_size))
    while True:
        np.random.shuffle(ids)
        for batch_step in range(n_batch):     
            lower = batch_size * batch_step
            upper = batch_size + lower
            
            batch_id = ids[lower: upper]
            batch = np.zeros(shape = (batch_id.size, n_item), dtype = np.float32)
            for i, idx in enumerate(batch_id):
                batch[i, profile[idx]] = 1.0
            
            yield batch

# %%
def valid_generator(query: pd.DataFrame,
                    relev: pd.DataFrame,
                    n_item: int,
                    batch_size: int) -> Tuple[np.ndarray]:

    query = list_agg(query)
    relev = list_agg(relev)

    n_data = query.index.size
    ids = np.arange(n_data)
    profile_q = query['movie_id']
    profile_r = relev['movie_id']

    n_batch = int(np.ceil(n_data / batch_size))
    while True:
        np.random.shuffle(ids)
        for batch_step in range(n_batch):
            lower = batch_size * batch_step
            upper = batch_size + lower
            
            batch_id = ids[lower: upper]
            batch_q = np.zeros(shape = (batch_id.size, n_item), dtype = np.float32)
            batch_r = np.zeros(shape = (batch_id.size, n_item), dtype = np.float32)
            for i, idx in enumerate(batch_id):
                batch_q[i, profile_q[idx]] = 1.0 # seen
                batch_r[i, profile_r[idx]] = 1.0 # unseen

            yield batch_q, batch_r

# %%
def binary_cross_entropy(true: tf.Tensor, pred: tf.Tensor) -> tf.Tensor:
    ce = tf.math.reduce_sum(K.binary_crossentropy(true, pred), axis = 1)
    return tf.math.reduce_mean(ce, axis = 0)

def multinomial(true: tf.Tensor, pred: tf.Tensor) -> tf.Tensor:
    ll = tf.math.reduce_sum(true * K.log(pred), axis = 1)
    return -tf.math.reduce_mean(ll, axis = 0)

def batch_ndcg(query: tf.Tensor, 
               relev: tf.Tensor,
               pred: tf.Tensor, 
               weight: tf.Tensor,
               k = 100) -> tf.Tensor: # only for validation

    rec = tf.where(query == 1.0, -1.0, pred) # leave only unseen-data
    rec = tf.argsort(rec, axis = 1, direction = 'DESCENDING')[:, :k]
    shape = tf.shape(rec)

    row = tf.repeat(tf.range(shape[0]), shape[1])
    row = tf.expand_dims(row, axis = 1)
    col = tf.reshape(rec, shape = [-1])
    col = tf.expand_dims(col, axis = 1)
    loc = tf.concat([row, col], axis = 1)

    top_k = tf.reshape(tf.gather_nd(relev, loc), shape = shape)
    ideal = tf.sort(relev, axis = 1, direction = 'DESCENDING')[:, :k]
    weight = weight[:shape[1]]

    dcg = tf.reduce_sum(top_k * weight, axis = 1)
    idcg = tf.reduce_sum(ideal * weight, axis = 1)
    return tf.reduce_mean(dcg / idcg, axis = 0)

# %%
class Encoder(tf.keras.layers.Layer):
    def __init__(self, units):
        super(Encoder, self).__init__()
        self.units = units

    def build(self, input_shape):
        self.W = self.add_weight(
            shape = (input_shape[-1], self.units),
            initializer = 'glorot_uniform',
            regularizer = 'l2',
            trainable = True,
            name = 'W'
        )
        self.b = self.add_weight(
            shape = (1, self.units),
            initializer = 'zeros',
            trainable = True,
            name = 'b'
        )
    def call(self, inputs):
        r = tf.einsum('nm,mh->nmh', inputs, self.W)
        logit_h = tf.math.cumsum(r, axis = 1, exclusive = True) + self.b
        return tf.nn.sigmoid(logit_h)

# %%
class Decoder(tf.keras.layers.Layer):
    def __init__(self, units):
        super(Decoder, self).__init__()
        self.units = units

    def build(self, input_shape):
        self.V = self.add_weight(
            shape = (input_shape[-1], self.units),
            initializer = 'glorot_uniform',
            regularizer = 'l2',
            trainable = True,
            name = 'V'
        )
        self.c = self.add_weight(
            shape = (1, self.units),
            initializer = 'zeros',
            trainable = True,
            name = 'c'
        )
    def call(self, inputs):
        logit_o = tf.einsum('nmh,hm->nm', inputs, self.V) + self.c
        return tf.nn.sigmoid(logit_o)

# %%
class NADE(tf.keras.models.Model):
    def __init__(self, input_dim, latent_dim):
        super(NADE, self).__init__()

        self.input_dim = input_dim
        self.latent_dim = latent_dim
        self.beta = 0.01

        self.encoder = Encoder(self.latent_dim)
        self.decoder = Decoder(self.input_dim)

        _ = self.call(Input(shape = (self.input_dim, )))
        self.build(input_shape = (None, self.input_dim))

    def call(self, inputs):
        h = self.encoder(inputs)
        return self.decoder(h)

    def train_step(self, inputs):
        with tf.GradientTape() as tape:
            outputs = self(inputs)
            loss_ce = self.loss(inputs, outputs)
            reg = tf.nn.l2_loss(self.encoder.W) + tf.nn.l2_loss(self.decoder.V)
            loss = loss_ce + self.beta * reg
        gradients = tape.gradient(loss, self.trainable_variables)
        self.optimizer.apply_gradients(zip(gradients, self.trainable_variables))
        return {'loss': loss}

    def test_step(self, data):
        query, relev = data
        pred = self(query)

        weight = tf.range(2, self.input_dim, dtype = 'float32')
        weight = tf.math.reciprocal(tf.math.log(weight))
        ndcg = batch_ndcg(query, relev, pred, weight)
        return {'ndcg': ndcg}

# %%
def show_history(hist, loss: str, metric: str) -> None:
    fig, (ax1, ax2) = plt.subplots(2, 1, figsize = (8, 6))

    ax1.plot(hist.history[f'{loss}'])
    ax1.set_title(loss, fontsize = 20)
    ax1.set_ylabel(loss)
    ax1.set_xlabel('epoch')

    ax2.plot(hist.history[f'val_{metric}'])
    ax2.set_title(metric, fontsize = 20)
    ax2.set_ylabel(metric)
    ax2.set_xlabel('epoch')
    plt.tight_layout()

# %%
epochs = 100
batch_size = 128

train_gen = train_generator(train, n_item, batch_size)
valid_gen = valid_generator(valid_q, valid_r, n_item, batch_size)

steps_per_epoch = train.user_id.nunique() // batch_size + 1
validation_steps = valid.user_id.nunique() // batch_size + 1

# %%
model = NADE(n_item, 500)
model.compile(optimizer = Adam(lr = 1e-4), loss = binary_cross_entropy)

model.summary()
# Out:
# Model: "nade"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# encoder (Encoder)            (None, 3706, 500)         1853500
# _________________________________________________________________
# decoder (Decoder)            (None, 3706)              1856706
# =================================================================
# Total params: 3,710,206
# Trainable params: 3,710,206
# Non-trainable params: 0
# _________________________________________________________________

# %%
# %%time
early_stopping = EarlyStopping(monitor = 'val_ndcg', mode = 'max', verbose = 1, patience = epochs)
model_checkpoint = ModelCheckpoint('NADE-CF.h5', monitor = 'val_ndcg', mode = 'max', save_best_only = True)

hist = model.fit(x = train_gen, validation_data = valid_gen, epochs = epochs,
                 steps_per_epoch = steps_per_epoch, validation_steps = validation_steps, 
                 verbose = 1, callbacks = [early_stopping, model_checkpoint])
show_history(hist, 'loss', 'ndcg')
# Out:
# Epoch 1/100
# 38/38 [==============================] - 9s 219ms/step - loss: 1886.2106 - val_ndcg: 0.0257
# Epoch 2/100
# 38/38 [==============================] - 8s 212ms/step - loss: 965.3996 - val_ndcg: 0.1220
# Epoch 3/100
# 38/38 [==============================] - 8s 214ms/step - loss: 636.0759 - val_ndcg: 0.1458
# Epoch 4/100
# 38/38 [==============================] - 8s 218ms/step - loss: 523.7502 - val_ndcg: 0.1480
# Epoch 5/100
# 38/38 [==============================] - 8s 217ms/step - loss: 476.9942 - val_ndcg: 0.1511
# Epoch 6/100
# 38/38 [==============================] - 8s 215ms/step - loss: 451.6238 - val_ndcg: 0.1535
# Epoch 7/100
# 38/38 [==============================] - 8s 213ms/step - loss: 440.1054 - val_ndcg: 0.1406
# Epoch 8/100
# 38/38 [==============================] - 8s 211ms/step - loss: 429.0518 - val_ndcg: 0.1661
# Epoch 9/100
# 38/38 [==============================] - 8s 211ms/step - loss: 422.0535 - val_ndcg: 0.1514
# Epoch 10/100
# 38/38 [==============================] - 8s 211ms/step - loss: 417.9547 - val_ndcg: 0.1528
# Epoch 11/100
# 38/38 [==============================] - 8s 211ms/step - loss: 416.2405 - val_ndcg: 0.1568
# Epoch 12/100
# 38/38 [==============================] - 8s 214ms/step - loss: 410.4477 - val_ndcg: 0.1608
# Epoch 13/100
# 38/38 [==============================] - 8s 214ms/step - loss: 407.8131 - val_ndcg: 0.1373
# Epoch 14/100
# 38/38 [==============================] - 8s 214ms/step - loss: 406.3627 - val_ndcg: 0.1392
# Epoch 15/100
# 38/38 [==============================] - 8s 214ms/step - loss: 403.7801 - val_ndcg: 0.1464
# Epoch 16/100
# 38/38 [==============================] - 8s 214ms/step - loss: 398.7933 - val_ndcg: 0.1515
# Epoch 17/100
# 38/38 [==============================] - 8s 214ms/step - loss: 393.3059 - val_ndcg: 0.1351
# Epoch 18/100
# 38/38 [==============================] - 8s 212ms/step - loss: 388.8537 - val_ndcg: 0.1542
# Epoch 19/100
# 38/38 [==============================] - 8s 212ms/step - loss: 381.7520 - val_ndcg: 0.1479
# Epoch 20/100
# 38/38 [==============================] - 8s 212ms/step - loss: 375.0664 - val_ndcg: 0.1265
# Epoch 21/100
# 38/38 [==============================] - 8s 213ms/step - loss: 368.8010 - val_ndcg: 0.1251
# Epoch 22/100
# 38/38 [==============================] - 8s 214ms/step - loss: 362.2147 - val_ndcg: 0.1732
# Epoch 23/100
# 38/38 [==============================] - 8s 214ms/step - loss: 356.8500 - val_ndcg: 0.1393
# Epoch 24/100
# 38/38 [==============================] - 8s 214ms/step - loss: 351.7726 - val_ndcg: 0.1506
# Epoch 25/100
# 38/38 [==============================] - 8s 214ms/step - loss: 345.6755 - val_ndcg: 0.1481
# Epoch 26/100
# 38/38 [==============================] - 8s 214ms/step - loss: 341.8725 - val_ndcg: 0.1495
# Epoch 27/100
# 38/38 [==============================] - 8s 214ms/step - loss: 337.8378 - val_ndcg: 0.1399
# Epoch 28/100
# 38/38 [==============================] - 8s 214ms/step - loss: 335.7934 - val_ndcg: 0.1605
# Epoch 29/100
# 38/38 [==============================] - 8s 214ms/step - loss: 331.9410 - val_ndcg: 0.1416
# Epoch 30/100
# 38/38 [==============================] - 8s 214ms/step - loss: 330.3105 - val_ndcg: 0.1622
# Epoch 31/100
# 38/38 [==============================] - 8s 214ms/step - loss: 329.2804 - val_ndcg: 0.1596
# Epoch 32/100
# 38/38 [==============================] - 8s 214ms/step - loss: 326.9841 - val_ndcg: 0.1434
# Epoch 33/100
# 38/38 [==============================] - 8s 214ms/step - loss: 324.1361 - val_ndcg: 0.1286
# Epoch 34/100
# 38/38 [==============================] - 8s 214ms/step - loss: 322.8475 - val_ndcg: 0.1540
# Epoch 35/100
# 38/38 [==============================] - 8s 214ms/step - loss: 321.1701 - val_ndcg: 0.1433
# Epoch 36/100
# 38/38 [==============================] - 8s 214ms/step - loss: 321.1239 - val_ndcg: 0.1468
# Epoch 37/100
# 38/38 [==============================] - 8s 213ms/step - loss: 319.5277 - val_ndcg: 0.1492
# Epoch 38/100
# 38/38 [==============================] - 8s 213ms/step - loss: 318.6361 - val_ndcg: 0.1607
# Epoch 39/100
# 38/38 [==============================] - 8s 214ms/step - loss: 317.9335 - val_ndcg: 0.1503
# Epoch 40/100
# 38/38 [==============================] - 8s 213ms/step - loss: 316.2935 - val_ndcg: 0.1374
# Epoch 41/100
# 38/38 [==============================] - 8s 213ms/step - loss: 316.7520 - val_ndcg: 0.1474
# Epoch 42/100
# 38/38 [==============================] - 8s 213ms/step - loss: 315.7707 - val_ndcg: 0.1473
# Epoch 43/100
# 38/38 [==============================] - 8s 214ms/step - loss: 314.7441 - val_ndcg: 0.1576
# Epoch 44/100
# 38/38 [==============================] - 8s 214ms/step - loss: 313.7665 - val_ndcg: 0.1339
# Epoch 45/100
# 38/38 [==============================] - 8s 214ms/step - loss: 313.3813 - val_ndcg: 0.1612
# Epoch 46/100
# 38/38 [==============================] - 8s 214ms/step - loss: 313.6266 - val_ndcg: 0.1536
# Epoch 47/100
# 38/38 [==============================] - 8s 214ms/step - loss: 313.4491 - val_ndcg: 0.1522
# Epoch 48/100
# 38/38 [==============================] - 8s 214ms/step - loss: 311.2611 - val_ndcg: 0.1529
# Epoch 49/100
# 38/38 [==============================] - 8s 214ms/step - loss: 309.9377 - val_ndcg: 0.1513
# Epoch 50/100
# 38/38 [==============================] - 8s 214ms/step - loss: 309.7609 - val_ndcg: 0.1493
# Epoch 51/100
# 38/38 [==============================] - 8s 214ms/step - loss: 308.3889 - val_ndcg: 0.1488
# Epoch 52/100
# 38/38 [==============================] - 8s 214ms/step - loss: 307.8170 - val_ndcg: 0.1503
# Epoch 53/100
# 38/38 [==============================] - 8s 214ms/step - loss: 306.3274 - val_ndcg: 0.1378
# Epoch 54/100
# 38/38 [==============================] - 8s 214ms/step - loss: 306.7628 - val_ndcg: 0.1644
# Epoch 55/100
# 38/38 [==============================] - 8s 214ms/step - loss: 304.9718 - val_ndcg: 0.1560
# Epoch 56/100
# 38/38 [==============================] - 8s 214ms/step - loss: 305.9005 - val_ndcg: 0.1568
# Epoch 57/100
# 38/38 [==============================] - 8s 214ms/step - loss: 303.9807 - val_ndcg: 0.1525
# Epoch 58/100
# 38/38 [==============================] - 8s 214ms/step - loss: 304.1371 - val_ndcg: 0.1527
# Epoch 59/100
# 38/38 [==============================] - 8s 214ms/step - loss: 304.7418 - val_ndcg: 0.1650
# Epoch 60/100
# 38/38 [==============================] - 8s 214ms/step - loss: 301.4875 - val_ndcg: 0.1598
# Epoch 61/100
# 38/38 [==============================] - 8s 214ms/step - loss: 302.2264 - val_ndcg: 0.1444
# Epoch 62/100
# 38/38 [==============================] - 8s 217ms/step - loss: 301.0577 - val_ndcg: 0.1451
# Epoch 63/100
# 38/38 [==============================] - 8s 214ms/step - loss: 301.8427 - val_ndcg: 0.1571
# Epoch 64/100
# 38/38 [==============================] - 8s 214ms/step - loss: 300.5188 - val_ndcg: 0.1417
# Epoch 65/100
# 38/38 [==============================] - 8s 214ms/step - loss: 299.8778 - val_ndcg: 0.1657
# Epoch 66/100
# 38/38 [==============================] - 8s 214ms/step - loss: 297.6018 - val_ndcg: 0.1453
# Epoch 67/100
# 38/38 [==============================] - 8s 214ms/step - loss: 296.8420 - val_ndcg: 0.1621
# Epoch 68/100
# 38/38 [==============================] - 8s 214ms/step - loss: 298.1688 - val_ndcg: 0.1568
# Epoch 69/100
# 38/38 [==============================] - 8s 214ms/step - loss: 296.6368 - val_ndcg: 0.1538
# Epoch 70/100
# 38/38 [==============================] - 8s 214ms/step - loss: 296.0743 - val_ndcg: 0.1640
# Epoch 71/100
# 38/38 [==============================] - 8s 214ms/step - loss: 295.7242 - val_ndcg: 0.1681
# Epoch 72/100
# 38/38 [==============================] - 8s 214ms/step - loss: 295.0518 - val_ndcg: 0.1712
# Epoch 73/100
# 38/38 [==============================] - 8s 214ms/step - loss: 295.7713 - val_ndcg: 0.1709
# Epoch 74/100
# 38/38 [==============================] - 8s 214ms/step - loss: 293.3728 - val_ndcg: 0.1619
# Epoch 75/100
# 38/38 [==============================] - 8s 214ms/step - loss: 291.5686 - val_ndcg: 0.1766
# Epoch 76/100
# 38/38 [==============================] - 8s 214ms/step - loss: 293.1161 - val_ndcg: 0.1496
# Epoch 77/100
# 38/38 [==============================] - 8s 214ms/step - loss: 291.4971 - val_ndcg: 0.1565
# Epoch 78/100
# 38/38 [==============================] - 8s 214ms/step - loss: 291.4216 - val_ndcg: 0.1663
# Epoch 79/100
# 38/38 [==============================] - 8s 214ms/step - loss: 290.4142 - val_ndcg: 0.1736
# Epoch 80/100
# 38/38 [==============================] - 8s 214ms/step - loss: 289.7142 - val_ndcg: 0.1427
# Epoch 81/100
# 38/38 [==============================] - 8s 217ms/step - loss: 289.8126 - val_ndcg: 0.1592
# Epoch 82/100
# 38/38 [==============================] - 8s 214ms/step - loss: 288.7480 - val_ndcg: 0.1791
# Epoch 83/100
# 38/38 [==============================] - 8s 214ms/step - loss: 289.4197 - val_ndcg: 0.1729
# Epoch 84/100
# 38/38 [==============================] - 8s 214ms/step - loss: 287.6289 - val_ndcg: 0.1625
# Epoch 85/100
# 38/38 [==============================] - 8s 214ms/step - loss: 288.3029 - val_ndcg: 0.1627
# Epoch 86/100
# 38/38 [==============================] - 8s 214ms/step - loss: 288.6566 - val_ndcg: 0.1835
# Epoch 87/100
# 38/38 [==============================] - 8s 214ms/step - loss: 285.4849 - val_ndcg: 0.1826
# Epoch 88/100
# 38/38 [==============================] - 8s 214ms/step - loss: 285.5426 - val_ndcg: 0.1682
# Epoch 89/100
# 38/38 [==============================] - 8s 214ms/step - loss: 285.3992 - val_ndcg: 0.1754
# Epoch 90/100
# 38/38 [==============================] - 8s 214ms/step - loss: 285.3263 - val_ndcg: 0.1602
# Epoch 91/100
# 38/38 [==============================] - 8s 214ms/step - loss: 283.4338 - val_ndcg: 0.1851
# Epoch 92/100
# 38/38 [==============================] - 8s 214ms/step - loss: 285.7765 - val_ndcg: 0.1725
# Epoch 93/100
# 38/38 [==============================] - 8s 214ms/step - loss: 283.6757 - val_ndcg: 0.1646
# Epoch 94/100
# 38/38 [==============================] - 8s 214ms/step - loss: 283.8449 - val_ndcg: 0.1740
# Epoch 95/100
# 38/38 [==============================] - 8s 214ms/step - loss: 283.0116 - val_ndcg: 0.1788
# Epoch 96/100
# 38/38 [==============================] - 8s 214ms/step - loss: 283.4675 - val_ndcg: 0.1763
# Epoch 97/100
# 38/38 [==============================] - 8s 214ms/step - loss: 281.3275 - val_ndcg: 0.1470
# Epoch 98/100
# 38/38 [==============================] - 8s 214ms/step - loss: 281.1535 - val_ndcg: 0.1489
# Epoch 99/100
# 38/38 [==============================] - 8s 217ms/step - loss: 281.5920 - val_ndcg: 0.1691
# Epoch 100/100
# 38/38 [==============================] - 8s 214ms/step - loss: 280.2338 - val_ndcg: 0.1908
# CPU times: user 4min 53s, sys: 3min 12s, total: 8min 6s
# Wall time: 13min 32s

# %%
def test_predictor(query: pd.DataFrame, 
                   model: Callable,
                   n_item: int, 
                   batch_size: int, 
                   N = 100) -> float:

    query = list_agg(query)

    n_data = query.index.size
    ids = np.arange(n_data)
    profile = query['movie_id']

    pred = []
    n_batch = int(np.ceil(n_data / batch_size))
    for batch_step in range(n_batch):
        lower = batch_size * batch_step
        upper = batch_size + lower

        batch_id = ids[lower: upper]
        batch = np.zeros(shape = (batch_id.size, n_item))
        for i, idx in enumerate(batch_id):
            batch[i, profile[idx]] = 1.0

        pred_batch = model.predict(batch, verbose = 0)
        
        rec = np.argsort(np.where(batch == 1.0, -1.0, pred_batch), axis = 1)[:, :-N-1:-1]
        pred.append(rec)
    pred = np.concatenate(pred)
    pred = [{'user_id': query.at[i, 'user_id'], 'movie_id': pred[i]} for i in range(n_data)]
    return pd.DataFrame(pred)

# %%
class evaluate:
    def __init__(self, true: pd.DataFrame, pred: pd.DataFrame):
        self.true = true
        self.pred = pred
        self.max_K = 10000
        self.idcg = np.cumsum([1.0 / np.log(i+2) for i in range(self.max_K)])

    def _recall(self, gt: List, rec: List, K = None) -> float:
        K = K if K else self.max_K
        res = [r for r in rec[:K] if r in gt]
        return len(res) / np.min([K, len(gt)])
    
    def _precision(self, gt: List, rec: List, K = None) -> float:
        K = K if K else self.max_K
        res = [r for r in rec[:K] if r in gt]
        return len(res) / len(rec[:K])

    def _AP(self, gt: List, rec: List, K = None) -> float: # Average Precision
        K = K if K else self.max_K
        res = 0.0
        for i, r in enumerate(rec[:K]):
            if r in gt:
                res += self._precision(gt, rec[:K], i+1)
        return res / np.min([K, len(gt)])

    def _RR(self, gt: List, rec: List, K = None) -> float: # Reciprocal Rank
        K = K if K else self.max_K
        for i, r in enumerate(rec[:K]):
            if r in gt:
                return  1.0 / (i+1)
        return 0

    def _nDCG(self, gt: List, rec: List, K = None) -> float: # normalized Discounted Cumulative Gain
        K = K if K else self.max_K
        dcg = 0.0
        for i, r in enumerate(rec[:K]):
            if r in gt:
                dcg += 1.0 / np.log(i+2)
        idcg = self.idcg[min([len(gt), K])-1]
        return dcg / idcg
    
    def __call__(self, K = None):
        self.K = K
        self.recall = 0
        self.precision = 0
        self.MAP = 0
        self.MRR = 0
        self.nDCG = 0
        n = self.true.index.size
        for gt, rec in zip(tqdm(self.true.movie_id), self.pred.movie_id):
            self.recall += self._recall(gt, rec, K) / n
            self.precision += self._precision(gt, rec, K) / n
            self.MAP += self._AP(gt, rec, K) / n
            self.MRR += self._RR(gt, rec, K) / n
            self.nDCG += self._nDCG(gt, rec, K) / n

    def print_all(self):
        K = '@' + str(self.K) if self.K else ''
        print(f'{"Recall":>12}{K} : {self.recall:.5f}',
              f'\n{"Precision":>12}{K} : {self.precision:.5f}',
              f'\n{"MAP":>12}{K} : {self.MAP:.5f}',
              f'\n{"MRR":>12}{K} : {self.MRR:.5f}',
              f'\n{"nDCG":>12}{K} : {self.nDCG:.5f}')

# %%
true = list_agg(test_r)
true.head(5)
# Out:
#    user_id                                           movie_id
# 0        2              [177, 179, 183, 84, 4, 198, 199, 207]
# 1        8  [59, 438, 93, 123, 463, 525, 30, 288, 534, 322...
# 2       41  [175, 182, 563, 184, 1176, 116, 128, 1037, 104...
# 3       78                             [1258, 305, 500, 2230]
# 4       91  [558, 1176, 195, 587, 592, 74, 1904, 186, 647,...

# %%
pred = test_predictor(test_q, model, n_item, batch_size, N = 100)
pred.head(5)
# Out:
#    user_id                                           movie_id
# 0        2  [217, 209, 48, 38, 23, 189, 132, 0, 210, 51, 2...
# 1        8  [244, 184, 44, 134, 92, 315, 124, 171, 68, 97,...
# 2       41  [132, 189, 711, 160, 92, 669, 740, 104, 775, 7...
# 3       78  [104, 5, 0, 38, 23, 44, 48, 4, 9, 7, 22, 51, 3...
# 4       91  [44, 23, 48, 124, 51, 64, 104, 39, 127, 729, 4...

# %%
scores = evaluate(true, pred)

scores(K = 20)
scores.print_all()

scores(K = 100)
scores.print_all()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=604.0), HTML(value='')))
#       Recall@20 : 0.11202
#    Precision@20 : 0.07310
#          MAP@20 : 0.03618
#          MRR@20 : 0.20943
#         nDCG@20 : 0.10000
# HBox(children=(FloatProgress(value=0.0, max=604.0), HTML(value='')))
#       Recall@100 : 0.30904
#    Precision@100 : 0.05079
#          MAP@100 : 0.04517
#          MRR@100 : 0.21737
#         nDCG@100 : 0.17553
