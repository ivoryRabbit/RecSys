# %% [markdown]
# # Mult-VAE
#
# - [Variational Autoencoders for Collaborative Filtering](https://arxiv.org/pdf/1802.05814.pdf)
# - [참고](https://jrzaurin.github.io/infinitoml/2020/05/15/mult-vae.html)
#
# ## Experiment
#
# - sampling vs training all
#      - sampling이 일반적으로 성능이 좋음
# - alternative learning
#     - alternative learning으로 성능 향상
# - multinomial vs logistic
#     - alternative learning을 적용하지 않으면 logistic의 성능이 더 좋았음
#     - alternative learning을 적용하게 되면 multinomial의 성능이 더 좋아짐
# - Mult-VAE vs Mult-CAE
#     - ML-1m에서는 Mult-CAE 성능이 더 높았음

# %%
import glob
import numpy as np
import pandas as pd
from typing import Callable, Tuple, List

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('bmh')

from sklearn.model_selection import train_test_split, KFold

import tensorflow as tf
import tensorflow.keras.backend as K
from tensorflow.keras.layers import Layer, Input, Dense, Dropout, Embedding, Flatten, concatenate
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.optimizers import SGD, RMSprop, Adam
from tensorflow.keras.optimizers.schedules import ExponentialDecay
from tensorflow.keras.initializers import TruncatedNormal, RandomNormal
from tensorflow.keras.regularizers import l2

from tensorflow.keras.utils import get_file
import zipfile

# %%
def load_data(data_size : str) -> pd.DataFrame:
    ''' load Movie Lens data '''

    if data_size == '100k':
        file = get_file('ml-100k.zip', 'http://files.grouplens.org/datasets/movielens/ml-100k.zip')
        file_name = 'ml-100k/*'
    elif data_size == '1m':
        file = get_file('ml-1m.zip', 'http://files.grouplens.org/datasets/movielens/ml-1m.zip')
        file_name = 'ml-1m/ratings.dat'
    elif data_size == '10m':
        file = get_file('ml-10m.zip', 'http://files.grouplens.org/datasets/movielens/ml-10m.zip')
        file_name = 'ml-10M100K/ratings.dat'
    elif data_size == '20m':
        file = get_file('ml-20m.zip', 'http://files.grouplens.org/datasets/movielens/ml-20m.zip')
        file_name = 'ml-20m/ratings.csv'
    elif data_size == '25m':
        file = get_file('ml-25m.zip', 'http://files.grouplens.org/datasets/movielens/ml-25m.zip')
        file_name = 'ml-25m/ratings.csv'
    zip_ref = zipfile.ZipFile(file, 'r')
    zip_ref.extractall()

    col_names = ['userId', 'movieId', 'rating', 'timestamp']
    if data_size in ['20m', '25m']:
        ratings = pd.read_csv(file_name, engine = 'python')
    else:
        ratings = pd.read_csv(file_name, sep = '|', delimiter = '::', names = col_names, engine = 'python')
    print(ratings.shape)
    return ratings

# %%
ratings = load_data('1m')
ratings.head()
# Out:
# (1000209, 4)
#    userId  movieId  rating  timestamp
# 0       1     1193       5  978300760
# 1       1      661       3  978302109
# 2       1      914       3  978301968
# 3       1     3408       4  978300275
# 4       1     2355       5  978824291

# %% [markdown]
# ## 1. Data Preprocessing

# %%
def preprocessing(df: pd.DataFrame, threshold = 4) -> pd.DataFrame:
    df = df[df.rating >= threshold]
    positive = df.groupby('userId')['movieId'].nunique()
    positive = positive.index[positive >= 5]
    df = df[df.userId.isin(positive)]
    return df.reset_index(drop = True)

# %%
idx_user_map = ratings.userId.unique()
user_idx_map = {e: i for i, e in enumerate(idx_user_map)}
n_user = idx_user_map.shape[0]
print(f'# of user = {n_user}')

idx_item_map = ratings.movieId.unique()
item_idx_map = {e: i for i, e in enumerate(idx_item_map)}
n_item = idx_item_map.shape[0]
print(f'# of item = {n_item}')
# Out:
# # of user = 6040
# # of item = 3706

# %%
def Id2idx(df: pd.DataFrame) -> pd.DataFrame:
    return df.assign(userId = lambda x: x.userId.map(user_idx_map), 
                     movieId = lambda x: x.movieId.map(item_idx_map))

def idx2Id(df: pd.DataFrame) -> pd.DataFrame:
    return df.assign(userId = lambda x: x.userId.apply(lambda x: idx_user_map[x]), 
                     movieId = lambda x: x.movieId.apply(lambda x: idx_item_map[x]))

# %%
ratings = preprocessing(ratings)
ratings = Id2idx(ratings)

print(ratings.shape)
ratings.head(5)
# Out:
# (575272, 4)
#    userId  movieId  rating  timestamp
# 0       0        0       5  978300760
# 1       0        3       4  978300275
# 2       0        4       5  978824291
# 3       0        6       5  978302039
# 4       0        7       5  978300719

# %%
def train_valid_test_split(df: pd.DataFrame) -> pd.DataFrame:
    train_user, test_user = train_test_split(df.userId.unique(), test_size = 0.2, random_state = 7777)
    valid_user, test_user = train_test_split(test_user, test_size = 0.5, random_state = 7777)

    train, valid, test = map(lambda x: df[df.userId.isin(x)], (train_user, valid_user, test_user))
    train, valid, test = map(lambda df: df.reset_index(drop = True), (train, valid, test))
    return train, valid, test

def query_answer_split(df: pd.DataFrame) -> pd.DataFrame:
    query, answer = train_test_split(df, test_size = 0.2, stratify = df.userId, random_state = 7777)
    query, answer = map(lambda df: df.sort_values(['userId', 'timestamp']), (query, answer))
    query, answer = map(lambda df: df.reset_index(drop = True), (query, answer))
    return query, answer

def list_aggregation(df: pd.DataFrame) -> pd.DataFrame:
    return df.groupby('userId', as_index = False)[['movieId', 'rating']].agg(list)

# %%
def train_generator(df: pd.DataFrame,
                    n_item: int,
                    batch_size: int,
                    implicit = True,
                    threshold = 4,
                    corruption = 0.5,
                    sampling = True,
                    NS = 5) -> Tuple[np.array, np.array]:

    n_row = df.index.size
    n_col = n_item

    Ids = np.arange(n_row)
    profile = df['movieId']
    rating = df['rating'] if not implicit else df['rating'].apply(lambda x: [1 if r >= threshold else 0 for r in x])

    n_batch = int(np.ceil(n_row / batch_size))
    if sampling:
        while True:
            batch_Id = np.random.choice(Ids, size = batch_size)
            batch = np.zeros(shape = (batch_size, n_col))
            
            for i, idx in enumerate(batch_Id):
                pos = np.array(profile[idx])
                batch[i, pos] = rating[idx]

            yield batch, batch
    else:
        while True:
            np.random.shuffle(Ids)
        
            for batch_step in range(n_batch):
                lower = batch_step * batch_size
                upper = lower + batch_size
                
                batch_Id = Ids[lower: upper]
                batch = np.zeros(shape = (batch_Id.size, n_col))
                for i, idx in enumerate(batch_Id):
                    pos = np.array(profile[idx])
                    batch[i, pos] = rating[idx]              
                yield batch, batch

# %%
def valid_generator(query: pd.DataFrame,
                    answer: pd.DataFrame,
                    n_item: int,
                    batch_size: int,
                    implicit = True,
                    threshold = 4) -> Tuple[np.array, np.array]:

    n_row = query.index.size
    n_col = n_item

    Ids = np.arange(n_row)
    profile_q = query['movieId']
    profile_a = answer['movieId']
    if implicit:
        rating_q = query['rating'].apply(lambda x: [1 if r >= threshold else 0 for r in x])
        rating_a = answer['rating'].apply(lambda x: [1 if r >= threshold else 0 for r in x])
    else:
        rating_q = query['rating']
        rating_a = answer['rating']

    n_batch = int(np.ceil(n_row / batch_size))
    while True:
        for batch_step in range(n_batch):
            lower = batch_step * batch_size
            upper = lower + batch_size
            
            batch_Id = Ids[lower: upper]
            batch_q = np.zeros(shape = (batch_Id.size, n_col))
            batch_a = np.zeros(shape = (batch_Id.size, n_col))

            for i, idx in enumerate(batch_Id):
                obs = np.array(profile_q[idx]) # observed
                ubs = np.array(profile_a[idx]) # unobserved

                batch_q[i, obs] = rating_q[idx]
                batch_a[i, ubs] = rating_a[idx]

            yield batch_q, batch_a

# %%
def mae(y_true: np.array, y_pred: np.array) -> tf.Tensor:
    ae = K.abs(y_true - y_pred)
    return K.mean(ae, axis = -1)

def rmse(y_true: np.array, y_pred: np.array) -> tf.Tensor:
    se = K.square(mask_true * (y_true - y_pred))
    return K.sqrt(K.mean(masked_se, axis = -1))

def cross_entropy(y_true: np.array, y_pred: np.array) -> tf.Tensor:
    ce = y_true * K.log(y_pred) + (1 - y_true) * K.log(1 - y_pred)
    return -K.sum(ce, axis = -1)

def log_loss(y_true: np.array, y_pred: np.array) -> tf.Tensor:
    return -K.sum(y_true * K.log(y_pred), axis = -1)

def batch_ndcg(y_true, y_pred, k = 100):
    rec = tf.argsort(y_pred, axis = -1, direction = 'DESCENDING')[:, :k]

    row = tf.repeat(tf.range(tf.shape(y_true)[0]), k)
    row = tf.expand_dims(row, axis = 1)
    col = tf.reshape(rec, shape = [-1])
    col = tf.expand_dims(col, axis = 1)
    loc = tf.concat([row, col], axis = 1)

    top_k = tf.reshape(tf.gather_nd(y_true, loc), shape = tf.shape(rec))
    ideal = tf.sort(top_k, axis = 1, direction = 'DESCENDING')

    weight = tf.range(2, 102, dtype = 'float32')
    weight = tf.math.log(weight)
    weight = tf.math.reciprocal(weight)
    
    dcg = tf.reduce_sum(top_k * weight, axis = 1)    
    idcg = tf.reduce_sum(ideal * weight, axis = 1)
    return dcg / tf.where(idcg == 0, 1.0, idcg)

# %%
class Sampling(Layer):
    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = tf.shape(z_mean)[0]
        dim = tf.shape(z_mean)[1]
        return z_mean + K.exp(0.5 * z_log_var) * K.random_normal(shape = (batch, dim))

# %%
def VAE(n_user: int,
        n_item: int,
        latent_dim = 200,
        activation = 'tanh',
        enc_optimizer = 'adam',
        optimizer = 'adam',
        dropout_rate = 0.5,
        kernel_initializer = None,
        likelihood = 'logistic',
        beta = 0.2) -> Callable:

    if not kernel_initializer:
        kernel_initializer = RandomNormal(mean = 0.0, stddev = 0.05, seed = None)

    if likelihood == 'multinomial':
        loss = log_loss
        last_activation = 'softmax'
    elif likelihood == 'logistic':
        loss = cross_entropy
        last_activation = 'sigmoid'
    elif likelihood == 'gaussian':
        loss = rmse
        last_activation = 'sigmoid'
    
    inputs = Input(shape = (n_item, ), name = 'input')
    z_mean_weight = Dense(latent_dim,
                          activation = activation,
                          kernel_initializer = kernel_initializer,
                          name = 'mean')
    z_log_var_weight = Dense(latent_dim, 
                             activation = activation,
                             kernel_initializer = kernel_initializer,
                             name = 'log_var')
    outputs_weight = Dense(n_item,
                           activation = last_activation, 
                           kernel_initializer = kernel_initializer,
                           name = 'output')

    x = Dropout(dropout_rate)(inputs)
    enc_z_mean = z_mean_weight(x)
    enc_z_log_var = z_log_var_weight(x)
    enc_z = Sampling()([enc_z_mean, enc_z_log_var])
    enc_KLD = -0.5 * K.sum(1 + enc_z_log_var - K.exp(enc_z_log_var) - K.square(enc_z_mean), axis = -1)

    encoder = Model(inputs = inputs, outputs = [enc_z_mean, enc_z_log_var, enc_z], name = 'encoder')
    encoder.add_loss(enc_KLD)
    encoder.compile(optimizer = enc_optimizer)

    z_mean = z_mean_weight(inputs)
    z_log_var = z_log_var_weight(inputs)
    z = Sampling()([z_mean, z_log_var])
    outputs = outputs_weight(z)

    KLD = -0.5 * K.sum(1 + z_log_var - K.exp(z_log_var) - K.square(z_mean), axis = -1)
    MLE = loss(inputs, outputs)
    vae_loss = K.mean(MLE + beta * KLD, axis = -1)

    model = Model(inputs = inputs, outputs = outputs, name = 'VAE')
    model.add_loss(vae_loss)
    model.compile(optimizer = optimizer, metrics = [mae, batch_ndcg])
    return encoder, model

# %%
def test_predictor(df: pd.DataFrame, 
                   model: Callable, 
                   n_item: int, 
                   batch_size: int, 
                   implicit = True,
                   threshold = 4,
                   top_N = 20) -> float:

    n_row = df.index.size
    n_col = n_item

    Ids = np.arange(n_row)
    profile = df['movieId']
    rating = df['rating'] if not implicit else df['rating'].apply(lambda x: [1 if r >= threshold else 0 for r in x])

    res = []
    steps = int(np.ceil(n_row / batch_size))
    for batch_step in range(steps):
        lower = batch_step * batch_size
        upper = lower + batch_size

        batch_Id = Ids[lower: upper]
        y_true = np.zeros(shape = (batch_Id.size, n_col))
        for i, idx in enumerate(batch_Id):
            y_true[i, profile[idx]] = rating[idx]

        y_pred = model.predict(y_true, verbose = 0)
        
        rec = np.argsort(np.where(y_true == 1, -1, y_pred), axis = -1)[:, :-top_N-1:-1]
        res.append(rec)
    return np.concatenate(res)

# %%
def show_history(history, loss: str, metric: str) -> None:
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (12, 4))

    ax1.plot(history[f'{loss}'])
    ax1.plot(history[f'val_{loss}'])
    ax1.set_title('Loss', fontsize = 20)
    ax1.set_ylabel('loss')
    ax1.set_xlabel('epoch')
    ax1.legend(['loss', 'val_loss'], loc = 'upper right')

    ax2.plot(history[f'{metric}'])
    ax2.plot(history[f'val_{metric}'])
    ax2.set_title('Metric', fontsize = 20)
    ax2.set_ylabel('metric')
    ax2.set_xlabel('epoch')
    ax2.legend(['metric', 'metric'], loc = 'upper right')
    plt.show()

# %%
def ndcg(gt, rec):
    dcg, idcg = 0.0, 0.0
    k = 0
    for i, r in enumerate(rec):
        if r in gt:
            dcg += 1.0 / np.log(i + 2)
            idcg += 1.0 / np.log(k + 2)
            k += 1
    return dcg / np.max([1, idcg])

def recall(gt, rec):
    res = [r for r in rec if r in gt]
    return len(res) / len(gt)

def precision(gt, rec):
    res = [r for r in rec if r in gt]
    return len(res) / len(rec)

def precision_k(gt, rec, k):
    rec_k = rec[:k+1]
    res = [r for r in rec_k if r in gt]
    return len(res) / k

def AP_k(gt, rec, k = 20):
    res = 0
    for i in range(k):
        if rec[i] in gt:
            res += precision_k(gt, rec, i+1)
    return res / min(k, len(gt))

# %%
def evaluation(true: pd.DataFrame, pred):
    m_ndcg = 0
    m_recall = 0
    m_precision = 0
    map_k = 0
    for i in range(len(pred)):
        rec = pred[i]
        gt = true.at[i, 'movieId']
        m_ndcg += ndcg(gt, rec)
        m_recall += recall(gt, rec)
        m_precision += precision(gt, rec)
        map_k += AP_k(gt, rec)
    m_ndcg /= len(pred)
    m_recall /= len(pred)
    m_precision /= len(pred)
    map_k /= len(pred)
    return m_ndcg, m_recall, m_precision, map_k

# %% [markdown]
# ### 1. Mult-DAE(Multinomial Likelihood)

# %%
batch_size = 128

train, valid, test = train_valid_test_split(ratings)
(valid_q, valid_a), (test_q, test_a) = map(query_answer_split, (valid, test))
train, valid_q, valid_a, test_q, test_a = map(list_aggregation, (train, valid_q, valid_a, test_q, test_a))

train_gen = train_generator(train, n_item, batch_size)
valid_gen = valid_generator(valid_q, valid_a, n_item, batch_size)

steps_per_epoch = train.index.size // batch_size + 1
validation_steps = valid_q.index.size // batch_size + 1

# %%
enc_optimizer = RMSprop(learning_rate = 0.001, decay = 1e-5)
optimizer = Adam(learning_rate = 0.001, decay = 1e-5)
encoder, model = VAE(n_user, n_item, latent_dim = 200, enc_optimizer = enc_optimizer, optimizer = optimizer, likelihood = 'multinomial')
model.summary()
# Out:
# Model: "VAE"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              [(None, 3706)]       0
# __________________________________________________________________________________________________
# mean (Dense)                    (None, 200)          741400      input[0][0]
# __________________________________________________________________________________________________
# log_var (Dense)                 (None, 200)          741400      input[0][0]
# __________________________________________________________________________________________________
# sampling_1 (Sampling)           (None, 200)          0           mean[1][0]
#                                                                  log_var[1][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 3706)         744906      sampling_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_1 (TensorFlow [(None, 200)]        0           log_var[1][0]
# __________________________________________________________________________________________________
# tf_op_layer_Exp_1 (TensorFlowOp [(None, 200)]        0           log_var[1][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sub_2 (TensorFlowOp [(None, 200)]        0           tf_op_layer_AddV2_1[0][0]
#                                                                  tf_op_layer_Exp_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Square_1 (TensorFlo [(None, 200)]        0           mean[1][0]
# __________________________________________________________________________________________________
# tf_op_layer_Log (TensorFlowOpLa [(None, 3706)]       0           output[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sub_3 (TensorFlowOp [(None, 200)]        0           tf_op_layer_Sub_2[0][0]
#                                                                  tf_op_layer_Square_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_2 (TensorFlowOp [(None, 3706)]       0           input[0][0]
#                                                                  tf_op_layer_Log[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sum_1 (TensorFlowOp [(None,)]            0           tf_op_layer_Sub_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sum_2 (TensorFlowOp [(None,)]            0           tf_op_layer_Mul_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_1 (TensorFlowOp [(None,)]            0           tf_op_layer_Sum_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Neg (TensorFlowOpLa [(None,)]            0           tf_op_layer_Sum_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_3 (TensorFlowOp [(None,)]            0           tf_op_layer_Mul_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_2 (TensorFlow [(None,)]            0           tf_op_layer_Neg[0][0]
#                                                                  tf_op_layer_Mul_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mean (TensorFlowOpL [()]                 0           tf_op_layer_AddV2_2[0][0]
# __________________________________________________________________________________________________
# add_loss_1 (AddLoss)            ()                   0           tf_op_layer_Mean[0][0]
# ==================================================================================================
# Total params: 2,227,706
# Trainable params: 2,227,706
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# %%time
epochs = 100
total_hist = {}
for _ in range(epochs):
    anneal_size, epoch_size = 8, 4
    encoder.fit(x = train_gen, epochs = anneal_size, steps_per_epoch = steps_per_epoch, verbose = 0)
    hist = model.fit(x = train_gen, validation_data = valid_gen, epochs = epoch_size, verbose = 1,
                     steps_per_epoch = steps_per_epoch, validation_steps = validation_steps)
    for key in hist.history.keys():
        total_hist[key] = total_hist.get(key, []) + hist.history[key]
# Out:
# Epoch 1/4
# 38/38 [==============================] - 1s 18ms/step - loss: 737.4662 - mae: 0.0259 - batch_ndcg: 0.4842 - val_loss: 544.0033 - val_mae: 0.0052 - val_batch_ndcg: 0.2829
# Epoch 2/4
# 38/38 [==============================] - 0s 13ms/step - loss: 693.1268 - mae: 0.0258 - batch_ndcg: 0.6434 - val_loss: 528.3876 - val_mae: 0.0052 - val_batch_ndcg: 0.3405
# Epoch 3/4
# 38/38 [==============================] - 1s 13ms/step - loss: 663.2756 - mae: 0.0254 - batch_ndcg: 0.7124 - val_loss: 518.1976 - val_mae: 0.0052 - val_batch_ndcg: 0.3542
# Epoch 4/4
# 38/38 [==============================] - 0s 13ms/step - loss: 670.3760 - mae: 0.0260 - batch_ndcg: 0.7475 - val_loss: 512.3726 - val_mae: 0.0052 - val_batch_ndcg: 0.3526
# Epoch 1/4
# 38/38 [==============================] - 1s 13ms/step - loss: 697.8267 - mae: 0.0259 - batch_ndcg: 0.6041 - val_loss: 519.9263 - val_mae: 0.0052 - val_batch_ndcg: 0.3293
# Epoch 2/4
# 38/38 [==============================] - 1s 13ms/step - loss: 657.0162 - mae: 0.0255 - batch_ndcg: 0.7187 - val_loss: 513.5949 - val_mae: 0.0052 - val_batch_ndcg: 0.3634
# Epoch 3/4
# 38/38 [==============================] - 1s 13ms/step - loss: 659.1346 - mae: 0.0258 - batch_ndcg: 0.7433 - val_loss: 510.4063 - val_mae: 0.0052 - val_batch_ndcg: 0.3636
# Epoch 4/4
# 38/38 [==============================] - 1s 14ms/step - loss: 675.6815 - mae: 0.0265 - batch_ndcg: 0.7600 - val_loss: 507.7903 - val_mae: 0.0052 - val_batch_ndcg: 0.3767
# Epoch 1/4
# 38/38 [==============================] - 1s 14ms/step - loss: 690.5310 - mae: 0.0258 - batch_ndcg: 0.6050 - val_loss: 516.0175 - val_mae: 0.0052 - val_batch_ndcg: 0.3503
# Epoch 2/4
# 38/38 [==============================] - 1s 13ms/step - loss: 664.5729 - mae: 0.0260 - batch_ndcg: 0.7327 - val_loss: 510.3781 - val_mae: 0.0052 - val_batch_ndcg: 0.3649
# Epoch 3/4
# 38/38 [==============================] - 0s 13ms/step - loss: 666.3948 - mae: 0.0262 - batch_ndcg: 0.7546 - val_loss: 507.3947 - val_mae: 0.0052 - val_batch_ndcg: 0.3681
# Epoch 4/4
# 38/38 [==============================] - 0s 13ms/step - loss: 645.6785 - mae: 0.0256 - batch_ndcg: 0.7633 - val_loss: 505.5215 - val_mae: 0.0052 - val_batch_ndcg: 0.3817
# Epoch 1/4
# 38/38 [==============================] - 1s 14ms/step - loss: 697.1528 - mae: 0.0261 - batch_ndcg: 0.6103 - val_loss: 513.7211 - val_mae: 0.0052 - val_batch_ndcg: 0.3599
# Epoch 2/4
# 38/38 [==============================] - 0s 13ms/step - loss: 662.7090 - mae: 0.0260 - batch_ndcg: 0.7401 - val_loss: 508.5580 - val_mae: 0.0052 - val_batch_ndcg: 0.3799
# Epoch 3/4
# 38/38 [==============================] - 1s 15ms/step - loss: 651.4664 - mae: 0.0258 - batch_ndcg: 0.7620 - val_loss: 505.6269 - val_mae: 0.0052 - val_batch_ndcg: 0.3781
# Epoch 4/4
# 38/38 [==============================] - 1s 15ms/step - loss: 664.5777 - mae: 0.0264 - batch_ndcg: 0.7729 - val_loss: 504.2660 - val_mae: 0.0052 - val_batch_ndcg: 0.3746
# Epoch 1/4
# 38/38 [==============================] - 1s 13ms/step - loss: 677.3010 - mae: 0.0257 - batch_ndcg: 0.6176 - val_loss: 510.8766 - val_mae: 0.0052 - val_batch_ndcg: 0.3683
# Epoch 2/4
# 38/38 [==============================] - 0s 13ms/step - loss: 653.6809 - mae: 0.0259 - batch_ndcg: 0.7506 - val_loss: 505.7307 - val_mae: 0.0052 - val_batch_ndcg: 0.3798
# Epoch 3/4
# 38/38 [==============================] - 0s 13ms/step - loss: 659.3608 - mae: 0.0262 - batch_ndcg: 0.7670 - val_loss: 504.2699 - val_mae: 0.0052 - val_batch_ndcg: 0.3821
# Epoch 4/4
# 38/38 [==============================] - 1s 13ms/step - loss: 635.3943 - mae: 0.0254 - batch_ndcg: 0.7774 - val_loss: 502.6508 - val_mae: 0.0052 - val_batch_ndcg: 0.3844
# Epoch 1/4
# 38/38 [==============================] - 1s 14ms/step - loss: 689.7873 - mae: 0.0261 - batch_ndcg: 0.6275 - val_loss: 509.7043 - val_mae: 0.0052 - val_batch_ndcg: 0.3681
# Epoch 2/4
# 38/38 [==============================] - 1s 13ms/step - loss: 647.2850 - mae: 0.0256 - batch_ndcg: 0.7533 - val_loss: 505.4745 - val_mae: 0.0052 - val_batch_ndcg: 0.3849
# Epoch 3/4
# 38/38 [==============================] - 0s 13ms/step - loss: 659.1541 - mae: 0.0262 - batch_ndcg: 0.7709 - val_loss: 503.4153 - val_mae: 0.0052 - val_batch_ndcg: 0.3804
# Epoch 4/4
# 38/38 [==============================] - 0s 13ms/step - loss: 656.6262 - mae: 0.0262 - batch_ndcg: 0.7833 - val_loss: 501.8018 - val_mae: 0.0052 - val_batch_ndcg: 0.3886
# Epoch 1/4
# 38/38 [==============================] - 1s 14ms/step - loss: 689.1668 - mae: 0.0261 - batch_ndcg: 0.6299 - val_loss: 509.8747 - val_mae: 0.0052 - val_batch_ndcg: 0.3617
# Epoch 2/4
# 38/38 [==============================] - 1s 14ms/step - loss: 677.1418 - mae: 0.0268 - batch_ndcg: 0.7621 - val_loss: 505.4650 - val_mae: 0.0052 - val_batch_ndcg: 0.3753
# Epoch 3/4
# 38/38 [==============================] - 0s 13ms/step - loss: 625.8380 - mae: 0.0250 - batch_ndcg: 0.7700 - val_loss: 502.9212 - val_mae: 0.0052 - val_batch_ndcg: 0.3906
# Epoch 4/4
# 38/38 [==============================] - 0s 13ms/step - loss: 664.3870 - mae: 0.0266 - batch_ndcg: 0.7858 - val_loss: 501.6628 - val_mae: 0.0052 - val_batch_ndcg: 0.3837
# Epoch 1/4
# 38/38 [==============================] - 1s 13ms/step - loss: 684.7201 - mae: 0.0260 - batch_ndcg: 0.6230 - val_loss: 509.0722 - val_mae: 0.0052 - val_batch_ndcg: 0.3685
# Epoch 2/4
# 38/38 [==============================] - 1s 13ms/step - loss: 642.8074 - mae: 0.0255 - batch_ndcg: 0.7556 - val_loss: 504.6279 - val_mae: 0.0052 - val_batch_ndcg: 0.3823
# Epoch 3/4
# 38/38 [==============================] - 1s 13ms/step - loss: 631.4451 - mae: 0.0252 - batch_ndcg: 0.7691 - val_loss: 502.7639 - val_mae: 0.0052 - val_batch_ndcg: 0.3863
# Epoch 4/4
# 38/38 [==============================] - 0s 13ms/step - loss: 642.2497 - mae: 0.0257 - batch_ndcg: 0.7839 - val_loss: 501.6644 - val_mae: 0.0052 - val_batch_ndcg: 0.3849
# Epoch 1/4
# 38/38 [==============================] - 1s 14ms/step - loss: 697.5972 - mae: 0.0265 - batch_ndcg: 0.6425 - val_loss: 507.9401 - val_mae: 0.0052 - val_batch_ndcg: 0.3741
# Epoch 2/4
# 38/38 [==============================] - 0s 13ms/step - loss: 652.1715 - mae: 0.0259 - batch_ndcg: 0.7642 - val_loss: 503.8062 - val_mae: 0.0052 - val_batch_ndcg: 0.3822
# Epoch 3/4
# 38/38 [==============================] - 1s 14ms/step - loss: 661.2407 - mae: 0.0264 - batch_ndcg: 0.7780 - val_loss: 502.1389 - val_mae: 0.0052 - val_batch_ndcg: 0.3887
# Epoch 4/4
# 38/38 [==============================] - 1s 13ms/step - loss: 649.9963 - mae: 0.0261 - batch_ndcg: 0.7860 - val_loss: 500.9767 - val_mae: 0.0052 - val_batch_ndcg: 0.3882
# Epoch 1/4
# 38/38 [==============================] - 1s 14ms/step - loss: 679.9490 - mae: 0.0259 - batch_ndcg: 0.6401 - val_loss: 507.6218 - val_mae: 0.0052 - val_batch_ndcg: 0.3694
# Epoch 2/4
# 38/38 [==============================] - 0s 13ms/step - loss: 647.4274 - mae: 0.0258 - batch_ndcg: 0.7610 - val_loss: 503.5883 - val_mae: 0.0052 - val_batch_ndcg: 0.3876
# Epoch 3/4
# 38/38 [==============================] - 0s 13ms/step - loss: 658.5176 - mae: 0.0264 - batch_ndcg: 0.7816 - val_loss: 501.8528 - val_mae: 0.0052 - val_batch_ndcg: 0.3815
# Epoch 4/4
# 38/38 [==============================] - 0s 13ms/step - loss: 656.8067 - mae: 0.0264 - batch_ndcg: 0.7898 - val_loss: 500.2520 - val_mae: 0.0052 - val_batch_ndcg: 0.3910
# Epoch 1/4
# 38/38 [==============================] - 1s 13ms/step - loss: 680.1998 - mae: 0.0259 - batch_ndcg: 0.6447 - val_loss: 507.8049 - val_mae: 0.0052 - val_batch_ndcg: 0.3773
# Epoch 2/4
# 38/38 [==============================] - 1s 14ms/step - loss: 655.3312 - mae: 0.0261 - batch_ndcg: 0.7624 - val_loss: 504.0667 - val_mae: 0.0052 - val_batch_ndcg: 0.3933
# Epoch 3/4
# 38/38 [==============================] - 1s 14ms/step - loss: 646.4176 - mae: 0.0259 - batch_ndcg: 0.7769 - val_loss: 501.5008 - val_mae: 0.0052 - val_batch_ndcg: 0.3850
# Epoch 4/4
# 38/38 [==============================] - 0s 13ms/step - loss: 646.9617 - mae: 0.0260 - batch_ndcg: 0.7871 - val_loss: 501.0306 - val_mae: 0.0052 - val_batch_ndcg: 0.3925
# Epoch 1/4
# 38/38 [==============================] - 1s 14ms/step - loss: 691.9894 - mae: 0.0263 - batch_ndcg: 0.6474 - val_loss: 508.3358 - val_mae: 0.0052 - val_batch_ndcg: 0.3684
# Epoch 2/4
# 38/38 [==============================] - 0s 13ms/step - loss: 670.8498 - mae: 0.0267 - batch_ndcg: 0.7655 - val_loss: 503.3881 - val_mae: 0.0052 - val_batch_ndcg: 0.3765
# Epoch 3/4
# 38/38 [==============================] - 0s 13ms/step - loss: 643.2896 - mae: 0.0258 - batch_ndcg: 0.7812 - val_loss: 502.0017 - val_mae: 0.0052 - val_batch_ndcg: 0.3782
# Epoch 4/4
# 38/38 [==============================] - 1s 14ms/step - loss: 644.9711 - mae: 0.0260 - batch_ndcg: 0.7891 - val_loss: 500.0203 - val_mae: 0.0052 - val_batch_ndcg: 0.3870
# Epoch 1/4
# 38/38 [==============================] - 1s 14ms/step - loss: 688.7310 - mae: 0.0262 - batch_ndcg: 0.6532 - val_loss: 507.1219 - val_mae: 0.0052 - val_batch_ndcg: 0.3747
# Epoch 2/4
# 38/38 [==============================] - 1s 13ms/step - loss: 644.0856 - mae: 0.0257 - batch_ndcg: 0.7661 - val_loss: 503.1458 - val_mae: 0.0052 - val_batch_ndcg: 0.3882
# Epoch 3/4
# 38/38 [==============================] - 0s 13ms/step - loss: 637.6356 - mae: 0.0256 - batch_ndcg: 0.7801 - val_loss: 501.1213 - val_mae: 0.0052 - val_batch_ndcg: 0.3956
# Epoch 4/4
# 38/38 [==============================] - 1s 13ms/step - loss: 649.5781 - mae: 0.0262 - batch_ndcg: 0.7928 - val_loss: 500.4720 - val_mae: 0.0052 - val_batch_ndcg: 0.3942
# Epoch 1/4
# 38/38 [==============================] - 1s 14ms/step - loss: 679.6703 - mae: 0.0257 - batch_ndcg: 0.6524 - val_loss: 508.4135 - val_mae: 0.0052 - val_batch_ndcg: 0.3744
# Epoch 2/4
# 38/38 [==============================] - 0s 13ms/step - loss: 665.7652 - mae: 0.0265 - batch_ndcg: 0.7705 - val_loss: 503.3488 - val_mae: 0.0052 - val_batch_ndcg: 0.3908
# Epoch 3/4
# 38/38 [==============================] - 0s 13ms/step - loss: 650.1829 - mae: 0.0261 - batch_ndcg: 0.7846 - val_loss: 501.8177 - val_mae: 0.0052 - val_batch_ndcg: 0.3964
# Epoch 4/4
# 38/38 [==============================] - 1s 13ms/step - loss: 644.1396 - mae: 0.0259 - batch_ndcg: 0.7870 - val_loss: 500.7443 - val_mae: 0.0052 - val_batch_ndcg: 0.3899
# Epoch 1/4
# 38/38 [==============================] - 0s 13ms/step - loss: 673.2022 - mae: 0.0257 - batch_ndcg: 0.6494 - val_loss: 507.4288 - val_mae: 0.0052 - val_batch_ndcg: 0.3821
# Epoch 2/4
# 38/38 [==============================] - 1s 13ms/step - loss: 659.7703 - mae: 0.0263 - batch_ndcg: 0.7664 - val_loss: 503.2541 - val_mae: 0.0052 - val_batch_ndcg: 0.3817
# Epoch 3/4
# 38/38 [==============================] - 0s 13ms/step - loss: 661.4953 - mae: 0.0266 - batch_ndcg: 0.7864 - val_loss: 501.2634 - val_mae: 0.0052 - val_batch_ndcg: 0.3884
# Epoch 4/4
# 38/38 [==============================] - 0s 13ms/step - loss: 653.6838 - mae: 0.0263 - batch_ndcg: 0.7931 - val_loss: 500.2026 - val_mae: 0.0052 - val_batch_ndcg: 0.3960
# Epoch 1/4
# 38/38 [==============================] - 1s 14ms/step - loss: 685.2485 - mae: 0.0261 - batch_ndcg: 0.6537 - val_loss: 507.5703 - val_mae: 0.0052 - val_batch_ndcg: 0.3690
# Epoch 2/4
# 38/38 [==============================] - 0s 13ms/step - loss: 628.2406 - mae: 0.0251 - batch_ndcg: 0.7656 - val_loss: 502.8170 - val_mae: 0.0052 - val_batch_ndcg: 0.3883
# Epoch 3/4
# 38/38 [==============================] - 1s 13ms/step - loss: 637.3959 - mae: 0.0256 - batch_ndcg: 0.7830 - val_loss: 501.1333 - val_mae: 0.0052 - val_batch_ndcg: 0.3893
# Epoch 4/4
# 38/38 [==============================] - 1s 13ms/step - loss: 636.7830 - mae: 0.0257 - batch_ndcg: 0.7937 - val_loss: 499.9816 - val_mae: 0.0052 - val_batch_ndcg: 0.3899
# Epoch 1/4
# 38/38 [==============================] - 0s 13ms/step - loss: 679.1942 - mae: 0.0259 - batch_ndcg: 0.6607 - val_loss: 506.8377 - val_mae: 0.0052 - val_batch_ndcg: 0.3780
# Epoch 2/4
# 38/38 [==============================] - 1s 13ms/step - loss: 640.5166 - mae: 0.0256 - batch_ndcg: 0.7685 - val_loss: 502.4065 - val_mae: 0.0052 - val_batch_ndcg: 0.3871
# Epoch 3/4
# 38/38 [==============================] - 1s 13ms/step - loss: 647.8192 - mae: 0.0260 - batch_ndcg: 0.7877 - val_loss: 500.6947 - val_mae: 0.0052 - val_batch_ndcg: 0.3882
# Epoch 4/4
# 38/38 [==============================] - 1s 13ms/step - loss: 658.2844 - mae: 0.0265 - batch_ndcg: 0.7992 - val_loss: 499.9500 - val_mae: 0.0052 - val_batch_ndcg: 0.3928
# Epoch 1/4
# 38/38 [==============================] - 1s 14ms/step - loss: 688.8367 - mae: 0.0264 - batch_ndcg: 0.6671 - val_loss: 505.9351 - val_mae: 0.0052 - val_batch_ndcg: 0.3750
# Epoch 2/4
# 38/38 [==============================] - 0s 13ms/step - loss: 642.2605 - mae: 0.0257 - batch_ndcg: 0.7691 - val_loss: 502.2121 - val_mae: 0.0052 - val_batch_ndcg: 0.3793
# Epoch 3/4
# 38/38 [==============================] - 0s 13ms/step - loss: 649.5179 - mae: 0.0261 - batch_ndcg: 0.7860 - val_loss: 500.1954 - val_mae: 0.0052 - val_batch_ndcg: 0.3878
# Epoch 4/4
# 38/38 [==============================] - 1s 13ms/step - loss: 659.7043 - mae: 0.0266 - batch_ndcg: 0.7982 - val_loss: 499.4499 - val_mae: 0.0052 - val_batch_ndcg: 0.3863
# Epoch 1/4
# 38/38 [==============================] - 1s 14ms/step - loss: 661.3279 - mae: 0.0252 - batch_ndcg: 0.6671 - val_loss: 507.3508 - val_mae: 0.0052 - val_batch_ndcg: 0.3776
# Epoch 2/4
# 38/38 [==============================] - 1s 13ms/step - loss: 670.5167 - mae: 0.0267 - batch_ndcg: 0.7701 - val_loss: 503.0479 - val_mae: 0.0052 - val_batch_ndcg: 0.3807
# Epoch 3/4
# 38/38 [==============================] - 1s 13ms/step - loss: 643.5204 - mae: 0.0259 - batch_ndcg: 0.7852 - val_loss: 500.8470 - val_mae: 0.0052 - val_batch_ndcg: 0.3896
# Epoch 4/4
# 38/38 [==============================] - 0s 13ms/step - loss: 634.2809 - mae: 0.0257 - batch_ndcg: 0.7967 - val_loss: 499.9758 - val_mae: 0.0052 - val_batch_ndcg: 0.3947
# Epoch 1/4
# 38/38 [==============================] - 1s 14ms/step - loss: 666.9492 - mae: 0.0255 - batch_ndcg: 0.6636 - val_loss: 506.7888 - val_mae: 0.0052 - val_batch_ndcg: 0.3780
# Epoch 2/4
# 38/38 [==============================] - 1s 13ms/step - loss: 650.5519 - mae: 0.0260 - batch_ndcg: 0.7687 - val_loss: 502.3914 - val_mae: 0.0052 - val_batch_ndcg: 0.3845
# Epoch 3/4
# 38/38 [==============================] - 1s 13ms/step - loss: 641.8780 - mae: 0.0259 - batch_ndcg: 0.7848 - val_loss: 500.2602 - val_mae: 0.0052 - val_batch_ndcg: 0.3827
# Epoch 4/4
# 38/38 [==============================] - 0s 13ms/step - loss: 634.6086 - mae: 0.0257 - batch_ndcg: 0.7922 - val_loss: 499.2014 - val_mae: 0.0052 - val_batch_ndcg: 0.3866
# Epoch 1/4
# 38/38 [==============================] - 1s 14ms/step - loss: 696.1024 - mae: 0.0267 - batch_ndcg: 0.6768 - val_loss: 505.6830 - val_mae: 0.0052 - val_batch_ndcg: 0.3838
# Epoch 2/4
# 38/38 [==============================] - 1s 14ms/step - loss: 644.9508 - mae: 0.0258 - batch_ndcg: 0.7718 - val_loss: 502.1149 - val_mae: 0.0052 - val_batch_ndcg: 0.3927
# Epoch 3/4
# 38/38 [==============================] - 0s 13ms/step - loss: 643.3519 - mae: 0.0260 - batch_ndcg: 0.7892 - val_loss: 500.3560 - val_mae: 0.0052 - val_batch_ndcg: 0.3810
# Epoch 4/4
# 38/38 [==============================] - 0s 13ms/step - loss: 630.3781 - mae: 0.0255 - batch_ndcg: 0.7959 - val_loss: 499.3756 - val_mae: 0.0052 - val_batch_ndcg: 0.3894
# Epoch 1/4
# 38/38 [==============================] - 1s 13ms/step - loss: 679.1343 - mae: 0.0261 - batch_ndcg: 0.6800 - val_loss: 506.7261 - val_mae: 0.0052 - val_batch_ndcg: 0.3795
# Epoch 2/4
# 38/38 [==============================] - 0s 13ms/step - loss: 653.7068 - mae: 0.0262 - batch_ndcg: 0.7730 - val_loss: 501.9019 - val_mae: 0.0052 - val_batch_ndcg: 0.3879
# Epoch 3/4
# 38/38 [==============================] - 1s 13ms/step - loss: 654.3404 - mae: 0.0264 - batch_ndcg: 0.7875 - val_loss: 500.4098 - val_mae: 0.0052 - val_batch_ndcg: 0.3875
# Epoch 4/4
# 38/38 [==============================] - 0s 13ms/step - loss: 623.8998 - mae: 0.0253 - batch_ndcg: 0.7941 - val_loss: 499.2986 - val_mae: 0.0052 - val_batch_ndcg: 0.4007
# Epoch 1/4
# 38/38 [==============================] - 1s 13ms/step - loss: 690.4360 - mae: 0.0264 - batch_ndcg: 0.6833 - val_loss: 505.8842 - val_mae: 0.0052 - val_batch_ndcg: 0.3871
# Epoch 2/4
# 38/38 [==============================] - 0s 13ms/step - loss: 633.2328 - mae: 0.0254 - batch_ndcg: 0.7680 - val_loss: 502.1161 - val_mae: 0.0052 - val_batch_ndcg: 0.3902
# Epoch 3/4
# 38/38 [==============================] - 1s 14ms/step - loss: 629.8464 - mae: 0.0254 - batch_ndcg: 0.7903 - val_loss: 499.7436 - val_mae: 0.0052 - val_batch_ndcg: 0.3901
# Epoch 4/4
# 38/38 [==============================] - 1s 13ms/step - loss: 634.6343 - mae: 0.0257 - batch_ndcg: 0.7977 - val_loss: 499.2396 - val_mae: 0.0052 - val_batch_ndcg: 0.3919
# Epoch 1/4
# 38/38 [==============================] - 1s 14ms/step - loss: 680.8760 - mae: 0.0261 - batch_ndcg: 0.6832 - val_loss: 506.1340 - val_mae: 0.0052 - val_batch_ndcg: 0.3803
# Epoch 2/4
# 38/38 [==============================] - 1s 13ms/step - loss: 646.5472 - mae: 0.0259 - batch_ndcg: 0.7771 - val_loss: 502.7703 - val_mae: 0.0052 - val_batch_ndcg: 0.3902
# Epoch 3/4
# 38/38 [==============================] - 1s 14ms/step - loss: 649.8356 - mae: 0.0261 - batch_ndcg: 0.7897 - val_loss: 499.9993 - val_mae: 0.0052 - val_batch_ndcg: 0.3855
# Epoch 4/4
# 38/38 [==============================] - 1s 13ms/step - loss: 641.6607 - mae: 0.0259 - batch_ndcg: 0.7976 - val_loss: 498.9290 - val_mae: 0.0052 - val_batch_ndcg: 0.3928
# Epoch 1/4
# 38/38 [==============================] - 1s 15ms/step - loss: 671.4646 - mae: 0.0259 - batch_ndcg: 0.6833 - val_loss: 506.2755 - val_mae: 0.0052 - val_batch_ndcg: 0.3831
# Epoch 2/4
# 38/38 [==============================] - 1s 13ms/step - loss: 637.8932 - mae: 0.0255 - batch_ndcg: 0.7682 - val_loss: 502.0075 - val_mae: 0.0052 - val_batch_ndcg: 0.3892
# Epoch 3/4
# 38/38 [==============================] - 1s 14ms/step - loss: 631.7372 - mae: 0.0255 - batch_ndcg: 0.7862 - val_loss: 499.9141 - val_mae: 0.0052 - val_batch_ndcg: 0.3897
# Epoch 4/4
# 38/38 [==============================] - 1s 13ms/step - loss: 635.9039 - mae: 0.0257 - batch_ndcg: 0.7957 - val_loss: 498.4090 - val_mae: 0.0052 - val_batch_ndcg: 0.3877
# Epoch 1/4
# 38/38 [==============================] - 1s 14ms/step - loss: 654.8035 - mae: 0.0252 - batch_ndcg: 0.6794 - val_loss: 505.5907 - val_mae: 0.0052 - val_batch_ndcg: 0.3725
# Epoch 2/4
# 38/38 [==============================] - 1s 14ms/step - loss: 652.7879 - mae: 0.0262 - batch_ndcg: 0.7798 - val_loss: 501.5544 - val_mae: 0.0052 - val_batch_ndcg: 0.3869
# Epoch 3/4
# 38/38 [==============================] - 1s 14ms/step - loss: 627.4008 - mae: 0.0254 - batch_ndcg: 0.7900 - val_loss: 499.6826 - val_mae: 0.0052 - val_batch_ndcg: 0.3984
# Epoch 4/4
# 38/38 [==============================] - 0s 13ms/step - loss: 639.7864 - mae: 0.0259 - batch_ndcg: 0.8002 - val_loss: 498.6001 - val_mae: 0.0052 - val_batch_ndcg: 0.3855
# Epoch 1/4
# 38/38 [==============================] - 1s 14ms/step - loss: 680.3411 - mae: 0.0262 - batch_ndcg: 0.6903 - val_loss: 505.3424 - val_mae: 0.0052 - val_batch_ndcg: 0.3810
# Epoch 2/4
# 38/38 [==============================] - 1s 13ms/step - loss: 661.7156 - mae: 0.0265 - batch_ndcg: 0.7783 - val_loss: 501.0112 - val_mae: 0.0052 - val_batch_ndcg: 0.3898
# Epoch 3/4
# 38/38 [==============================] - 0s 13ms/step - loss: 628.1590 - mae: 0.0254 - batch_ndcg: 0.7869 - val_loss: 499.4375 - val_mae: 0.0052 - val_batch_ndcg: 0.3898
# Epoch 4/4
# 38/38 [==============================] - 1s 14ms/step - loss: 623.2606 - mae: 0.0253 - batch_ndcg: 0.7980 - val_loss: 498.4286 - val_mae: 0.0052 - val_batch_ndcg: 0.3961
# Epoch 1/4
# 38/38 [==============================] - 1s 14ms/step - loss: 677.0073 - mae: 0.0261 - batch_ndcg: 0.6904 - val_loss: 504.9543 - val_mae: 0.0052 - val_batch_ndcg: 0.3763
# Epoch 2/4
# 38/38 [==============================] - 1s 14ms/step - loss: 650.3918 - mae: 0.0261 - batch_ndcg: 0.7779 - val_loss: 500.9011 - val_mae: 0.0052 - val_batch_ndcg: 0.3842
# Epoch 3/4
# 38/38 [==============================] - 1s 13ms/step - loss: 634.9316 - mae: 0.0257 - batch_ndcg: 0.7900 - val_loss: 499.0643 - val_mae: 0.0052 - val_batch_ndcg: 0.3967
# Epoch 4/4
# 38/38 [==============================] - 1s 14ms/step - loss: 627.5848 - mae: 0.0255 - batch_ndcg: 0.7979 - val_loss: 498.7365 - val_mae: 0.0052 - val_batch_ndcg: 0.4029
# Epoch 1/4
# 38/38 [==============================] - 1s 14ms/step - loss: 672.6359 - mae: 0.0259 - batch_ndcg: 0.6921 - val_loss: 505.4945 - val_mae: 0.0052 - val_batch_ndcg: 0.3880
# Epoch 2/4
# 38/38 [==============================] - 0s 13ms/step - loss: 634.9701 - mae: 0.0255 - batch_ndcg: 0.7705 - val_loss: 501.4827 - val_mae: 0.0052 - val_batch_ndcg: 0.3870
# Epoch 3/4
# 38/38 [==============================] - 1s 13ms/step - loss: 637.8559 - mae: 0.0258 - batch_ndcg: 0.7938 - val_loss: 499.4468 - val_mae: 0.0052 - val_batch_ndcg: 0.3899
# Epoch 4/4
# 38/38 [==============================] - 1s 14ms/step - loss: 636.2700 - mae: 0.0258 - batch_ndcg: 0.7992 - val_loss: 498.3697 - val_mae: 0.0052 - val_batch_ndcg: 0.3943
# Epoch 1/4
# 38/38 [==============================] - 1s 14ms/step - loss: 664.0486 - mae: 0.0256 - batch_ndcg: 0.6965 - val_loss: 505.6475 - val_mae: 0.0052 - val_batch_ndcg: 0.3751
# Epoch 2/4
# 38/38 [==============================] - 0s 13ms/step - loss: 640.2367 - mae: 0.0257 - batch_ndcg: 0.7737 - val_loss: 500.8720 - val_mae: 0.0052 - val_batch_ndcg: 0.3902
# Epoch 3/4
# 38/38 [==============================] - 0s 13ms/step - loss: 629.5123 - mae: 0.0255 - batch_ndcg: 0.7879 - val_loss: 499.1966 - val_mae: 0.0052 - val_batch_ndcg: 0.3974
# Epoch 4/4
# 38/38 [==============================] - 1s 13ms/step - loss: 637.4001 - mae: 0.0259 - batch_ndcg: 0.8002 - val_loss: 498.0606 - val_mae: 0.0052 - val_batch_ndcg: 0.3928
# Epoch 1/4
# 38/38 [==============================] - 1s 14ms/step - loss: 679.8633 - mae: 0.0261 - batch_ndcg: 0.6935 - val_loss: 505.1403 - val_mae: 0.0052 - val_batch_ndcg: 0.3838
# Epoch 2/4
# 38/38 [==============================] - 1s 13ms/step - loss: 631.3446 - mae: 0.0254 - batch_ndcg: 0.7742 - val_loss: 501.2741 - val_mae: 0.0052 - val_batch_ndcg: 0.3902
# Epoch 3/4
# 38/38 [==============================] - 1s 14ms/step - loss: 646.5117 - mae: 0.0261 - batch_ndcg: 0.7917 - val_loss: 499.5230 - val_mae: 0.0052 - val_batch_ndcg: 0.3926
# Epoch 4/4
# 38/38 [==============================] - 0s 13ms/step - loss: 662.0115 - mae: 0.0268 - batch_ndcg: 0.8019 - val_loss: 498.1741 - val_mae: 0.0052 - val_batch_ndcg: 0.3963
# Epoch 1/4
# 38/38 [==============================] - 1s 14ms/step - loss: 660.1003 - mae: 0.0255 - batch_ndcg: 0.6971 - val_loss: 505.6232 - val_mae: 0.0052 - val_batch_ndcg: 0.3875
# Epoch 2/4
# 38/38 [==============================] - 1s 14ms/step - loss: 655.6463 - mae: 0.0263 - batch_ndcg: 0.7776 - val_loss: 500.7717 - val_mae: 0.0052 - val_batch_ndcg: 0.3936
# Epoch 3/4
# 38/38 [==============================] - 1s 16ms/step - loss: 635.0905 - mae: 0.0257 - batch_ndcg: 0.7908 - val_loss: 499.4195 - val_mae: 0.0052 - val_batch_ndcg: 0.3928
# Epoch 4/4
# 38/38 [==============================] - 1s 17ms/step - loss: 642.9801 - mae: 0.0261 - batch_ndcg: 0.7993 - val_loss: 497.8814 - val_mae: 0.0052 - val_batch_ndcg: 0.3941
# Epoch 1/4
# 38/38 [==============================] - 1s 14ms/step - loss: 680.8090 - mae: 0.0263 - batch_ndcg: 0.7049 - val_loss: 504.8147 - val_mae: 0.0052 - val_batch_ndcg: 0.3781
# Epoch 2/4
# 38/38 [==============================] - 1s 13ms/step - loss: 630.4989 - mae: 0.0254 - batch_ndcg: 0.7773 - val_loss: 500.6425 - val_mae: 0.0052 - val_batch_ndcg: 0.3921
# Epoch 3/4
# 38/38 [==============================] - 1s 14ms/step - loss: 634.3810 - mae: 0.0256 - batch_ndcg: 0.7875 - val_loss: 499.2148 - val_mae: 0.0052 - val_batch_ndcg: 0.3922
# Epoch 4/4
# 38/38 [==============================] - 0s 13ms/step - loss: 619.6078 - mae: 0.0252 - batch_ndcg: 0.7928 - val_loss: 497.7850 - val_mae: 0.0052 - val_batch_ndcg: 0.3968
# Epoch 1/4
# 38/38 [==============================] - 1s 14ms/step - loss: 670.3666 - mae: 0.0259 - batch_ndcg: 0.6999 - val_loss: 504.3547 - val_mae: 0.0052 - val_batch_ndcg: 0.3862
# Epoch 2/4
# 38/38 [==============================] - 1s 14ms/step - loss: 662.8138 - mae: 0.0266 - batch_ndcg: 0.7841 - val_loss: 500.3381 - val_mae: 0.0052 - val_batch_ndcg: 0.3943
# Epoch 3/4
# 38/38 [==============================] - 1s 13ms/step - loss: 627.3333 - mae: 0.0254 - batch_ndcg: 0.7934 - val_loss: 498.9426 - val_mae: 0.0052 - val_batch_ndcg: 0.3941
# Epoch 4/4
# 38/38 [==============================] - 1s 13ms/step - loss: 641.4381 - mae: 0.0261 - batch_ndcg: 0.7987 - val_loss: 497.1490 - val_mae: 0.0052 - val_batch_ndcg: 0.3945
# Epoch 1/4
# 38/38 [==============================] - 1s 14ms/step - loss: 682.0303 - mae: 0.0263 - batch_ndcg: 0.7037 - val_loss: 503.9013 - val_mae: 0.0052 - val_batch_ndcg: 0.3878
# Epoch 2/4
# 38/38 [==============================] - 1s 13ms/step - loss: 653.9297 - mae: 0.0263 - batch_ndcg: 0.7805 - val_loss: 499.4545 - val_mae: 0.0052 - val_batch_ndcg: 0.3917
# Epoch 3/4
# 38/38 [==============================] - 0s 13ms/step - loss: 642.3527 - mae: 0.0260 - batch_ndcg: 0.7939 - val_loss: 498.3608 - val_mae: 0.0052 - val_batch_ndcg: 0.3908
# Epoch 4/4
# 38/38 [==============================] - 1s 14ms/step - loss: 631.7154 - mae: 0.0257 - batch_ndcg: 0.8022 - val_loss: 497.1170 - val_mae: 0.0052 - val_batch_ndcg: 0.3917
# Epoch 1/4
# 38/38 [==============================] - 1s 14ms/step - loss: 687.0562 - mae: 0.0266 - batch_ndcg: 0.7127 - val_loss: 504.1870 - val_mae: 0.0052 - val_batch_ndcg: 0.3809
# Epoch 2/4
# 38/38 [==============================] - 1s 14ms/step - loss: 649.1437 - mae: 0.0261 - batch_ndcg: 0.7824 - val_loss: 500.5548 - val_mae: 0.0052 - val_batch_ndcg: 0.3963
# Epoch 3/4
# 38/38 [==============================] - 0s 13ms/step - loss: 648.8853 - mae: 0.0262 - batch_ndcg: 0.7953 - val_loss: 498.4040 - val_mae: 0.0052 - val_batch_ndcg: 0.3806
# Epoch 4/4
# 38/38 [==============================] - 0s 13ms/step - loss: 641.3668 - mae: 0.0260 - batch_ndcg: 0.8029 - val_loss: 497.3036 - val_mae: 0.0052 - val_batch_ndcg: 0.3921
# Epoch 1/4
# 38/38 [==============================] - 1s 13ms/step - loss: 679.3392 - mae: 0.0262 - batch_ndcg: 0.7039 - val_loss: 505.0757 - val_mae: 0.0052 - val_batch_ndcg: 0.3847
# Epoch 2/4
# 38/38 [==============================] - 1s 14ms/step - loss: 640.0577 - mae: 0.0258 - batch_ndcg: 0.7803 - val_loss: 500.7174 - val_mae: 0.0052 - val_batch_ndcg: 0.3925
# Epoch 3/4
# 38/38 [==============================] - 1s 13ms/step - loss: 636.1749 - mae: 0.0258 - batch_ndcg: 0.7951 - val_loss: 498.3683 - val_mae: 0.0052 - val_batch_ndcg: 0.3935
# Epoch 4/4
# 38/38 [==============================] - 1s 14ms/step - loss: 645.5323 - mae: 0.0263 - batch_ndcg: 0.8022 - val_loss: 497.8106 - val_mae: 0.0052 - val_batch_ndcg: 0.3946
# Epoch 1/4
# 38/38 [==============================] - 1s 13ms/step - loss: 676.7805 - mae: 0.0261 - batch_ndcg: 0.7077 - val_loss: 504.1951 - val_mae: 0.0052 - val_batch_ndcg: 0.3844
# Epoch 2/4
# 38/38 [==============================] - 1s 13ms/step - loss: 655.0206 - mae: 0.0264 - batch_ndcg: 0.7844 - val_loss: 500.6300 - val_mae: 0.0052 - val_batch_ndcg: 0.3844
# Epoch 3/4
# 38/38 [==============================] - 1s 13ms/step - loss: 629.2983 - mae: 0.0256 - batch_ndcg: 0.7929 - val_loss: 498.0425 - val_mae: 0.0052 - val_batch_ndcg: 0.4020
# Epoch 4/4
# 38/38 [==============================] - 1s 13ms/step - loss: 635.1580 - mae: 0.0259 - batch_ndcg: 0.8010 - val_loss: 497.5749 - val_mae: 0.0052 - val_batch_ndcg: 0.3908
# Epoch 1/4
# 38/38 [==============================] - 1s 15ms/step - loss: 693.0568 - mae: 0.0267 - batch_ndcg: 0.7129 - val_loss: 504.0784 - val_mae: 0.0052 - val_batch_ndcg: 0.3933
# Epoch 2/4
# 38/38 [==============================] - 1s 13ms/step - loss: 648.0549 - mae: 0.0261 - batch_ndcg: 0.7861 - val_loss: 500.0336 - val_mae: 0.0052 - val_batch_ndcg: 0.3958
# Epoch 3/4
# 38/38 [==============================] - 1s 14ms/step - loss: 643.1763 - mae: 0.0261 - batch_ndcg: 0.7970 - val_loss: 498.5388 - val_mae: 0.0052 - val_batch_ndcg: 0.3918
# Epoch 4/4
# 38/38 [==============================] - 1s 14ms/step - loss: 623.3128 - mae: 0.0254 - batch_ndcg: 0.7990 - val_loss: 497.5843 - val_mae: 0.0052 - val_batch_ndcg: 0.3968
# Epoch 1/4
# 38/38 [==============================] - 1s 14ms/step - loss: 685.5626 - mae: 0.0265 - batch_ndcg: 0.7110 - val_loss: 503.6091 - val_mae: 0.0052 - val_batch_ndcg: 0.3856
# Epoch 2/4
# 38/38 [==============================] - 1s 13ms/step - loss: 644.0861 - mae: 0.0260 - batch_ndcg: 0.7831 - val_loss: 499.6548 - val_mae: 0.0052 - val_batch_ndcg: 0.3975
# Epoch 3/4
# 38/38 [==============================] - 1s 13ms/step - loss: 647.9280 - mae: 0.0262 - batch_ndcg: 0.7954 - val_loss: 498.4787 - val_mae: 0.0052 - val_batch_ndcg: 0.3969
# Epoch 4/4
# 38/38 [==============================] - 1s 14ms/step - loss: 649.6089 - mae: 0.0264 - batch_ndcg: 0.8020 - val_loss: 496.8295 - val_mae: 0.0052 - val_batch_ndcg: 0.3983
# Epoch 1/4
# 38/38 [==============================] - 1s 15ms/step - loss: 673.2840 - mae: 0.0261 - batch_ndcg: 0.7158 - val_loss: 504.0464 - val_mae: 0.0052 - val_batch_ndcg: 0.3823
# Epoch 2/4
# 38/38 [==============================] - 0s 13ms/step - loss: 651.3458 - mae: 0.0262 - batch_ndcg: 0.7811 - val_loss: 499.4333 - val_mae: 0.0052 - val_batch_ndcg: 0.3914
# Epoch 3/4
# 38/38 [==============================] - 0s 13ms/step - loss: 644.8815 - mae: 0.0262 - batch_ndcg: 0.7943 - val_loss: 498.2186 - val_mae: 0.0052 - val_batch_ndcg: 0.3930
# Epoch 4/4
# 38/38 [==============================] - 1s 13ms/step - loss: 633.6629 - mae: 0.0258 - batch_ndcg: 0.7998 - val_loss: 496.7768 - val_mae: 0.0052 - val_batch_ndcg: 0.4041
# Epoch 1/4
# 38/38 [==============================] - 1s 14ms/step - loss: 683.1789 - mae: 0.0265 - batch_ndcg: 0.7164 - val_loss: 502.9932 - val_mae: 0.0052 - val_batch_ndcg: 0.3828
# Epoch 2/4
# 38/38 [==============================] - 1s 13ms/step - loss: 652.9868 - mae: 0.0263 - batch_ndcg: 0.7838 - val_loss: 499.6341 - val_mae: 0.0052 - val_batch_ndcg: 0.3927
# Epoch 3/4
# 38/38 [==============================] - 1s 14ms/step - loss: 646.4748 - mae: 0.0262 - batch_ndcg: 0.7917 - val_loss: 498.3360 - val_mae: 0.0052 - val_batch_ndcg: 0.3941
# Epoch 4/4
# 38/38 [==============================] - 1s 13ms/step - loss: 626.0934 - mae: 0.0256 - batch_ndcg: 0.8038 - val_loss: 497.1965 - val_mae: 0.0052 - val_batch_ndcg: 0.3971
# Epoch 1/4
# 38/38 [==============================] - 1s 14ms/step - loss: 679.5749 - mae: 0.0264 - batch_ndcg: 0.7144 - val_loss: 503.3862 - val_mae: 0.0052 - val_batch_ndcg: 0.3902
# Epoch 2/4
# 38/38 [==============================] - 0s 13ms/step - loss: 643.3498 - mae: 0.0260 - batch_ndcg: 0.7808 - val_loss: 500.1256 - val_mae: 0.0052 - val_batch_ndcg: 0.3935
# Epoch 3/4
# 38/38 [==============================] - 0s 13ms/step - loss: 634.2922 - mae: 0.0258 - batch_ndcg: 0.7979 - val_loss: 498.0041 - val_mae: 0.0052 - val_batch_ndcg: 0.3950
# Epoch 4/4
# 38/38 [==============================] - 1s 14ms/step - loss: 641.4803 - mae: 0.0261 - batch_ndcg: 0.8013 - val_loss: 497.0211 - val_mae: 0.0052 - val_batch_ndcg: 0.3969
# Epoch 1/4
# 38/38 [==============================] - 1s 13ms/step - loss: 665.9156 - mae: 0.0258 - batch_ndcg: 0.7145 - val_loss: 503.5716 - val_mae: 0.0052 - val_batch_ndcg: 0.3876
# Epoch 2/4
# 38/38 [==============================] - 1s 14ms/step - loss: 622.1472 - mae: 0.0251 - batch_ndcg: 0.7821 - val_loss: 499.8280 - val_mae: 0.0052 - val_batch_ndcg: 0.3939
# Epoch 3/4
# 38/38 [==============================] - 0s 13ms/step - loss: 640.6160 - mae: 0.0260 - batch_ndcg: 0.7972 - val_loss: 498.5118 - val_mae: 0.0052 - val_batch_ndcg: 0.3895
# Epoch 4/4
# 38/38 [==============================] - 1s 13ms/step - loss: 636.6329 - mae: 0.0259 - batch_ndcg: 0.8004 - val_loss: 497.3724 - val_mae: 0.0052 - val_batch_ndcg: 0.4024
# Epoch 1/4
# 38/38 [==============================] - 1s 14ms/step - loss: 673.2228 - mae: 0.0260 - batch_ndcg: 0.7159 - val_loss: 503.8399 - val_mae: 0.0052 - val_batch_ndcg: 0.3859
# Epoch 2/4
# 38/38 [==============================] - 1s 15ms/step - loss: 657.5477 - mae: 0.0265 - batch_ndcg: 0.7849 - val_loss: 500.2318 - val_mae: 0.0052 - val_batch_ndcg: 0.3893
# Epoch 3/4
# 38/38 [==============================] - 1s 13ms/step - loss: 634.0454 - mae: 0.0257 - batch_ndcg: 0.7939 - val_loss: 497.9102 - val_mae: 0.0052 - val_batch_ndcg: 0.3918
# Epoch 4/4
# 38/38 [==============================] - 1s 14ms/step - loss: 640.3084 - mae: 0.0261 - batch_ndcg: 0.8068 - val_loss: 497.0487 - val_mae: 0.0052 - val_batch_ndcg: 0.3948
# Epoch 1/4
# 38/38 [==============================] - 1s 15ms/step - loss: 680.3600 - mae: 0.0264 - batch_ndcg: 0.7168 - val_loss: 503.3010 - val_mae: 0.0052 - val_batch_ndcg: 0.3882
# Epoch 2/4
# 38/38 [==============================] - 1s 15ms/step - loss: 661.6871 - mae: 0.0267 - batch_ndcg: 0.7881 - val_loss: 499.1267 - val_mae: 0.0052 - val_batch_ndcg: 0.3940
# Epoch 3/4
# 38/38 [==============================] - 1s 14ms/step - loss: 640.3390 - mae: 0.0260 - batch_ndcg: 0.7973 - val_loss: 497.9315 - val_mae: 0.0052 - val_batch_ndcg: 0.3947
# Epoch 4/4
# 38/38 [==============================] - 1s 14ms/step - loss: 628.2827 - mae: 0.0257 - batch_ndcg: 0.8034 - val_loss: 496.5528 - val_mae: 0.0052 - val_batch_ndcg: 0.3959
# Epoch 1/4
# 38/38 [==============================] - 1s 15ms/step - loss: 664.0204 - mae: 0.0257 - batch_ndcg: 0.7179 - val_loss: 503.0115 - val_mae: 0.0052 - val_batch_ndcg: 0.3965
# Epoch 2/4
# 38/38 [==============================] - 1s 14ms/step - loss: 632.8229 - mae: 0.0256 - batch_ndcg: 0.7787 - val_loss: 499.4607 - val_mae: 0.0052 - val_batch_ndcg: 0.3948
# Epoch 3/4
# 38/38 [==============================] - 0s 13ms/step - loss: 633.9105 - mae: 0.0258 - batch_ndcg: 0.7975 - val_loss: 497.9639 - val_mae: 0.0052 - val_batch_ndcg: 0.4006
# Epoch 4/4
# 38/38 [==============================] - 0s 13ms/step - loss: 654.5708 - mae: 0.0266 - batch_ndcg: 0.8059 - val_loss: 496.5463 - val_mae: 0.0052 - val_batch_ndcg: 0.3995
# Epoch 1/4
# 38/38 [==============================] - 1s 14ms/step - loss: 685.1013 - mae: 0.0263 - batch_ndcg: 0.7158 - val_loss: 505.1152 - val_mae: 0.0052 - val_batch_ndcg: 0.3886
# Epoch 2/4
# 38/38 [==============================] - 1s 14ms/step - loss: 660.2484 - mae: 0.0266 - batch_ndcg: 0.7859 - val_loss: 500.4078 - val_mae: 0.0052 - val_batch_ndcg: 0.3913
# Epoch 3/4
# 38/38 [==============================] - 1s 14ms/step - loss: 643.8162 - mae: 0.0261 - batch_ndcg: 0.7952 - val_loss: 498.3908 - val_mae: 0.0052 - val_batch_ndcg: 0.3991
# Epoch 4/4
# 38/38 [==============================] - 1s 13ms/step - loss: 645.1704 - mae: 0.0262 - batch_ndcg: 0.7977 - val_loss: 496.8248 - val_mae: 0.0052 - val_batch_ndcg: 0.4030
# Epoch 1/4
# 38/38 [==============================] - 1s 14ms/step - loss: 671.8560 - mae: 0.0260 - batch_ndcg: 0.7201 - val_loss: 503.3655 - val_mae: 0.0052 - val_batch_ndcg: 0.3959
# Epoch 2/4
# 38/38 [==============================] - 1s 14ms/step - loss: 620.8139 - mae: 0.0251 - batch_ndcg: 0.7801 - val_loss: 499.1781 - val_mae: 0.0052 - val_batch_ndcg: 0.3922
# Epoch 3/4
# 38/38 [==============================] - 1s 13ms/step - loss: 651.2362 - mae: 0.0264 - batch_ndcg: 0.7970 - val_loss: 498.0622 - val_mae: 0.0052 - val_batch_ndcg: 0.3936
# Epoch 4/4
# 38/38 [==============================] - 1s 13ms/step - loss: 624.7758 - mae: 0.0255 - batch_ndcg: 0.8023 - val_loss: 496.6486 - val_mae: 0.0052 - val_batch_ndcg: 0.4032
# Epoch 1/4
# 38/38 [==============================] - 1s 14ms/step - loss: 661.0276 - mae: 0.0256 - batch_ndcg: 0.7134 - val_loss: 503.5459 - val_mae: 0.0052 - val_batch_ndcg: 0.3865
# Epoch 2/4
# 38/38 [==============================] - 1s 14ms/step - loss: 658.8881 - mae: 0.0266 - batch_ndcg: 0.7829 - val_loss: 499.7136 - val_mae: 0.0052 - val_batch_ndcg: 0.3888
# Epoch 3/4
# 38/38 [==============================] - 0s 13ms/step - loss: 657.6113 - mae: 0.0266 - batch_ndcg: 0.7991 - val_loss: 497.7820 - val_mae: 0.0052 - val_batch_ndcg: 0.3942
# Epoch 4/4
# 38/38 [==============================] - 1s 13ms/step - loss: 631.0703 - mae: 0.0257 - batch_ndcg: 0.8002 - val_loss: 496.5176 - val_mae: 0.0052 - val_batch_ndcg: 0.3959
# Epoch 1/4
# 38/38 [==============================] - 1s 14ms/step - loss: 672.4352 - mae: 0.0261 - batch_ndcg: 0.7207 - val_loss: 502.9439 - val_mae: 0.0052 - val_batch_ndcg: 0.3874
# Epoch 2/4
# 38/38 [==============================] - 1s 14ms/step - loss: 645.5001 - mae: 0.0260 - batch_ndcg: 0.7761 - val_loss: 499.0833 - val_mae: 0.0052 - val_batch_ndcg: 0.3896
# Epoch 3/4
# 38/38 [==============================] - 1s 14ms/step - loss: 626.4630 - mae: 0.0255 - batch_ndcg: 0.7960 - val_loss: 497.3306 - val_mae: 0.0052 - val_batch_ndcg: 0.3996
# Epoch 4/4
# 38/38 [==============================] - 0s 13ms/step - loss: 627.7186 - mae: 0.0256 - batch_ndcg: 0.8046 - val_loss: 496.4432 - val_mae: 0.0052 - val_batch_ndcg: 0.3966
# Epoch 1/4
# 38/38 [==============================] - 1s 14ms/step - loss: 667.0410 - mae: 0.0258 - batch_ndcg: 0.7145 - val_loss: 503.6054 - val_mae: 0.0052 - val_batch_ndcg: 0.3872
# Epoch 2/4
# 38/38 [==============================] - 1s 14ms/step - loss: 626.1141 - mae: 0.0253 - batch_ndcg: 0.7790 - val_loss: 499.8586 - val_mae: 0.0052 - val_batch_ndcg: 0.3935
# Epoch 3/4
# 38/38 [==============================] - 1s 14ms/step - loss: 657.4774 - mae: 0.0267 - batch_ndcg: 0.7988 - val_loss: 497.9546 - val_mae: 0.0052 - val_batch_ndcg: 0.3936
# Epoch 4/4
# 38/38 [==============================] - 1s 13ms/step - loss: 628.5275 - mae: 0.0257 - batch_ndcg: 0.8017 - val_loss: 496.5498 - val_mae: 0.0052 - val_batch_ndcg: 0.3945
# Epoch 1/4
# 38/38 [==============================] - 1s 13ms/step - loss: 658.4969 - mae: 0.0256 - batch_ndcg: 0.7202 - val_loss: 503.2956 - val_mae: 0.0052 - val_batch_ndcg: 0.3872
# Epoch 2/4
# 38/38 [==============================] - 1s 14ms/step - loss: 631.7056 - mae: 0.0255 - batch_ndcg: 0.7798 - val_loss: 499.7159 - val_mae: 0.0052 - val_batch_ndcg: 0.3861
# Epoch 3/4
# 38/38 [==============================] - 1s 14ms/step - loss: 635.2670 - mae: 0.0259 - batch_ndcg: 0.7954 - val_loss: 497.4368 - val_mae: 0.0052 - val_batch_ndcg: 0.3895
# Epoch 4/4
# 38/38 [==============================] - 1s 14ms/step - loss: 624.3889 - mae: 0.0256 - batch_ndcg: 0.8027 - val_loss: 496.2299 - val_mae: 0.0052 - val_batch_ndcg: 0.3924
# Epoch 1/4
# 38/38 [==============================] - 1s 15ms/step - loss: 670.3698 - mae: 0.0260 - batch_ndcg: 0.7156 - val_loss: 503.1251 - val_mae: 0.0052 - val_batch_ndcg: 0.3904
# Epoch 2/4
# 38/38 [==============================] - 1s 14ms/step - loss: 626.2180 - mae: 0.0254 - batch_ndcg: 0.7801 - val_loss: 499.2596 - val_mae: 0.0052 - val_batch_ndcg: 0.3916
# Epoch 3/4
# 38/38 [==============================] - 1s 14ms/step - loss: 661.0637 - mae: 0.0269 - batch_ndcg: 0.8004 - val_loss: 497.2066 - val_mae: 0.0052 - val_batch_ndcg: 0.3967
# Epoch 4/4
# 38/38 [==============================] - 1s 14ms/step - loss: 637.6640 - mae: 0.0260 - batch_ndcg: 0.8016 - val_loss: 496.3873 - val_mae: 0.0052 - val_batch_ndcg: 0.3943
# Epoch 1/4
# 38/38 [==============================] - 1s 14ms/step - loss: 674.0858 - mae: 0.0262 - batch_ndcg: 0.7210 - val_loss: 503.4980 - val_mae: 0.0052 - val_batch_ndcg: 0.3940
# Epoch 2/4
# 38/38 [==============================] - 1s 14ms/step - loss: 632.2426 - mae: 0.0256 - batch_ndcg: 0.7791 - val_loss: 499.1641 - val_mae: 0.0052 - val_batch_ndcg: 0.3900
# Epoch 3/4
# 38/38 [==============================] - 1s 14ms/step - loss: 625.6991 - mae: 0.0255 - batch_ndcg: 0.7962 - val_loss: 497.5409 - val_mae: 0.0052 - val_batch_ndcg: 0.3936
# Epoch 4/4
# 38/38 [==============================] - 1s 14ms/step - loss: 636.3680 - mae: 0.0260 - batch_ndcg: 0.8041 - val_loss: 496.2019 - val_mae: 0.0052 - val_batch_ndcg: 0.3943
# Epoch 1/4
# 38/38 [==============================] - 1s 14ms/step - loss: 661.4673 - mae: 0.0257 - batch_ndcg: 0.7216 - val_loss: 503.2677 - val_mae: 0.0052 - val_batch_ndcg: 0.3853
# Epoch 2/4
# 38/38 [==============================] - 1s 14ms/step - loss: 640.3132 - mae: 0.0259 - batch_ndcg: 0.7815 - val_loss: 499.0915 - val_mae: 0.0052 - val_batch_ndcg: 0.3901
# Epoch 3/4
# 38/38 [==============================] - 1s 14ms/step - loss: 637.7974 - mae: 0.0259 - batch_ndcg: 0.7940 - val_loss: 497.4145 - val_mae: 0.0052 - val_batch_ndcg: 0.3902
# Epoch 4/4
# 38/38 [==============================] - 1s 14ms/step - loss: 633.1014 - mae: 0.0259 - batch_ndcg: 0.8059 - val_loss: 496.3277 - val_mae: 0.0052 - val_batch_ndcg: 0.3973
# Epoch 1/4
# 38/38 [==============================] - 1s 15ms/step - loss: 685.7927 - mae: 0.0266 - batch_ndcg: 0.7212 - val_loss: 502.8072 - val_mae: 0.0052 - val_batch_ndcg: 0.3935
# Epoch 2/4
# 38/38 [==============================] - 1s 14ms/step - loss: 650.0083 - mae: 0.0263 - batch_ndcg: 0.7832 - val_loss: 499.0492 - val_mae: 0.0052 - val_batch_ndcg: 0.3948
# Epoch 3/4
# 38/38 [==============================] - 1s 14ms/step - loss: 622.3079 - mae: 0.0254 - batch_ndcg: 0.7927 - val_loss: 497.8464 - val_mae: 0.0052 - val_batch_ndcg: 0.3979
# Epoch 4/4
# 38/38 [==============================] - 1s 14ms/step - loss: 632.6226 - mae: 0.0259 - batch_ndcg: 0.8034 - val_loss: 496.4544 - val_mae: 0.0052 - val_batch_ndcg: 0.3982
# Epoch 1/4
# 38/38 [==============================] - 1s 14ms/step - loss: 672.4291 - mae: 0.0261 - batch_ndcg: 0.7192 - val_loss: 503.6234 - val_mae: 0.0052 - val_batch_ndcg: 0.3905
# Epoch 2/4
# 38/38 [==============================] - 1s 14ms/step - loss: 630.9363 - mae: 0.0255 - batch_ndcg: 0.7821 - val_loss: 499.6483 - val_mae: 0.0052 - val_batch_ndcg: 0.3971
# Epoch 3/4
# 38/38 [==============================] - 1s 14ms/step - loss: 614.8133 - mae: 0.0251 - batch_ndcg: 0.7956 - val_loss: 497.5282 - val_mae: 0.0052 - val_batch_ndcg: 0.3963
# Epoch 4/4
# 38/38 [==============================] - 1s 14ms/step - loss: 629.9545 - mae: 0.0258 - batch_ndcg: 0.8036 - val_loss: 496.4574 - val_mae: 0.0052 - val_batch_ndcg: 0.3958
# Epoch 1/4
# 38/38 [==============================] - 1s 15ms/step - loss: 678.8929 - mae: 0.0264 - batch_ndcg: 0.7253 - val_loss: 502.9913 - val_mae: 0.0052 - val_batch_ndcg: 0.3894
# Epoch 2/4
# 38/38 [==============================] - 1s 14ms/step - loss: 650.6217 - mae: 0.0263 - batch_ndcg: 0.7844 - val_loss: 499.1822 - val_mae: 0.0052 - val_batch_ndcg: 0.3916
# Epoch 3/4
# 38/38 [==============================] - 1s 14ms/step - loss: 640.9954 - mae: 0.0261 - batch_ndcg: 0.7951 - val_loss: 497.3822 - val_mae: 0.0052 - val_batch_ndcg: 0.3966
# Epoch 4/4
# 38/38 [==============================] - 1s 14ms/step - loss: 619.7102 - mae: 0.0254 - batch_ndcg: 0.8014 - val_loss: 496.1452 - val_mae: 0.0052 - val_batch_ndcg: 0.3973
# Epoch 1/4
# 38/38 [==============================] - 1s 14ms/step - loss: 668.8508 - mae: 0.0260 - batch_ndcg: 0.7240 - val_loss: 502.9733 - val_mae: 0.0052 - val_batch_ndcg: 0.3873
# Epoch 2/4
# 38/38 [==============================] - 1s 14ms/step - loss: 642.5624 - mae: 0.0260 - batch_ndcg: 0.7817 - val_loss: 498.8486 - val_mae: 0.0052 - val_batch_ndcg: 0.4031
# Epoch 3/4
# 38/38 [==============================] - 0s 13ms/step - loss: 628.0380 - mae: 0.0256 - batch_ndcg: 0.7988 - val_loss: 497.1476 - val_mae: 0.0052 - val_batch_ndcg: 0.3948
# Epoch 4/4
# 38/38 [==============================] - 1s 14ms/step - loss: 625.2812 - mae: 0.0256 - batch_ndcg: 0.8051 - val_loss: 496.0079 - val_mae: 0.0052 - val_batch_ndcg: 0.4010
# Epoch 1/4
# 38/38 [==============================] - 1s 15ms/step - loss: 679.8533 - mae: 0.0264 - batch_ndcg: 0.7236 - val_loss: 502.7199 - val_mae: 0.0052 - val_batch_ndcg: 0.3921
# Epoch 2/4
# 38/38 [==============================] - 1s 14ms/step - loss: 621.0085 - mae: 0.0252 - batch_ndcg: 0.7828 - val_loss: 498.7096 - val_mae: 0.0052 - val_batch_ndcg: 0.3884
# Epoch 3/4
# 38/38 [==============================] - 1s 14ms/step - loss: 651.4968 - mae: 0.0265 - batch_ndcg: 0.8014 - val_loss: 497.3366 - val_mae: 0.0052 - val_batch_ndcg: 0.3938
# Epoch 4/4
# 38/38 [==============================] - 1s 14ms/step - loss: 616.5438 - mae: 0.0252 - batch_ndcg: 0.7979 - val_loss: 495.5031 - val_mae: 0.0052 - val_batch_ndcg: 0.3951
# Epoch 1/4
# 38/38 [==============================] - 1s 14ms/step - loss: 668.1815 - mae: 0.0260 - batch_ndcg: 0.7243 - val_loss: 502.6990 - val_mae: 0.0052 - val_batch_ndcg: 0.3841
# Epoch 2/4
# 38/38 [==============================] - 1s 14ms/step - loss: 639.4081 - mae: 0.0259 - batch_ndcg: 0.7842 - val_loss: 498.5677 - val_mae: 0.0052 - val_batch_ndcg: 0.3951
# Epoch 3/4
# 38/38 [==============================] - 1s 14ms/step - loss: 642.4429 - mae: 0.0262 - batch_ndcg: 0.7985 - val_loss: 496.8780 - val_mae: 0.0052 - val_batch_ndcg: 0.3937
# Epoch 4/4
# 38/38 [==============================] - 1s 14ms/step - loss: 632.4660 - mae: 0.0259 - batch_ndcg: 0.8049 - val_loss: 495.7841 - val_mae: 0.0052 - val_batch_ndcg: 0.3930
# Epoch 1/4
# 38/38 [==============================] - 1s 15ms/step - loss: 654.5114 - mae: 0.0255 - batch_ndcg: 0.7209 - val_loss: 502.8822 - val_mae: 0.0052 - val_batch_ndcg: 0.3926
# Epoch 2/4
# 38/38 [==============================] - 1s 14ms/step - loss: 660.1040 - mae: 0.0267 - batch_ndcg: 0.7850 - val_loss: 498.3366 - val_mae: 0.0052 - val_batch_ndcg: 0.3947
# Epoch 3/4
# 38/38 [==============================] - 1s 14ms/step - loss: 639.1438 - mae: 0.0261 - batch_ndcg: 0.8020 - val_loss: 497.3392 - val_mae: 0.0052 - val_batch_ndcg: 0.3921
# Epoch 4/4
# 38/38 [==============================] - 1s 14ms/step - loss: 642.8215 - mae: 0.0263 - batch_ndcg: 0.8088 - val_loss: 496.0392 - val_mae: 0.0052 - val_batch_ndcg: 0.3901
# Epoch 1/4
# 38/38 [==============================] - 1s 14ms/step - loss: 669.0744 - mae: 0.0260 - batch_ndcg: 0.7150 - val_loss: 502.5291 - val_mae: 0.0052 - val_batch_ndcg: 0.3891
# Epoch 2/4
# 38/38 [==============================] - 1s 14ms/step - loss: 641.4889 - mae: 0.0260 - batch_ndcg: 0.7814 - val_loss: 498.7014 - val_mae: 0.0052 - val_batch_ndcg: 0.3910
# Epoch 3/4
# 38/38 [==============================] - 1s 14ms/step - loss: 635.6918 - mae: 0.0259 - batch_ndcg: 0.7918 - val_loss: 496.3343 - val_mae: 0.0052 - val_batch_ndcg: 0.3974
# Epoch 4/4
# 38/38 [==============================] - 1s 14ms/step - loss: 638.5784 - mae: 0.0262 - batch_ndcg: 0.8095 - val_loss: 495.9691 - val_mae: 0.0052 - val_batch_ndcg: 0.3952
# Epoch 1/4
# 38/38 [==============================] - 1s 14ms/step - loss: 672.8993 - mae: 0.0262 - batch_ndcg: 0.7257 - val_loss: 502.7060 - val_mae: 0.0052 - val_batch_ndcg: 0.3839
# Epoch 2/4
# 38/38 [==============================] - 1s 15ms/step - loss: 646.7512 - mae: 0.0262 - batch_ndcg: 0.7865 - val_loss: 499.0369 - val_mae: 0.0052 - val_batch_ndcg: 0.3913
# Epoch 3/4
# 38/38 [==============================] - 1s 14ms/step - loss: 642.6157 - mae: 0.0262 - batch_ndcg: 0.8017 - val_loss: 496.9746 - val_mae: 0.0052 - val_batch_ndcg: 0.3937
# Epoch 4/4
# 38/38 [==============================] - 1s 14ms/step - loss: 611.2192 - mae: 0.0251 - batch_ndcg: 0.8004 - val_loss: 495.6754 - val_mae: 0.0052 - val_batch_ndcg: 0.3935
# Epoch 1/4
# 38/38 [==============================] - 1s 15ms/step - loss: 662.7547 - mae: 0.0258 - batch_ndcg: 0.7221 - val_loss: 502.7794 - val_mae: 0.0052 - val_batch_ndcg: 0.3962
# Epoch 2/4
# 38/38 [==============================] - 1s 15ms/step - loss: 649.2720 - mae: 0.0263 - batch_ndcg: 0.7855 - val_loss: 499.2255 - val_mae: 0.0052 - val_batch_ndcg: 0.3943
# Epoch 3/4
# 38/38 [==============================] - 1s 14ms/step - loss: 640.1512 - mae: 0.0261 - batch_ndcg: 0.8009 - val_loss: 497.3734 - val_mae: 0.0052 - val_batch_ndcg: 0.3936
# Epoch 4/4
# 38/38 [==============================] - 1s 15ms/step - loss: 634.7301 - mae: 0.0260 - batch_ndcg: 0.8077 - val_loss: 495.5772 - val_mae: 0.0052 - val_batch_ndcg: 0.3905
# Epoch 1/4
# 38/38 [==============================] - 1s 15ms/step - loss: 661.0129 - mae: 0.0257 - batch_ndcg: 0.7198 - val_loss: 502.5195 - val_mae: 0.0052 - val_batch_ndcg: 0.3819
# Epoch 2/4
# 38/38 [==============================] - 1s 18ms/step - loss: 638.9373 - mae: 0.0259 - batch_ndcg: 0.7872 - val_loss: 498.5999 - val_mae: 0.0052 - val_batch_ndcg: 0.3966
# Epoch 3/4
# ...
# Epoch 1/4
# 38/38 [==============================] - 1s 15ms/step - loss: 668.8683 - mae: 0.0260 - batch_ndcg: 0.7214 - val_loss: 502.7453 - val_mae: 0.0052 - val_batch_ndcg: 0.3945
# Epoch 2/4
# 38/38 [==============================] - 1s 14ms/step - loss: 652.5715 - mae: 0.0265 - batch_ndcg: 0.7909 - val_loss: 498.6068 - val_mae: 0.0052 - val_batch_ndcg: 0.3893
# Epoch 3/4
# 38/38 [==============================] - 1s 15ms/step - loss: 642.4816 - mae: 0.0262 - batch_ndcg: 0.7953 - val_loss: 496.7367 - val_mae: 0.0052 - val_batch_ndcg: 0.3950
# Epoch 4/4
# 38/38 [==============================] - 1s 14ms/step - loss: 620.8241 - mae: 0.0255 - batch_ndcg: 0.8086 - val_loss: 495.9286 - val_mae: 0.0052 - val_batch_ndcg: 0.3968
# Epoch 1/4
# 38/38 [==============================] - 1s 14ms/step - loss: 643.6164 - mae: 0.0251 - batch_ndcg: 0.7176 - val_loss: 502.7452 - val_mae: 0.0052 - val_batch_ndcg: 0.3843
# Epoch 2/4
# 38/38 [==============================] - 1s 15ms/step - loss: 648.5482 - mae: 0.0262 - batch_ndcg: 0.7885 - val_loss: 498.5214 - val_mae: 0.0052 - val_batch_ndcg: 0.3899
# Epoch 3/4
# 38/38 [==============================] - 1s 14ms/step - loss: 629.8685 - mae: 0.0258 - batch_ndcg: 0.7985 - val_loss: 496.9583 - val_mae: 0.0052 - val_batch_ndcg: 0.3955
# Epoch 4/4
# 38/38 [==============================] - 1s 14ms/step - loss: 629.6926 - mae: 0.0259 - batch_ndcg: 0.8088 - val_loss: 495.6277 - val_mae: 0.0052 - val_batch_ndcg: 0.3927
# Epoch 1/4
# 38/38 [==============================] - 1s 15ms/step - loss: 664.2402 - mae: 0.0259 - batch_ndcg: 0.7223 - val_loss: 502.8721 - val_mae: 0.0052 - val_batch_ndcg: 0.3817
# Epoch 2/4
# 38/38 [==============================] - 1s 18ms/step - loss: 625.9588 - mae: 0.0254 - batch_ndcg: 0.7841 - val_loss: 498.1577 - val_mae: 0.0052 - val_batch_ndcg: 0.3930
# Epoch 3/4
# 38/38 [==============================] - 1s 14ms/step - loss: 627.4974 - mae: 0.0257 - batch_ndcg: 0.8020 - val_loss: 496.4681 - val_mae: 0.0052 - val_batch_ndcg: 0.3980
# Epoch 4/4
# 38/38 [==============================] - 1s 14ms/step - loss: 598.2035 - mae: 0.0247 - batch_ndcg: 0.8055 - val_loss: 495.8588 - val_mae: 0.0052 - val_batch_ndcg: 0.3957
# Epoch 1/4
# 38/38 [==============================] - 1s 15ms/step - loss: 663.1092 - mae: 0.0259 - batch_ndcg: 0.7220 - val_loss: 502.1549 - val_mae: 0.0052 - val_batch_ndcg: 0.3875
# Epoch 2/4
# 38/38 [==============================] - 1s 14ms/step - loss: 649.0004 - mae: 0.0263 - batch_ndcg: 0.7885 - val_loss: 498.5623 - val_mae: 0.0052 - val_batch_ndcg: 0.3969
# Epoch 3/4
# 38/38 [==============================] - 1s 14ms/step - loss: 640.7552 - mae: 0.0262 - batch_ndcg: 0.8019 - val_loss: 496.5331 - val_mae: 0.0052 - val_batch_ndcg: 0.3953
# Epoch 4/4
# 38/38 [==============================] - 1s 15ms/step - loss: 624.2959 - mae: 0.0257 - batch_ndcg: 0.8081 - val_loss: 495.2847 - val_mae: 0.0052 - val_batch_ndcg: 0.3983
# Epoch 1/4
# 38/38 [==============================] - 1s 17ms/step - loss: 669.1776 - mae: 0.0261 - batch_ndcg: 0.7223 - val_loss: 502.5645 - val_mae: 0.0052 - val_batch_ndcg: 0.3873
# Epoch 2/4
# 38/38 [==============================] - 1s 14ms/step - loss: 628.0066 - mae: 0.0255 - batch_ndcg: 0.7873 - val_loss: 498.2226 - val_mae: 0.0052 - val_batch_ndcg: 0.3937
# Epoch 3/4
# 38/38 [==============================] - 1s 14ms/step - loss: 639.4019 - mae: 0.0261 - batch_ndcg: 0.8002 - val_loss: 496.6125 - val_mae: 0.0052 - val_batch_ndcg: 0.3927
# Epoch 4/4
# 38/38 [==============================] - 1s 15ms/step - loss: 632.3582 - mae: 0.0259 - batch_ndcg: 0.8096 - val_loss: 495.6447 - val_mae: 0.0052 - val_batch_ndcg: 0.3957
# Epoch 1/4
# 38/38 [==============================] - 1s 16ms/step - loss: 673.1619 - mae: 0.0263 - batch_ndcg: 0.7174 - val_loss: 502.8858 - val_mae: 0.0052 - val_batch_ndcg: 0.3920
# Epoch 2/4
# 38/38 [==============================] - 1s 14ms/step - loss: 627.5366 - mae: 0.0255 - batch_ndcg: 0.7864 - val_loss: 498.2293 - val_mae: 0.0052 - val_batch_ndcg: 0.3945
# Epoch 3/4
# 38/38 [==============================] - 1s 14ms/step - loss: 632.0300 - mae: 0.0259 - batch_ndcg: 0.8004 - val_loss: 497.1541 - val_mae: 0.0052 - val_batch_ndcg: 0.3913
# Epoch 4/4
# 38/38 [==============================] - 1s 14ms/step - loss: 635.8331 - mae: 0.0261 - batch_ndcg: 0.8103 - val_loss: 495.6947 - val_mae: 0.0052 - val_batch_ndcg: 0.3887
# Epoch 1/4
# 38/38 [==============================] - 1s 15ms/step - loss: 663.7435 - mae: 0.0259 - batch_ndcg: 0.7204 - val_loss: 502.8430 - val_mae: 0.0052 - val_batch_ndcg: 0.3902
# Epoch 2/4
# 38/38 [==============================] - 1s 14ms/step - loss: 639.5518 - mae: 0.0259 - batch_ndcg: 0.7858 - val_loss: 497.7540 - val_mae: 0.0052 - val_batch_ndcg: 0.3994
# Epoch 3/4
# 38/38 [==============================] - 1s 15ms/step - loss: 627.1171 - mae: 0.0257 - batch_ndcg: 0.7998 - val_loss: 497.2808 - val_mae: 0.0052 - val_batch_ndcg: 0.3890
# Epoch 4/4
# 38/38 [==============================] - 1s 14ms/step - loss: 639.6414 - mae: 0.0263 - batch_ndcg: 0.8107 - val_loss: 495.5364 - val_mae: 0.0052 - val_batch_ndcg: 0.3997
# Epoch 1/4
# 38/38 [==============================] - 1s 17ms/step - loss: 677.0617 - mae: 0.0263 - batch_ndcg: 0.7202 - val_loss: 502.3666 - val_mae: 0.0052 - val_batch_ndcg: 0.3829
# Epoch 2/4
# 38/38 [==============================] - 1s 14ms/step - loss: 612.3036 - mae: 0.0249 - batch_ndcg: 0.7789 - val_loss: 498.3859 - val_mae: 0.0052 - val_batch_ndcg: 0.3940
# Epoch 3/4
# 38/38 [==============================] - 1s 15ms/step - loss: 620.9744 - mae: 0.0254 - batch_ndcg: 0.8002 - val_loss: 496.0343 - val_mae: 0.0052 - val_batch_ndcg: 0.3908
# Epoch 4/4
# 38/38 [==============================] - 1s 15ms/step - loss: 612.7474 - mae: 0.0252 - batch_ndcg: 0.8056 - val_loss: 495.7220 - val_mae: 0.0052 - val_batch_ndcg: 0.3889
# Epoch 1/4
# 38/38 [==============================] - 1s 16ms/step - loss: 670.0486 - mae: 0.0261 - batch_ndcg: 0.7255 - val_loss: 502.6631 - val_mae: 0.0052 - val_batch_ndcg: 0.3859
# Epoch 2/4
# 38/38 [==============================] - 1s 14ms/step - loss: 629.6927 - mae: 0.0256 - batch_ndcg: 0.7853 - val_loss: 498.5143 - val_mae: 0.0052 - val_batch_ndcg: 0.3949
# Epoch 3/4
# 38/38 [==============================] - 1s 14ms/step - loss: 634.8931 - mae: 0.0260 - batch_ndcg: 0.8011 - val_loss: 496.8117 - val_mae: 0.0052 - val_batch_ndcg: 0.3924
# Epoch 4/4
# 38/38 [==============================] - 1s 15ms/step - loss: 631.4122 - mae: 0.0260 - batch_ndcg: 0.8120 - val_loss: 495.5331 - val_mae: 0.0052 - val_batch_ndcg: 0.3929
# Epoch 1/4
# 38/38 [==============================] - 1s 16ms/step - loss: 686.4882 - mae: 0.0268 - batch_ndcg: 0.7263 - val_loss: 502.6800 - val_mae: 0.0052 - val_batch_ndcg: 0.3867
# Epoch 2/4
# 38/38 [==============================] - 1s 15ms/step - loss: 644.7535 - mae: 0.0261 - batch_ndcg: 0.7850 - val_loss: 497.9954 - val_mae: 0.0052 - val_batch_ndcg: 0.3921
# Epoch 3/4
# 38/38 [==============================] - 1s 15ms/step - loss: 632.4362 - mae: 0.0259 - batch_ndcg: 0.8031 - val_loss: 496.4214 - val_mae: 0.0052 - val_batch_ndcg: 0.3840
# Epoch 4/4
# 38/38 [==============================] - 1s 15ms/step - loss: 621.2801 - mae: 0.0256 - batch_ndcg: 0.8076 - val_loss: 495.7144 - val_mae: 0.0052 - val_batch_ndcg: 0.3968
# Epoch 1/4
# 38/38 [==============================] - 1s 15ms/step - loss: 657.5242 - mae: 0.0256 - batch_ndcg: 0.7231 - val_loss: 502.9481 - val_mae: 0.0052 - val_batch_ndcg: 0.3911
# Epoch 2/4
# 38/38 [==============================] - 1s 15ms/step - loss: 642.3729 - mae: 0.0261 - batch_ndcg: 0.7891 - val_loss: 498.4871 - val_mae: 0.0052 - val_batch_ndcg: 0.3978
# Epoch 3/4
# 38/38 [==============================] - 1s 14ms/step - loss: 641.0002 - mae: 0.0262 - batch_ndcg: 0.8029 - val_loss: 496.5392 - val_mae: 0.0052 - val_batch_ndcg: 0.3936
# Epoch 4/4
# 38/38 [==============================] - 1s 15ms/step - loss: 619.0119 - mae: 0.0255 - batch_ndcg: 0.8092 - val_loss: 495.4174 - val_mae: 0.0052 - val_batch_ndcg: 0.3952
# Epoch 1/4
# 38/38 [==============================] - 1s 16ms/step - loss: 672.8207 - mae: 0.0262 - batch_ndcg: 0.7227 - val_loss: 502.9715 - val_mae: 0.0052 - val_batch_ndcg: 0.3863
# Epoch 2/4
# 38/38 [==============================] - 1s 14ms/step - loss: 641.9676 - mae: 0.0261 - batch_ndcg: 0.7836 - val_loss: 498.8429 - val_mae: 0.0052 - val_batch_ndcg: 0.3939
# Epoch 3/4
# 38/38 [==============================] - 1s 15ms/step - loss: 631.3433 - mae: 0.0258 - batch_ndcg: 0.8009 - val_loss: 496.5512 - val_mae: 0.0052 - val_batch_ndcg: 0.4015
# Epoch 4/4
# 38/38 [==============================] - 1s 15ms/step - loss: 638.5659 - mae: 0.0262 - batch_ndcg: 0.8067 - val_loss: 495.5521 - val_mae: 0.0052 - val_batch_ndcg: 0.3947
# Epoch 1/4
# 38/38 [==============================] - 1s 16ms/step - loss: 668.0606 - mae: 0.0261 - batch_ndcg: 0.7275 - val_loss: 502.5015 - val_mae: 0.0052 - val_batch_ndcg: 0.3926
# Epoch 2/4
# 38/38 [==============================] - 1s 15ms/step - loss: 641.3525 - mae: 0.0260 - batch_ndcg: 0.7861 - val_loss: 498.4742 - val_mae: 0.0052 - val_batch_ndcg: 0.3916
# Epoch 3/4
# 38/38 [==============================] - 1s 15ms/step - loss: 640.1291 - mae: 0.0262 - batch_ndcg: 0.8024 - val_loss: 496.5462 - val_mae: 0.0052 - val_batch_ndcg: 0.4007
# Epoch 4/4
# 38/38 [==============================] - 1s 15ms/step - loss: 637.3994 - mae: 0.0261 - batch_ndcg: 0.8069 - val_loss: 495.2467 - val_mae: 0.0052 - val_batch_ndcg: 0.3959
# Epoch 1/4
# 38/38 [==============================] - 1s 15ms/step - loss: 666.7427 - mae: 0.0260 - batch_ndcg: 0.7242 - val_loss: 502.4088 - val_mae: 0.0052 - val_batch_ndcg: 0.3940
# Epoch 2/4
# 38/38 [==============================] - 1s 16ms/step - loss: 636.1479 - mae: 0.0258 - batch_ndcg: 0.7884 - val_loss: 498.6262 - val_mae: 0.0052 - val_batch_ndcg: 0.3994
# Epoch 3/4
# 38/38 [==============================] - 1s 15ms/step - loss: 629.6857 - mae: 0.0258 - batch_ndcg: 0.8011 - val_loss: 496.1667 - val_mae: 0.0052 - val_batch_ndcg: 0.3996
# Epoch 4/4
# 38/38 [==============================] - 1s 15ms/step - loss: 632.8259 - mae: 0.0260 - batch_ndcg: 0.8096 - val_loss: 495.6478 - val_mae: 0.0052 - val_batch_ndcg: 0.3923
# Epoch 1/4
# 38/38 [==============================] - 1s 15ms/step - loss: 655.5651 - mae: 0.0256 - batch_ndcg: 0.7200 - val_loss: 502.4324 - val_mae: 0.0052 - val_batch_ndcg: 0.3903
# Epoch 2/4
# 38/38 [==============================] - 1s 15ms/step - loss: 634.2599 - mae: 0.0257 - batch_ndcg: 0.7807 - val_loss: 498.5480 - val_mae: 0.0052 - val_batch_ndcg: 0.3931
# Epoch 3/4
# 38/38 [==============================] - 1s 16ms/step - loss: 626.9130 - mae: 0.0257 - batch_ndcg: 0.8005 - val_loss: 496.2060 - val_mae: 0.0052 - val_batch_ndcg: 0.3935
# Epoch 4/4
# 38/38 [==============================] - 1s 15ms/step - loss: 630.1183 - mae: 0.0259 - batch_ndcg: 0.8079 - val_loss: 495.4906 - val_mae: 0.0052 - val_batch_ndcg: 0.3989
# Epoch 1/4
# 38/38 [==============================] - 1s 15ms/step - loss: 652.9064 - mae: 0.0255 - batch_ndcg: 0.7298 - val_loss: 502.3326 - val_mae: 0.0052 - val_batch_ndcg: 0.3907
# Epoch 2/4
# 38/38 [==============================] - 1s 14ms/step - loss: 640.8011 - mae: 0.0260 - batch_ndcg: 0.7857 - val_loss: 498.3160 - val_mae: 0.0052 - val_batch_ndcg: 0.3870
# Epoch 3/4
# 38/38 [==============================] - 1s 15ms/step - loss: 625.6799 - mae: 0.0256 - batch_ndcg: 0.7985 - val_loss: 496.5820 - val_mae: 0.0052 - val_batch_ndcg: 0.3892
# Epoch 4/4
# 38/38 [==============================] - 1s 14ms/step - loss: 614.8170 - mae: 0.0253 - batch_ndcg: 0.8040 - val_loss: 494.9757 - val_mae: 0.0052 - val_batch_ndcg: 0.3926
# Epoch 1/4
# 38/38 [==============================] - 1s 21ms/step - loss: 650.9908 - mae: 0.0254 - batch_ndcg: 0.7222 - val_loss: 502.0294 - val_mae: 0.0052 - val_batch_ndcg: 0.3874
# Epoch 2/4
# 38/38 [==============================] - 1s 16ms/step - loss: 627.4818 - mae: 0.0255 - batch_ndcg: 0.7844 - val_loss: 498.9571 - val_mae: 0.0052 - val_batch_ndcg: 0.4015
# Epoch 3/4
# 38/38 [==============================] - 1s 15ms/step - loss: 639.7228 - mae: 0.0261 - batch_ndcg: 0.8011 - val_loss: 496.0887 - val_mae: 0.0052 - val_batch_ndcg: 0.4028
# Epoch 4/4
# 38/38 [==============================] - 1s 15ms/step - loss: 631.9564 - mae: 0.0260 - batch_ndcg: 0.8060 - val_loss: 495.5679 - val_mae: 0.0052 - val_batch_ndcg: 0.3967
# Epoch 1/4
# 38/38 [==============================] - 1s 15ms/step - loss: 650.0884 - mae: 0.0254 - batch_ndcg: 0.7221 - val_loss: 502.7678 - val_mae: 0.0052 - val_batch_ndcg: 0.3900
# Epoch 2/4
# 38/38 [==============================] - 1s 15ms/step - loss: 646.0980 - mae: 0.0262 - batch_ndcg: 0.7869 - val_loss: 498.4793 - val_mae: 0.0052 - val_batch_ndcg: 0.3905
# Epoch 3/4
# 38/38 [==============================] - 1s 15ms/step - loss: 651.9946 - mae: 0.0267 - batch_ndcg: 0.8051 - val_loss: 496.5810 - val_mae: 0.0052 - val_batch_ndcg: 0.4036
# Epoch 4/4
# 38/38 [==============================] - 1s 14ms/step - loss: 629.2526 - mae: 0.0259 - batch_ndcg: 0.8120 - val_loss: 494.9999 - val_mae: 0.0052 - val_batch_ndcg: 0.3939
# Epoch 1/4
# 38/38 [==============================] - 1s 15ms/step - loss: 657.6620 - mae: 0.0256 - batch_ndcg: 0.7180 - val_loss: 502.9225 - val_mae: 0.0052 - val_batch_ndcg: 0.3858
# Epoch 2/4
# 38/38 [==============================] - 1s 15ms/step - loss: 652.6729 - mae: 0.0264 - batch_ndcg: 0.7870 - val_loss: 498.5125 - val_mae: 0.0052 - val_batch_ndcg: 0.3905
# Epoch 3/4
# 38/38 [==============================] - 1s 15ms/step - loss: 638.7271 - mae: 0.0261 - batch_ndcg: 0.8004 - val_loss: 496.8335 - val_mae: 0.0052 - val_batch_ndcg: 0.3958
# Epoch 4/4
# 38/38 [==============================] - 1s 14ms/step - loss: 613.8753 - mae: 0.0253 - batch_ndcg: 0.8072 - val_loss: 495.7276 - val_mae: 0.0052 - val_batch_ndcg: 0.3952
# Epoch 1/4
# 38/38 [==============================] - 1s 15ms/step - loss: 666.9091 - mae: 0.0260 - batch_ndcg: 0.7247 - val_loss: 502.7328 - val_mae: 0.0052 - val_batch_ndcg: 0.3878
# Epoch 2/4
# 38/38 [==============================] - 1s 14ms/step - loss: 640.1838 - mae: 0.0260 - batch_ndcg: 0.7882 - val_loss: 498.5766 - val_mae: 0.0052 - val_batch_ndcg: 0.3950
# Epoch 3/4
# 38/38 [==============================] - 1s 15ms/step - loss: 647.6642 - mae: 0.0265 - batch_ndcg: 0.8027 - val_loss: 496.4887 - val_mae: 0.0052 - val_batch_ndcg: 0.4039
# Epoch 4/4
# 38/38 [==============================] - 1s 15ms/step - loss: 631.1839 - mae: 0.0259 - batch_ndcg: 0.8075 - val_loss: 495.3979 - val_mae: 0.0052 - val_batch_ndcg: 0.3966
# Epoch 1/4
# 38/38 [==============================] - 1s 15ms/step - loss: 668.8247 - mae: 0.0261 - batch_ndcg: 0.7280 - val_loss: 502.6010 - val_mae: 0.0052 - val_batch_ndcg: 0.3843
# Epoch 2/4
# 38/38 [==============================] - 1s 14ms/step - loss: 633.5559 - mae: 0.0258 - batch_ndcg: 0.7864 - val_loss: 498.3611 - val_mae: 0.0052 - val_batch_ndcg: 0.3966
# Epoch 3/4
# 38/38 [==============================] - 1s 14ms/step - loss: 623.6727 - mae: 0.0256 - batch_ndcg: 0.7988 - val_loss: 497.2277 - val_mae: 0.0052 - val_batch_ndcg: 0.3944
# Epoch 4/4
# 38/38 [==============================] - 1s 15ms/step - loss: 614.0447 - mae: 0.0253 - batch_ndcg: 0.8083 - val_loss: 495.5473 - val_mae: 0.0052 - val_batch_ndcg: 0.3885
# Epoch 1/4
# 38/38 [==============================] - 1s 15ms/step - loss: 665.9950 - mae: 0.0261 - batch_ndcg: 0.7252 - val_loss: 502.3851 - val_mae: 0.0052 - val_batch_ndcg: 0.3824
# Epoch 2/4
# 38/38 [==============================] - 1s 15ms/step - loss: 642.1008 - mae: 0.0261 - batch_ndcg: 0.7885 - val_loss: 498.5300 - val_mae: 0.0052 - val_batch_ndcg: 0.3888
# Epoch 3/4
# 38/38 [==============================] - 1s 15ms/step - loss: 637.3844 - mae: 0.0261 - batch_ndcg: 0.8007 - val_loss: 496.6000 - val_mae: 0.0052 - val_batch_ndcg: 0.3940
# Epoch 4/4
# 38/38 [==============================] - 1s 14ms/step - loss: 616.4594 - mae: 0.0254 - batch_ndcg: 0.8106 - val_loss: 495.6952 - val_mae: 0.0052 - val_batch_ndcg: 0.3986
# CPU times: user 9min 39s, sys: 41.1 s, total: 10min 20s
# Wall time: 7min 37s

# %%
show_history(total_hist, 'loss', 'batch_ndcg')

# %%
pred = test_predictor(test_q, model, n_item, batch_size)
pred
# Out:
# array([[ 729, 1194,  690, ...,   48,  703,  828],
#        [1034, 1553,   33, ...,  624,  662,  767],
#        [ 501,   69,  919, ...,   90,  137,  937],
#        ...,
#        [ 104,  184,  315, ...,  171,   44,  116],
#        [ 609,  719, 1046, ...,    0,   46,  128],
#        [  44,  127,  217, ...,   48,   23,  559]])

# %%
m_ndcg, m_recall, m_precision, map_k = evaluation(test_a, pred)
print(f'nDCG: {m_ndcg:.5f}',
      f'\nRecall: {m_recall:.5f}',
      f'\nPrecision: {m_precision:.5f}',
      f'\nMAP: {map_k:.5f}')
# Out:
# nDCG: 0.52202
# Recall: 0.21683
# Precision: 0.17061
# MAP: 0.13030

# %% [markdown]
# ### 2. Mult-DAE(Logistic)

# %%
enc_optimizer = RMSprop(learning_rate = 0.001, decay = 1e-5)
optimizer = Adam(learning_rate = 0.001, decay = 1e-5)
encoder, model = VAE(n_user, n_item, latent_dim = 200, enc_optimizer = enc_optimizer, optimizer = optimizer, likelihood = 'logistic')
model.summary()
# Out:
# Model: "VAE"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              [(None, 3706)]       0
# __________________________________________________________________________________________________
# mean (Dense)                    (None, 200)          741400      input[0][0]
# __________________________________________________________________________________________________
# log_var (Dense)                 (None, 200)          741400      input[0][0]
# __________________________________________________________________________________________________
# sampling_3 (Sampling)           (None, 200)          0           mean[1][0]
#                                                                  log_var[1][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 3706)         744906      sampling_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sub_9 (TensorFlowOp [(None, 3706)]       0           output[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_4 (TensorFlow [(None, 200)]        0           log_var[1][0]
# __________________________________________________________________________________________________
# tf_op_layer_Exp_3 (TensorFlowOp [(None, 200)]        0           log_var[1][0]
# __________________________________________________________________________________________________
# tf_op_layer_Log_1 (TensorFlowOp [(None, 3706)]       0           output[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sub_8 (TensorFlowOp [(None, 3706)]       0           input[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Log_2 (TensorFlowOp [(None, 3706)]       0           tf_op_layer_Sub_9[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sub_6 (TensorFlowOp [(None, 200)]        0           tf_op_layer_AddV2_4[0][0]
#                                                                  tf_op_layer_Exp_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Square_3 (TensorFlo [(None, 200)]        0           mean[1][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_6 (TensorFlowOp [(None, 3706)]       0           input[0][0]
#                                                                  tf_op_layer_Log_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_7 (TensorFlowOp [(None, 3706)]       0           tf_op_layer_Sub_8[0][0]
#                                                                  tf_op_layer_Log_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sub_7 (TensorFlowOp [(None, 200)]        0           tf_op_layer_Sub_6[0][0]
#                                                                  tf_op_layer_Square_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_5 (TensorFlow [(None, 3706)]       0           tf_op_layer_Mul_6[0][0]
#                                                                  tf_op_layer_Mul_7[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sum_4 (TensorFlowOp [(None,)]            0           tf_op_layer_Sub_7[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Sum_5 (TensorFlowOp [(None,)]            0           tf_op_layer_AddV2_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_5 (TensorFlowOp [(None,)]            0           tf_op_layer_Sum_4[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Neg_1 (TensorFlowOp [(None,)]            0           tf_op_layer_Sum_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mul_8 (TensorFlowOp [(None,)]            0           tf_op_layer_Mul_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_6 (TensorFlow [(None,)]            0           tf_op_layer_Neg_1[0][0]
#                                                                  tf_op_layer_Mul_8[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mean_1 (TensorFlowO [()]                 0           tf_op_layer_AddV2_6[0][0]
# __________________________________________________________________________________________________
# add_loss_3 (AddLoss)            ()                   0           tf_op_layer_Mean_1[0][0]
# ==================================================================================================
# Total params: 2,227,706
# Trainable params: 2,227,706
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# %%time
epochs = 100
total_hist = {}
for _ in range(epochs):
    anneal_size, epoch_size = 8, 4
    encoder.fit(x = train_gen, epochs = anneal_size, steps_per_epoch = steps_per_epoch, verbose = 0)
    hist = model.fit(x = train_gen, validation_data = valid_gen, epochs = epoch_size, verbose = 1,
                     steps_per_epoch = steps_per_epoch, validation_steps = validation_steps)
    for key in hist.history.keys():
        total_hist[key] = total_hist.get(key, []) + hist.history[key]
# Out:
# Epoch 1/4
# 38/38 [==============================] - 1s 19ms/step - loss: 1312.0226 - mae: 0.2417 - batch_ndcg: 0.4680 - val_loss: 508.5359 - val_mae: 0.0697 - val_batch_ndcg: 0.3221
# Epoch 2/4
# 38/38 [==============================] - 1s 14ms/step - loss: 466.5149 - mae: 0.0593 - batch_ndcg: 0.6235 - val_loss: 404.3511 - val_mae: 0.0479 - val_batch_ndcg: 0.3320
# Epoch 3/4
# 38/38 [==============================] - 1s 13ms/step - loss: 424.6739 - mae: 0.0536 - batch_ndcg: 0.6284 - val_loss: 384.4121 - val_mae: 0.0439 - val_batch_ndcg: 0.3241
# Epoch 4/4
# 38/38 [==============================] - 1s 14ms/step - loss: 401.0433 - mae: 0.0504 - batch_ndcg: 0.6291 - val_loss: 364.1041 - val_mae: 0.0403 - val_batch_ndcg: 0.3283
# Epoch 1/4
# 38/38 [==============================] - 1s 14ms/step - loss: 723.5132 - mae: 0.1126 - batch_ndcg: 0.5594 - val_loss: 440.1209 - val_mae: 0.0545 - val_batch_ndcg: 0.3093
# Epoch 2/4
# 38/38 [==============================] - 1s 14ms/step - loss: 450.2708 - mae: 0.0573 - batch_ndcg: 0.6204 - val_loss: 407.4695 - val_mae: 0.0487 - val_batch_ndcg: 0.3233
# Epoch 3/4
# 38/38 [==============================] - 1s 14ms/step - loss: 421.3716 - mae: 0.0542 - batch_ndcg: 0.6333 - val_loss: 386.8481 - val_mae: 0.0452 - val_batch_ndcg: 0.3318
# Epoch 4/4
# 38/38 [==============================] - 1s 13ms/step - loss: 401.3689 - mae: 0.0513 - batch_ndcg: 0.6440 - val_loss: 373.0206 - val_mae: 0.0438 - val_batch_ndcg: 0.3436
# Epoch 1/4
# 38/38 [==============================] - 1s 14ms/step - loss: 675.2314 - mae: 0.1035 - batch_ndcg: 0.5807 - val_loss: 423.4009 - val_mae: 0.0516 - val_batch_ndcg: 0.3347
# Epoch 2/4
# 38/38 [==============================] - 1s 13ms/step - loss: 436.6980 - mae: 0.0550 - batch_ndcg: 0.6447 - val_loss: 402.9168 - val_mae: 0.0512 - val_batch_ndcg: 0.3380
# Epoch 3/4
# 38/38 [==============================] - 0s 13ms/step - loss: 414.2870 - mae: 0.0535 - batch_ndcg: 0.6554 - val_loss: 376.2323 - val_mae: 0.0454 - val_batch_ndcg: 0.3438
# Epoch 4/4
# 38/38 [==============================] - 1s 14ms/step - loss: 407.0239 - mae: 0.0528 - batch_ndcg: 0.6576 - val_loss: 367.9290 - val_mae: 0.0447 - val_batch_ndcg: 0.3496
# Epoch 1/4
# 38/38 [==============================] - 1s 14ms/step - loss: 656.1462 - mae: 0.1017 - batch_ndcg: 0.5817 - val_loss: 413.3373 - val_mae: 0.0511 - val_batch_ndcg: 0.3416
# Epoch 2/4
# 38/38 [==============================] - 1s 14ms/step - loss: 420.9031 - mae: 0.0542 - batch_ndcg: 0.6506 - val_loss: 389.5785 - val_mae: 0.0477 - val_batch_ndcg: 0.3511
# Epoch 3/4
# 38/38 [==============================] - 1s 13ms/step - loss: 392.3209 - mae: 0.0515 - batch_ndcg: 0.6546 - val_loss: 368.0287 - val_mae: 0.0450 - val_batch_ndcg: 0.3474
# Epoch 4/4
# 38/38 [==============================] - 1s 13ms/step - loss: 380.8092 - mae: 0.0500 - batch_ndcg: 0.6633 - val_loss: 348.9328 - val_mae: 0.0413 - val_batch_ndcg: 0.3485
# Epoch 1/4
# 38/38 [==============================] - 1s 14ms/step - loss: 622.1795 - mae: 0.0946 - batch_ndcg: 0.5992 - val_loss: 391.9450 - val_mae: 0.0462 - val_batch_ndcg: 0.3468
# Epoch 2/4
# 38/38 [==============================] - 0s 13ms/step - loss: 397.9485 - mae: 0.0521 - batch_ndcg: 0.6625 - val_loss: 369.1105 - val_mae: 0.0447 - val_batch_ndcg: 0.3489
# Epoch 3/4
# 38/38 [==============================] - 1s 14ms/step - loss: 384.3933 - mae: 0.0504 - batch_ndcg: 0.6694 - val_loss: 347.9341 - val_mae: 0.0413 - val_batch_ndcg: 0.3539
# Epoch 4/4
# 38/38 [==============================] - 1s 14ms/step - loss: 377.9761 - mae: 0.0497 - batch_ndcg: 0.6735 - val_loss: 343.5440 - val_mae: 0.0421 - val_batch_ndcg: 0.3511
# Epoch 1/4
# 38/38 [==============================] - 1s 14ms/step - loss: 623.9242 - mae: 0.0943 - batch_ndcg: 0.5966 - val_loss: 384.1540 - val_mae: 0.0458 - val_batch_ndcg: 0.3444
# Epoch 2/4
# 38/38 [==============================] - 1s 14ms/step - loss: 391.3420 - mae: 0.0510 - batch_ndcg: 0.6617 - val_loss: 351.9813 - val_mae: 0.0406 - val_batch_ndcg: 0.3541
# Epoch 3/4
# 38/38 [==============================] - 1s 14ms/step - loss: 382.8170 - mae: 0.0504 - batch_ndcg: 0.6699 - val_loss: 341.2436 - val_mae: 0.0406 - val_batch_ndcg: 0.3519
# Epoch 4/4
# 38/38 [==============================] - 1s 13ms/step - loss: 366.9669 - mae: 0.0484 - batch_ndcg: 0.6691 - val_loss: 332.3930 - val_mae: 0.0398 - val_batch_ndcg: 0.3570
# Epoch 1/4
# 38/38 [==============================] - 1s 14ms/step - loss: 622.9015 - mae: 0.0944 - batch_ndcg: 0.6037 - val_loss: 369.4589 - val_mae: 0.0442 - val_batch_ndcg: 0.3486
# Epoch 2/4
# 38/38 [==============================] - 1s 14ms/step - loss: 389.0061 - mae: 0.0508 - batch_ndcg: 0.6698 - val_loss: 347.1263 - val_mae: 0.0417 - val_batch_ndcg: 0.3505
# Epoch 3/4
# 38/38 [==============================] - 1s 13ms/step - loss: 366.3414 - mae: 0.0487 - batch_ndcg: 0.6694 - val_loss: 335.9329 - val_mae: 0.0397 - val_batch_ndcg: 0.3565
# Epoch 4/4
# 38/38 [==============================] - 1s 13ms/step - loss: 360.9230 - mae: 0.0473 - batch_ndcg: 0.6690 - val_loss: 321.9604 - val_mae: 0.0363 - val_batch_ndcg: 0.3556
# Epoch 1/4
# 38/38 [==============================] - 1s 14ms/step - loss: 617.3872 - mae: 0.0918 - batch_ndcg: 0.6122 - val_loss: 375.2883 - val_mae: 0.0456 - val_batch_ndcg: 0.3465
# Epoch 2/4
# 38/38 [==============================] - 1s 14ms/step - loss: 388.0570 - mae: 0.0514 - batch_ndcg: 0.6652 - val_loss: 342.8306 - val_mae: 0.0414 - val_batch_ndcg: 0.3510
# Epoch 3/4
# 38/38 [==============================] - 1s 13ms/step - loss: 364.5383 - mae: 0.0483 - batch_ndcg: 0.6706 - val_loss: 332.4075 - val_mae: 0.0398 - val_batch_ndcg: 0.3576
# Epoch 4/4
# 38/38 [==============================] - 0s 13ms/step - loss: 354.5675 - mae: 0.0469 - batch_ndcg: 0.6739 - val_loss: 326.9599 - val_mae: 0.0375 - val_batch_ndcg: 0.3576
# Epoch 1/4
# 38/38 [==============================] - 1s 14ms/step - loss: 587.8413 - mae: 0.0859 - batch_ndcg: 0.6142 - val_loss: 366.5861 - val_mae: 0.0431 - val_batch_ndcg: 0.3506
# Epoch 2/4
# 38/38 [==============================] - 1s 14ms/step - loss: 386.7545 - mae: 0.0504 - batch_ndcg: 0.6665 - val_loss: 342.0789 - val_mae: 0.0415 - val_batch_ndcg: 0.3525
# Epoch 3/4
# 38/38 [==============================] - 1s 13ms/step - loss: 360.5548 - mae: 0.0475 - batch_ndcg: 0.6749 - val_loss: 326.8609 - val_mae: 0.0375 - val_batch_ndcg: 0.3584
# Epoch 4/4
# 38/38 [==============================] - 1s 13ms/step - loss: 356.9502 - mae: 0.0474 - batch_ndcg: 0.6751 - val_loss: 319.9557 - val_mae: 0.0378 - val_batch_ndcg: 0.3612
# Epoch 1/4
# 38/38 [==============================] - 1s 14ms/step - loss: 609.3316 - mae: 0.0887 - batch_ndcg: 0.6042 - val_loss: 356.8828 - val_mae: 0.0433 - val_batch_ndcg: 0.3463
# Epoch 2/4
# 38/38 [==============================] - 1s 14ms/step - loss: 364.4905 - mae: 0.0488 - batch_ndcg: 0.6677 - val_loss: 339.4540 - val_mae: 0.0406 - val_batch_ndcg: 0.3522
# Epoch 3/4
# 38/38 [==============================] - 1s 14ms/step - loss: 361.7177 - mae: 0.0478 - batch_ndcg: 0.6677 - val_loss: 327.9687 - val_mae: 0.0386 - val_batch_ndcg: 0.3542
# Epoch 4/4
# 38/38 [==============================] - 1s 13ms/step - loss: 356.1527 - mae: 0.0471 - batch_ndcg: 0.6717 - val_loss: 316.2649 - val_mae: 0.0366 - val_batch_ndcg: 0.3571
# Epoch 1/4
# 38/38 [==============================] - 1s 14ms/step - loss: 613.1588 - mae: 0.0878 - batch_ndcg: 0.6121 - val_loss: 376.9925 - val_mae: 0.0459 - val_batch_ndcg: 0.3501
# Epoch 2/4
# 38/38 [==============================] - 1s 14ms/step - loss: 382.7580 - mae: 0.0513 - batch_ndcg: 0.6687 - val_loss: 339.6442 - val_mae: 0.0405 - val_batch_ndcg: 0.3624
# Epoch 3/4
# 38/38 [==============================] - 1s 13ms/step - loss: 358.9738 - mae: 0.0481 - batch_ndcg: 0.6716 - val_loss: 326.7214 - val_mae: 0.0377 - val_batch_ndcg: 0.3579
# Epoch 4/4
# 38/38 [==============================] - 0s 13ms/step - loss: 349.6742 - mae: 0.0467 - batch_ndcg: 0.6782 - val_loss: 314.0973 - val_mae: 0.0357 - val_batch_ndcg: 0.3630
# Epoch 1/4
# 38/38 [==============================] - 1s 14ms/step - loss: 588.5493 - mae: 0.0872 - batch_ndcg: 0.6070 - val_loss: 356.5328 - val_mae: 0.0425 - val_batch_ndcg: 0.3471
# Epoch 2/4
# 38/38 [==============================] - 1s 15ms/step - loss: 368.2420 - mae: 0.0490 - batch_ndcg: 0.6671 - val_loss: 323.4947 - val_mae: 0.0374 - val_batch_ndcg: 0.3499
# Epoch 3/4
# 38/38 [==============================] - 1s 14ms/step - loss: 360.1780 - mae: 0.0480 - batch_ndcg: 0.6775 - val_loss: 317.8406 - val_mae: 0.0366 - val_batch_ndcg: 0.3536
# Epoch 4/4
# 38/38 [==============================] - 1s 14ms/step - loss: 345.8783 - mae: 0.0462 - batch_ndcg: 0.6786 - val_loss: 311.8569 - val_mae: 0.0367 - val_batch_ndcg: 0.3586
# Epoch 1/4
# 38/38 [==============================] - 1s 15ms/step - loss: 576.5500 - mae: 0.0850 - batch_ndcg: 0.6113 - val_loss: 358.8872 - val_mae: 0.0438 - val_batch_ndcg: 0.3516
# Epoch 2/4
# 38/38 [==============================] - 1s 15ms/step - loss: 370.0618 - mae: 0.0493 - batch_ndcg: 0.6764 - val_loss: 331.7386 - val_mae: 0.0402 - val_batch_ndcg: 0.3564
# Epoch 3/4
# 38/38 [==============================] - 1s 14ms/step - loss: 347.5294 - mae: 0.0471 - batch_ndcg: 0.6812 - val_loss: 312.6553 - val_mae: 0.0352 - val_batch_ndcg: 0.3580
# Epoch 4/4
# 38/38 [==============================] - 1s 15ms/step - loss: 340.4249 - mae: 0.0455 - batch_ndcg: 0.6864 - val_loss: 314.3539 - val_mae: 0.0365 - val_batch_ndcg: 0.3628
# Epoch 1/4
# 38/38 [==============================] - 1s 15ms/step - loss: 568.4411 - mae: 0.0835 - batch_ndcg: 0.6018 - val_loss: 354.5375 - val_mae: 0.0422 - val_batch_ndcg: 0.3444
# Epoch 2/4
# 38/38 [==============================] - 1s 14ms/step - loss: 368.2393 - mae: 0.0490 - batch_ndcg: 0.6718 - val_loss: 327.4673 - val_mae: 0.0393 - val_batch_ndcg: 0.3563
# Epoch 3/4
# 38/38 [==============================] - 1s 14ms/step - loss: 350.6957 - mae: 0.0471 - batch_ndcg: 0.6767 - val_loss: 313.7776 - val_mae: 0.0357 - val_batch_ndcg: 0.3600
# Epoch 4/4
# 38/38 [==============================] - 1s 14ms/step - loss: 343.3918 - mae: 0.0458 - batch_ndcg: 0.6823 - val_loss: 307.4050 - val_mae: 0.0352 - val_batch_ndcg: 0.3602
# Epoch 1/4
# 38/38 [==============================] - 1s 14ms/step - loss: 557.8436 - mae: 0.0826 - batch_ndcg: 0.6029 - val_loss: 343.7538 - val_mae: 0.0411 - val_batch_ndcg: 0.3444
# Epoch 2/4
# 38/38 [==============================] - 1s 14ms/step - loss: 355.7743 - mae: 0.0479 - batch_ndcg: 0.6676 - val_loss: 326.6202 - val_mae: 0.0384 - val_batch_ndcg: 0.3578
# Epoch 3/4
# 38/38 [==============================] - 1s 13ms/step - loss: 341.2919 - mae: 0.0458 - batch_ndcg: 0.6800 - val_loss: 312.7358 - val_mae: 0.0357 - val_batch_ndcg: 0.3598
# Epoch 4/4
# 38/38 [==============================] - 1s 14ms/step - loss: 344.2770 - mae: 0.0463 - batch_ndcg: 0.6829 - val_loss: 306.9780 - val_mae: 0.0345 - val_batch_ndcg: 0.3622
# Epoch 1/4
# 38/38 [==============================] - 1s 15ms/step - loss: 567.9030 - mae: 0.0823 - batch_ndcg: 0.6169 - val_loss: 351.6384 - val_mae: 0.0430 - val_batch_ndcg: 0.3462
# Epoch 2/4
# 38/38 [==============================] - 1s 13ms/step - loss: 356.3861 - mae: 0.0489 - batch_ndcg: 0.6746 - val_loss: 325.3403 - val_mae: 0.0390 - val_batch_ndcg: 0.3536
# Epoch 3/4
# 38/38 [==============================] - 1s 14ms/step - loss: 347.7519 - mae: 0.0473 - batch_ndcg: 0.6796 - val_loss: 313.4640 - val_mae: 0.0372 - val_batch_ndcg: 0.3616
# Epoch 4/4
# 38/38 [==============================] - 1s 14ms/step - loss: 336.6196 - mae: 0.0456 - batch_ndcg: 0.6896 - val_loss: 305.4919 - val_mae: 0.0351 - val_batch_ndcg: 0.3695
# Epoch 1/4
# 38/38 [==============================] - 1s 15ms/step - loss: 539.4385 - mae: 0.0812 - batch_ndcg: 0.6191 - val_loss: 338.9774 - val_mae: 0.0406 - val_batch_ndcg: 0.3516
# Epoch 2/4
# 38/38 [==============================] - 1s 14ms/step - loss: 351.0831 - mae: 0.0478 - batch_ndcg: 0.6810 - val_loss: 322.1934 - val_mae: 0.0394 - val_batch_ndcg: 0.3556
# Epoch 3/4
# 38/38 [==============================] - 1s 15ms/step - loss: 337.5045 - mae: 0.0460 - batch_ndcg: 0.6897 - val_loss: 305.9901 - val_mae: 0.0360 - val_batch_ndcg: 0.3634
# Epoch 4/4
# 38/38 [==============================] - 1s 14ms/step - loss: 327.8985 - mae: 0.0443 - batch_ndcg: 0.6937 - val_loss: 296.4791 - val_mae: 0.0342 - val_batch_ndcg: 0.3650
# Epoch 1/4
# 38/38 [==============================] - 1s 14ms/step - loss: 578.6686 - mae: 0.0770 - batch_ndcg: 0.6103 - val_loss: 363.3499 - val_mae: 0.0438 - val_batch_ndcg: 0.3484
# Epoch 2/4
# 38/38 [==============================] - 1s 14ms/step - loss: 371.0547 - mae: 0.0502 - batch_ndcg: 0.6808 - val_loss: 332.1360 - val_mae: 0.0409 - val_batch_ndcg: 0.3671
# Epoch 3/4
# 38/38 [==============================] - 1s 13ms/step - loss: 344.9556 - mae: 0.0476 - batch_ndcg: 0.6923 - val_loss: 307.7944 - val_mae: 0.0375 - val_batch_ndcg: 0.3638
# Epoch 4/4
# 38/38 [==============================] - 1s 14ms/step - loss: 336.7727 - mae: 0.0465 - batch_ndcg: 0.6931 - val_loss: 305.3653 - val_mae: 0.0367 - val_batch_ndcg: 0.3591
# Epoch 1/4
# 38/38 [==============================] - 1s 14ms/step - loss: 579.2886 - mae: 0.0814 - batch_ndcg: 0.6044 - val_loss: 368.0408 - val_mae: 0.0462 - val_batch_ndcg: 0.3431
# Epoch 2/4
# 38/38 [==============================] - 1s 13ms/step - loss: 373.0075 - mae: 0.0506 - batch_ndcg: 0.6755 - val_loss: 332.5353 - val_mae: 0.0408 - val_batch_ndcg: 0.3583
# Epoch 3/4
# 38/38 [==============================] - 1s 14ms/step - loss: 347.6624 - mae: 0.0476 - batch_ndcg: 0.6826 - val_loss: 310.1126 - val_mae: 0.0368 - val_batch_ndcg: 0.3594
# Epoch 4/4
# 38/38 [==============================] - 1s 14ms/step - loss: 333.6921 - mae: 0.0459 - batch_ndcg: 0.6897 - val_loss: 301.3696 - val_mae: 0.0347 - val_batch_ndcg: 0.3668
# Epoch 1/4
# 38/38 [==============================] - 1s 14ms/step - loss: 549.8222 - mae: 0.0782 - batch_ndcg: 0.6214 - val_loss: 362.5812 - val_mae: 0.0450 - val_batch_ndcg: 0.3445
# Epoch 2/4
# 38/38 [==============================] - 1s 14ms/step - loss: 372.5577 - mae: 0.0507 - batch_ndcg: 0.6844 - val_loss: 329.9393 - val_mae: 0.0411 - val_batch_ndcg: 0.3584
# Epoch 3/4
# 38/38 [==============================] - 1s 13ms/step - loss: 345.1419 - mae: 0.0476 - batch_ndcg: 0.6893 - val_loss: 314.2723 - val_mae: 0.0382 - val_batch_ndcg: 0.3671
# Epoch 4/4
# 38/38 [==============================] - 1s 14ms/step - loss: 336.8821 - mae: 0.0468 - batch_ndcg: 0.6967 - val_loss: 302.5323 - val_mae: 0.0367 - val_batch_ndcg: 0.3689
# Epoch 1/4
# 38/38 [==============================] - 1s 14ms/step - loss: 549.2742 - mae: 0.0817 - batch_ndcg: 0.6128 - val_loss: 343.9864 - val_mae: 0.0426 - val_batch_ndcg: 0.3451
# Epoch 2/4
# 38/38 [==============================] - 1s 15ms/step - loss: 350.5290 - mae: 0.0486 - batch_ndcg: 0.6845 - val_loss: 316.8086 - val_mae: 0.0384 - val_batch_ndcg: 0.3574
# Epoch 3/4
# 38/38 [==============================] - 1s 15ms/step - loss: 339.4437 - mae: 0.0468 - batch_ndcg: 0.6974 - val_loss: 308.9923 - val_mae: 0.0379 - val_batch_ndcg: 0.3641
# Epoch 4/4
# 38/38 [==============================] - 1s 14ms/step - loss: 330.8450 - mae: 0.0454 - batch_ndcg: 0.6958 - val_loss: 298.4532 - val_mae: 0.0351 - val_batch_ndcg: 0.3694
# Epoch 1/4
# 38/38 [==============================] - 1s 15ms/step - loss: 535.3611 - mae: 0.0781 - batch_ndcg: 0.6147 - val_loss: 340.5080 - val_mae: 0.0418 - val_batch_ndcg: 0.3467
# Epoch 2/4
# 38/38 [==============================] - 1s 14ms/step - loss: 354.3935 - mae: 0.0489 - batch_ndcg: 0.6850 - val_loss: 318.8527 - val_mae: 0.0389 - val_batch_ndcg: 0.3602
# Epoch 3/4
# 38/38 [==============================] - 1s 14ms/step - loss: 335.3881 - mae: 0.0462 - batch_ndcg: 0.6991 - val_loss: 302.9214 - val_mae: 0.0363 - val_batch_ndcg: 0.3617
# Epoch 4/4
# 38/38 [==============================] - 1s 14ms/step - loss: 327.6678 - mae: 0.0451 - batch_ndcg: 0.6962 - val_loss: 296.7195 - val_mae: 0.0348 - val_batch_ndcg: 0.3655
# Epoch 1/4
# 38/38 [==============================] - 1s 14ms/step - loss: 526.9279 - mae: 0.0789 - batch_ndcg: 0.6132 - val_loss: 333.0880 - val_mae: 0.0415 - val_batch_ndcg: 0.3473
# Epoch 2/4
# 38/38 [==============================] - 1s 14ms/step - loss: 347.2441 - mae: 0.0484 - batch_ndcg: 0.6890 - val_loss: 309.7286 - val_mae: 0.0375 - val_batch_ndcg: 0.3671
# Epoch 3/4
# 38/38 [==============================] - 1s 14ms/step - loss: 338.4109 - mae: 0.0470 - batch_ndcg: 0.7029 - val_loss: 297.1981 - val_mae: 0.0354 - val_batch_ndcg: 0.3723
# Epoch 4/4
# 38/38 [==============================] - 1s 14ms/step - loss: 326.2605 - mae: 0.0449 - batch_ndcg: 0.7012 - val_loss: 290.2625 - val_mae: 0.0343 - val_batch_ndcg: 0.3705
# Epoch 1/4
# 38/38 [==============================] - 1s 14ms/step - loss: 526.3455 - mae: 0.0753 - batch_ndcg: 0.6187 - val_loss: 332.7989 - val_mae: 0.0409 - val_batch_ndcg: 0.3496
# Epoch 2/4
# 38/38 [==============================] - 1s 14ms/step - loss: 342.8311 - mae: 0.0479 - batch_ndcg: 0.6880 - val_loss: 300.1710 - val_mae: 0.0359 - val_batch_ndcg: 0.3686
# Epoch 3/4
# 38/38 [==============================] - 1s 14ms/step - loss: 326.7546 - mae: 0.0456 - batch_ndcg: 0.7062 - val_loss: 297.0329 - val_mae: 0.0362 - val_batch_ndcg: 0.3703
# Epoch 4/4
# 38/38 [==============================] - 1s 13ms/step - loss: 316.9358 - mae: 0.0441 - batch_ndcg: 0.7021 - val_loss: 287.0728 - val_mae: 0.0331 - val_batch_ndcg: 0.3734
# Epoch 1/4
# 38/38 [==============================] - 1s 15ms/step - loss: 523.0757 - mae: 0.0769 - batch_ndcg: 0.6172 - val_loss: 325.7439 - val_mae: 0.0401 - val_batch_ndcg: 0.3580
# Epoch 2/4
# 38/38 [==============================] - 1s 14ms/step - loss: 343.3436 - mae: 0.0480 - batch_ndcg: 0.6972 - val_loss: 302.6979 - val_mae: 0.0364 - val_batch_ndcg: 0.3683
# Epoch 3/4
# 38/38 [==============================] - 1s 14ms/step - loss: 321.9906 - mae: 0.0449 - batch_ndcg: 0.7026 - val_loss: 296.1706 - val_mae: 0.0361 - val_batch_ndcg: 0.3688
# Epoch 4/4
# 38/38 [==============================] - 1s 14ms/step - loss: 323.8952 - mae: 0.0453 - batch_ndcg: 0.7131 - val_loss: 288.3083 - val_mae: 0.0332 - val_batch_ndcg: 0.3770
# Epoch 1/4
# 37/38 [============================>.] - ETA: 0s - loss: 499.8997 - mae: 0.0770 - batch_ndcg: 0.6218WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0061s vs `on_test_batch_end` time: 0.0096s). Check your callbacks.
# 38/38 [==============================] - 1s 15ms/step - loss: 495.8969 - mae: 0.0762 - batch_ndcg: 0.6238 - val_loss: 322.0538 - val_mae: 0.0396 - val_batch_ndcg: 0.3613
# Epoch 2/4
# 38/38 [==============================] - 1s 14ms/step - loss: 337.4827 - mae: 0.0475 - batch_ndcg: 0.6965 - val_loss: 297.3088 - val_mae: 0.0359 - val_batch_ndcg: 0.3663
# Epoch 3/4
# 38/38 [==============================] - 1s 14ms/step - loss: 321.8015 - mae: 0.0450 - batch_ndcg: 0.7092 - val_loss: 287.5311 - val_mae: 0.0339 - val_batch_ndcg: 0.3759
# Epoch 4/4
# 38/38 [==============================] - 1s 15ms/step - loss: 317.1889 - mae: 0.0442 - batch_ndcg: 0.7212 - val_loss: 288.3685 - val_mae: 0.0346 - val_batch_ndcg: 0.3737
# Epoch 1/4
# 38/38 [==============================] - 1s 15ms/step - loss: 507.2291 - mae: 0.0719 - batch_ndcg: 0.6235 - val_loss: 328.1648 - val_mae: 0.0411 - val_batch_ndcg: 0.3474
# Epoch 2/4
# 38/38 [==============================] - 1s 14ms/step - loss: 340.7542 - mae: 0.0479 - batch_ndcg: 0.6974 - val_loss: 297.6373 - val_mae: 0.0353 - val_batch_ndcg: 0.3629
# Epoch 3/4
# 38/38 [==============================] - 1s 14ms/step - loss: 325.1869 - mae: 0.0456 - batch_ndcg: 0.7099 - val_loss: 287.4862 - val_mae: 0.0348 - val_batch_ndcg: 0.3823
# Epoch 4/4
# 38/38 [==============================] - 1s 14ms/step - loss: 312.9133 - mae: 0.0440 - batch_ndcg: 0.7115 - val_loss: 282.8436 - val_mae: 0.0336 - val_batch_ndcg: 0.3765
# Epoch 1/4
# 38/38 [==============================] - 1s 15ms/step - loss: 495.3694 - mae: 0.0723 - batch_ndcg: 0.6195 - val_loss: 321.7891 - val_mae: 0.0407 - val_batch_ndcg: 0.3579
# Epoch 2/4
# 38/38 [==============================] - 1s 14ms/step - loss: 338.8313 - mae: 0.0476 - batch_ndcg: 0.7018 - val_loss: 304.3241 - val_mae: 0.0383 - val_batch_ndcg: 0.3629
# Epoch 3/4
# 38/38 [==============================] - 1s 14ms/step - loss: 316.6616 - mae: 0.0447 - batch_ndcg: 0.7097 - val_loss: 289.2498 - val_mae: 0.0353 - val_batch_ndcg: 0.3726
# Epoch 4/4
# 38/38 [==============================] - 1s 14ms/step - loss: 312.3078 - mae: 0.0438 - batch_ndcg: 0.7135 - val_loss: 282.3364 - val_mae: 0.0333 - val_batch_ndcg: 0.3771
# Epoch 1/4
# 38/38 [==============================] - 1s 15ms/step - loss: 527.4737 - mae: 0.0725 - batch_ndcg: 0.6121 - val_loss: 340.4020 - val_mae: 0.0444 - val_batch_ndcg: 0.3494
# Epoch 2/4
# 38/38 [==============================] - 1s 14ms/step - loss: 339.1204 - mae: 0.0479 - batch_ndcg: 0.6961 - val_loss: 303.7653 - val_mae: 0.0383 - val_batch_ndcg: 0.3669
# Epoch 3/4
# 38/38 [==============================] - 1s 14ms/step - loss: 322.6292 - mae: 0.0459 - batch_ndcg: 0.7113 - val_loss: 297.9412 - val_mae: 0.0372 - val_batch_ndcg: 0.3721
# Epoch 4/4
# 38/38 [==============================] - 1s 14ms/step - loss: 315.4916 - mae: 0.0444 - batch_ndcg: 0.7176 - val_loss: 284.9124 - val_mae: 0.0346 - val_batch_ndcg: 0.3758
# Epoch 1/4
# 38/38 [==============================] - 1s 15ms/step - loss: 528.9774 - mae: 0.0702 - batch_ndcg: 0.6128 - val_loss: 337.0245 - val_mae: 0.0396 - val_batch_ndcg: 0.3455
# Epoch 2/4
# 38/38 [==============================] - 1s 14ms/step - loss: 352.3373 - mae: 0.0483 - batch_ndcg: 0.6774 - val_loss: 315.0627 - val_mae: 0.0387 - val_batch_ndcg: 0.3515
# Epoch 3/4
# 38/38 [==============================] - 1s 14ms/step - loss: 337.9539 - mae: 0.0470 - batch_ndcg: 0.6961 - val_loss: 301.7193 - val_mae: 0.0362 - val_batch_ndcg: 0.3607
# Epoch 4/4
# 38/38 [==============================] - 1s 14ms/step - loss: 323.6850 - mae: 0.0452 - batch_ndcg: 0.7014 - val_loss: 290.2169 - val_mae: 0.0350 - val_batch_ndcg: 0.3589
# Epoch 1/4
# 38/38 [==============================] - 1s 14ms/step - loss: 515.1962 - mae: 0.0755 - batch_ndcg: 0.6038 - val_loss: 330.6891 - val_mae: 0.0407 - val_batch_ndcg: 0.3454
# Epoch 2/4
# 38/38 [==============================] - 1s 14ms/step - loss: 343.1595 - mae: 0.0477 - batch_ndcg: 0.6795 - val_loss: 307.9913 - val_mae: 0.0373 - val_batch_ndcg: 0.3543
# Epoch 3/4
# 38/38 [==============================] - 1s 15ms/step - loss: 324.3302 - mae: 0.0455 - batch_ndcg: 0.6978 - val_loss: 289.7680 - val_mae: 0.0348 - val_batch_ndcg: 0.3638
# Epoch 4/4
# 38/38 [==============================] - 1s 14ms/step - loss: 318.6091 - mae: 0.0445 - batch_ndcg: 0.7050 - val_loss: 286.1427 - val_mae: 0.0343 - val_batch_ndcg: 0.3709
# Epoch 1/4
# 38/38 [==============================] - 1s 15ms/step - loss: 482.1388 - mae: 0.0726 - batch_ndcg: 0.6137 - val_loss: 321.2336 - val_mae: 0.0382 - val_batch_ndcg: 0.3546
# Epoch 2/4
# 38/38 [==============================] - 1s 14ms/step - loss: 334.6508 - mae: 0.0472 - batch_ndcg: 0.6839 - val_loss: 302.8412 - val_mae: 0.0372 - val_batch_ndcg: 0.3591
# Epoch 3/4
# 38/38 [==============================] - 1s 14ms/step - loss: 324.6649 - mae: 0.0456 - batch_ndcg: 0.7003 - val_loss: 287.0315 - val_mae: 0.0338 - val_batch_ndcg: 0.3718
# Epoch 4/4
# 38/38 [==============================] - 1s 15ms/step - loss: 309.1248 - mae: 0.0433 - batch_ndcg: 0.7060 - val_loss: 283.2888 - val_mae: 0.0335 - val_batch_ndcg: 0.3732
# Epoch 1/4
# 38/38 [==============================] - 1s 14ms/step - loss: 493.1056 - mae: 0.0700 - batch_ndcg: 0.6179 - val_loss: 323.0459 - val_mae: 0.0396 - val_batch_ndcg: 0.3509
# Epoch 2/4
# 38/38 [==============================] - 1s 14ms/step - loss: 340.9508 - mae: 0.0481 - batch_ndcg: 0.6899 - val_loss: 297.2028 - val_mae: 0.0369 - val_batch_ndcg: 0.3619
# Epoch 3/4
# 38/38 [==============================] - 1s 14ms/step - loss: 331.4707 - mae: 0.0471 - batch_ndcg: 0.7061 - val_loss: 289.7974 - val_mae: 0.0352 - val_batch_ndcg: 0.3693
# Epoch 4/4
# 38/38 [==============================] - 1s 14ms/step - loss: 317.9281 - mae: 0.0450 - batch_ndcg: 0.7090 - val_loss: 278.6248 - val_mae: 0.0324 - val_batch_ndcg: 0.3733
# Epoch 1/4
# 38/38 [==============================] - 1s 14ms/step - loss: 511.6126 - mae: 0.0687 - batch_ndcg: 0.6133 - val_loss: 332.1703 - val_mae: 0.0403 - val_batch_ndcg: 0.3433
# Epoch 2/4
# 38/38 [==============================] - 1s 14ms/step - loss: 348.4200 - mae: 0.0488 - batch_ndcg: 0.6875 - val_loss: 306.4429 - val_mae: 0.0370 - val_batch_ndcg: 0.3540
# Epoch 3/4
# 38/38 [==============================] - 1s 14ms/step - loss: 324.4730 - mae: 0.0456 - batch_ndcg: 0.6997 - val_loss: 291.4120 - val_mae: 0.0355 - val_batch_ndcg: 0.3686
# Epoch 4/4
# 38/38 [==============================] - 1s 14ms/step - loss: 310.1606 - mae: 0.0435 - batch_ndcg: 0.7129 - val_loss: 283.6605 - val_mae: 0.0341 - val_batch_ndcg: 0.3698
# Epoch 1/4
# 38/38 [==============================] - 1s 15ms/step - loss: 481.1471 - mae: 0.0723 - batch_ndcg: 0.6172 - val_loss: 310.7608 - val_mae: 0.0358 - val_batch_ndcg: 0.3562
# Epoch 2/4
# 38/38 [==============================] - 1s 14ms/step - loss: 338.3817 - mae: 0.0477 - batch_ndcg: 0.6976 - val_loss: 293.7880 - val_mae: 0.0355 - val_batch_ndcg: 0.3627
# Epoch 3/4
# 38/38 [==============================] - 1s 14ms/step - loss: 321.6088 - mae: 0.0453 - batch_ndcg: 0.7094 - val_loss: 285.1653 - val_mae: 0.0345 - val_batch_ndcg: 0.3711
# Epoch 4/4
# 38/38 [==============================] - 1s 15ms/step - loss: 311.6558 - mae: 0.0439 - batch_ndcg: 0.7136 - val_loss: 278.8539 - val_mae: 0.0334 - val_batch_ndcg: 0.3737
# Epoch 1/4
# 38/38 [==============================] - 1s 15ms/step - loss: 462.3374 - mae: 0.0690 - batch_ndcg: 0.6131 - val_loss: 311.9549 - val_mae: 0.0390 - val_batch_ndcg: 0.3564
# Epoch 2/4
# 38/38 [==============================] - 1s 14ms/step - loss: 325.1193 - mae: 0.0464 - batch_ndcg: 0.6901 - val_loss: 290.4901 - val_mae: 0.0358 - val_batch_ndcg: 0.3644
# Epoch 3/4
# 38/38 [==============================] - 1s 14ms/step - loss: 315.4888 - mae: 0.0448 - batch_ndcg: 0.7074 - val_loss: 279.4831 - val_mae: 0.0332 - val_batch_ndcg: 0.3747
# Epoch 4/4
# 38/38 [==============================] - 1s 15ms/step - loss: 309.0875 - mae: 0.0438 - batch_ndcg: 0.7193 - val_loss: 275.3427 - val_mae: 0.0328 - val_batch_ndcg: 0.3764
# Epoch 1/4
# 38/38 [==============================] - 1s 14ms/step - loss: 464.2372 - mae: 0.0668 - batch_ndcg: 0.6221 - val_loss: 312.9341 - val_mae: 0.0379 - val_batch_ndcg: 0.3555
# Epoch 2/4
# 38/38 [==============================] - 1s 14ms/step - loss: 329.0134 - mae: 0.0465 - batch_ndcg: 0.7003 - val_loss: 289.8918 - val_mae: 0.0352 - val_batch_ndcg: 0.3636
# Epoch 3/4
# 38/38 [==============================] - 1s 14ms/step - loss: 306.8745 - mae: 0.0438 - batch_ndcg: 0.7045 - val_loss: 280.6640 - val_mae: 0.0332 - val_batch_ndcg: 0.3700
# Epoch 4/4
# 38/38 [==============================] - 1s 14ms/step - loss: 309.7631 - mae: 0.0439 - batch_ndcg: 0.7176 - val_loss: 275.0770 - val_mae: 0.0326 - val_batch_ndcg: 0.3742
# Epoch 1/4
# 38/38 [==============================] - 1s 15ms/step - loss: 456.8437 - mae: 0.0663 - batch_ndcg: 0.6272 - val_loss: 314.1622 - val_mae: 0.0386 - val_batch_ndcg: 0.3531
# Epoch 2/4
# 38/38 [==============================] - 1s 14ms/step - loss: 322.5445 - mae: 0.0458 - batch_ndcg: 0.6974 - val_loss: 284.8886 - val_mae: 0.0337 - val_batch_ndcg: 0.3620
# Epoch 3/4
# 38/38 [==============================] - 1s 14ms/step - loss: 307.1930 - mae: 0.0434 - batch_ndcg: 0.7121 - val_loss: 280.5450 - val_mae: 0.0339 - val_batch_ndcg: 0.3649
# Epoch 4/4
# 38/38 [==============================] - 1s 14ms/step - loss: 304.7816 - mae: 0.0433 - batch_ndcg: 0.7208 - val_loss: 271.6309 - val_mae: 0.0316 - val_batch_ndcg: 0.3788
# Epoch 1/4
# 38/38 [==============================] - 1s 15ms/step - loss: 460.6945 - mae: 0.0643 - batch_ndcg: 0.6186 - val_loss: 313.7552 - val_mae: 0.0370 - val_batch_ndcg: 0.3512
# Epoch 2/4
# 38/38 [==============================] - 1s 14ms/step - loss: 329.5941 - mae: 0.0461 - batch_ndcg: 0.6927 - val_loss: 294.8869 - val_mae: 0.0357 - val_batch_ndcg: 0.3626
# Epoch 3/4
# 38/38 [==============================] - 1s 14ms/step - loss: 309.8678 - mae: 0.0436 - batch_ndcg: 0.7086 - val_loss: 280.3857 - val_mae: 0.0332 - val_batch_ndcg: 0.3712
# Epoch 4/4
# 38/38 [==============================] - 1s 14ms/step - loss: 308.2937 - mae: 0.0432 - batch_ndcg: 0.7174 - val_loss: 274.8362 - val_mae: 0.0316 - val_batch_ndcg: 0.3754
# Epoch 1/4
# 36/38 [===========================>..] - ETA: 0s - loss: 446.6414 - mae: 0.0681 - batch_ndcg: 0.6248WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0062s vs `on_test_batch_end` time: 0.0101s). Check your callbacks.
# 38/38 [==============================] - 1s 15ms/step - loss: 442.3396 - mae: 0.0671 - batch_ndcg: 0.6292 - val_loss: 303.7427 - val_mae: 0.0365 - val_batch_ndcg: 0.3521
# Epoch 2/4
# 38/38 [==============================] - 1s 14ms/step - loss: 319.5475 - mae: 0.0457 - batch_ndcg: 0.6998 - val_loss: 283.1314 - val_mae: 0.0338 - val_batch_ndcg: 0.3669
# Epoch 3/4
# 38/38 [==============================] - 1s 14ms/step - loss: 307.2222 - mae: 0.0434 - batch_ndcg: 0.7159 - val_loss: 280.4994 - val_mae: 0.0337 - val_batch_ndcg: 0.3755
# Epoch 4/4
# 38/38 [==============================] - 1s 14ms/step - loss: 300.9453 - mae: 0.0424 - batch_ndcg: 0.7206 - val_loss: 268.6173 - val_mae: 0.0307 - val_batch_ndcg: 0.3716
# Epoch 1/4
# 38/38 [==============================] - 1s 14ms/step - loss: 435.5393 - mae: 0.0638 - batch_ndcg: 0.6239 - val_loss: 312.0840 - val_mae: 0.0367 - val_batch_ndcg: 0.3543
# Epoch 2/4
# 38/38 [==============================] - 1s 14ms/step - loss: 327.0213 - mae: 0.0461 - batch_ndcg: 0.6988 - val_loss: 286.1336 - val_mae: 0.0338 - val_batch_ndcg: 0.3644
# Epoch 3/4
# 38/38 [==============================] - 1s 14ms/step - loss: 305.8777 - mae: 0.0433 - batch_ndcg: 0.7159 - val_loss: 276.6450 - val_mae: 0.0327 - val_batch_ndcg: 0.3727
# Epoch 4/4
# 38/38 [==============================] - 1s 15ms/step - loss: 306.1512 - mae: 0.0431 - batch_ndcg: 0.7209 - val_loss: 276.5660 - val_mae: 0.0330 - val_batch_ndcg: 0.3739
# Epoch 1/4
# 38/38 [==============================] - 1s 14ms/step - loss: 447.5233 - mae: 0.0669 - batch_ndcg: 0.6286 - val_loss: 301.7499 - val_mae: 0.0360 - val_batch_ndcg: 0.3567
# Epoch 2/4
# 38/38 [==============================] - 1s 15ms/step - loss: 319.0457 - mae: 0.0455 - batch_ndcg: 0.7063 - val_loss: 279.4658 - val_mae: 0.0337 - val_batch_ndcg: 0.3679
# Epoch 3/4
# 38/38 [==============================] - 1s 14ms/step - loss: 303.7703 - mae: 0.0435 - batch_ndcg: 0.7224 - val_loss: 271.8320 - val_mae: 0.0322 - val_batch_ndcg: 0.3726
# Epoch 4/4
# 38/38 [==============================] - 1s 14ms/step - loss: 299.1548 - mae: 0.0420 - batch_ndcg: 0.7280 - val_loss: 270.0632 - val_mae: 0.0329 - val_batch_ndcg: 0.3821
# Epoch 1/4
# 38/38 [==============================] - 1s 15ms/step - loss: 434.5585 - mae: 0.0652 - batch_ndcg: 0.6296 - val_loss: 300.9552 - val_mae: 0.0358 - val_batch_ndcg: 0.3598
# Epoch 2/4
# 38/38 [==============================] - 1s 14ms/step - loss: 314.8163 - mae: 0.0450 - batch_ndcg: 0.7055 - val_loss: 282.0225 - val_mae: 0.0342 - val_batch_ndcg: 0.3688
# Epoch 3/4
# 38/38 [==============================] - 1s 14ms/step - loss: 307.3282 - mae: 0.0437 - batch_ndcg: 0.7259 - val_loss: 271.8456 - val_mae: 0.0331 - val_batch_ndcg: 0.3724
# Epoch 4/4
# 38/38 [==============================] - 1s 15ms/step - loss: 298.2801 - mae: 0.0424 - batch_ndcg: 0.7303 - val_loss: 266.6458 - val_mae: 0.0316 - val_batch_ndcg: 0.3777
# Epoch 1/4
# 38/38 [==============================] - 1s 14ms/step - loss: 426.9187 - mae: 0.0644 - batch_ndcg: 0.6328 - val_loss: 294.0504 - val_mae: 0.0352 - val_batch_ndcg: 0.3693
# Epoch 2/4
# 38/38 [==============================] - 1s 14ms/step - loss: 317.6584 - mae: 0.0457 - batch_ndcg: 0.7125 - val_loss: 280.6827 - val_mae: 0.0344 - val_batch_ndcg: 0.3666
# Epoch 3/4
# 38/38 [==============================] - 1s 14ms/step - loss: 299.7252 - mae: 0.0428 - batch_ndcg: 0.7222 - val_loss: 269.9923 - val_mae: 0.0322 - val_batch_ndcg: 0.3694
# Epoch 4/4
# 38/38 [==============================] - 1s 14ms/step - loss: 296.2145 - mae: 0.0422 - batch_ndcg: 0.7274 - val_loss: 265.9855 - val_mae: 0.0317 - val_batch_ndcg: 0.3747
# Epoch 1/4
# 38/38 [==============================] - 1s 15ms/step - loss: 440.8467 - mae: 0.0633 - batch_ndcg: 0.6365 - val_loss: 304.5340 - val_mae: 0.0374 - val_batch_ndcg: 0.3558
# Epoch 2/4
# 38/38 [==============================] - 1s 14ms/step - loss: 320.9818 - mae: 0.0464 - batch_ndcg: 0.7094 - val_loss: 279.0602 - val_mae: 0.0331 - val_batch_ndcg: 0.3663
# Epoch 3/4
# 38/38 [==============================] - 1s 14ms/step - loss: 298.5004 - mae: 0.0427 - batch_ndcg: 0.7233 - val_loss: 268.0735 - val_mae: 0.0318 - val_batch_ndcg: 0.3741
# Epoch 4/4
# 38/38 [==============================] - 1s 14ms/step - loss: 300.2193 - mae: 0.0430 - batch_ndcg: 0.7329 - val_loss: 262.8192 - val_mae: 0.0313 - val_batch_ndcg: 0.3753
# Epoch 1/4
# 38/38 [==============================] - 1s 14ms/step - loss: 452.0907 - mae: 0.0588 - batch_ndcg: 0.6151 - val_loss: 311.0361 - val_mae: 0.0346 - val_batch_ndcg: 0.3480
# Epoch 2/4
# 38/38 [==============================] - 1s 14ms/step - loss: 327.9377 - mae: 0.0457 - batch_ndcg: 0.6981 - val_loss: 286.8746 - val_mae: 0.0334 - val_batch_ndcg: 0.3692
# Epoch 3/4
# 38/38 [==============================] - 1s 14ms/step - loss: 307.6243 - mae: 0.0434 - batch_ndcg: 0.7181 - val_loss: 277.2445 - val_mae: 0.0332 - val_batch_ndcg: 0.3684
# Epoch 4/4
# 38/38 [==============================] - 1s 14ms/step - loss: 305.8382 - mae: 0.0432 - batch_ndcg: 0.7236 - val_loss: 268.2880 - val_mae: 0.0311 - val_batch_ndcg: 0.3761
# Epoch 1/4
# 38/38 [==============================] - 1s 14ms/step - loss: 445.7652 - mae: 0.0643 - batch_ndcg: 0.6331 - val_loss: 300.7314 - val_mae: 0.0364 - val_batch_ndcg: 0.3580
# Epoch 2/4
# 38/38 [==============================] - 1s 15ms/step - loss: 321.5787 - mae: 0.0459 - batch_ndcg: 0.7099 - val_loss: 280.5940 - val_mae: 0.0336 - val_batch_ndcg: 0.3680
# Epoch 3/4
# 38/38 [==============================] - 1s 14ms/step - loss: 309.3380 - mae: 0.0441 - batch_ndcg: 0.7170 - val_loss: 275.4517 - val_mae: 0.0333 - val_batch_ndcg: 0.3674
# Epoch 4/4
# 38/38 [==============================] - 1s 14ms/step - loss: 297.2246 - mae: 0.0423 - batch_ndcg: 0.7285 - val_loss: 268.5546 - val_mae: 0.0324 - val_batch_ndcg: 0.3758
# Epoch 1/4
# 38/38 [==============================] - 1s 15ms/step - loss: 437.6234 - mae: 0.0635 - batch_ndcg: 0.6284 - val_loss: 299.0495 - val_mae: 0.0373 - val_batch_ndcg: 0.3544
# Epoch 2/4
# 38/38 [==============================] - 1s 15ms/step - loss: 313.8527 - mae: 0.0449 - batch_ndcg: 0.7072 - val_loss: 281.4194 - val_mae: 0.0343 - val_batch_ndcg: 0.3619
# Epoch 3/4
# 38/38 [==============================] - 1s 14ms/step - loss: 308.0255 - mae: 0.0440 - batch_ndcg: 0.7211 - val_loss: 275.6112 - val_mae: 0.0348 - val_batch_ndcg: 0.3738
# Epoch 4/4
# 38/38 [==============================] - 1s 15ms/step - loss: 298.8090 - mae: 0.0427 - batch_ndcg: 0.7278 - val_loss: 267.1387 - val_mae: 0.0309 - val_batch_ndcg: 0.3760
# Epoch 1/4
# 38/38 [==============================] - 1s 15ms/step - loss: 415.3947 - mae: 0.0621 - batch_ndcg: 0.6329 - val_loss: 291.8819 - val_mae: 0.0346 - val_batch_ndcg: 0.3703
# Epoch 2/4
# 38/38 [==============================] - 1s 14ms/step - loss: 315.2990 - mae: 0.0447 - batch_ndcg: 0.7135 - val_loss: 272.5709 - val_mae: 0.0321 - val_batch_ndcg: 0.3771
# Epoch 3/4
# 38/38 [==============================] - 1s 14ms/step - loss: 301.9054 - mae: 0.0433 - batch_ndcg: 0.7246 - val_loss: 270.8207 - val_mae: 0.0324 - val_batch_ndcg: 0.3782
# Epoch 4/4
# 38/38 [==============================] - 1s 14ms/step - loss: 296.2644 - mae: 0.0422 - batch_ndcg: 0.7298 - val_loss: 265.4896 - val_mae: 0.0319 - val_batch_ndcg: 0.3764
# Epoch 1/4
# 38/38 [==============================] - 1s 14ms/step - loss: 407.8972 - mae: 0.0594 - batch_ndcg: 0.6376 - val_loss: 291.2774 - val_mae: 0.0342 - val_batch_ndcg: 0.3594
# Epoch 2/4
# 38/38 [==============================] - 1s 15ms/step - loss: 309.0950 - mae: 0.0439 - batch_ndcg: 0.7132 - val_loss: 278.2606 - val_mae: 0.0338 - val_batch_ndcg: 0.3753
# Epoch 3/4
# 38/38 [==============================] - 1s 14ms/step - loss: 303.1920 - mae: 0.0430 - batch_ndcg: 0.7258 - val_loss: 268.4587 - val_mae: 0.0323 - val_batch_ndcg: 0.3782
# Epoch 4/4
# 38/38 [==============================] - 1s 15ms/step - loss: 297.4583 - mae: 0.0421 - batch_ndcg: 0.7297 - val_loss: 261.9254 - val_mae: 0.0301 - val_batch_ndcg: 0.3910
# Epoch 1/4
# 38/38 [==============================] - 1s 14ms/step - loss: 393.2223 - mae: 0.0606 - batch_ndcg: 0.6350 - val_loss: 286.7472 - val_mae: 0.0351 - val_batch_ndcg: 0.3574
# Epoch 2/4
# 38/38 [==============================] - 1s 15ms/step - loss: 310.3222 - mae: 0.0442 - batch_ndcg: 0.7227 - val_loss: 274.6614 - val_mae: 0.0342 - val_batch_ndcg: 0.3692
# Epoch 3/4
# 38/38 [==============================] - 1s 14ms/step - loss: 297.8987 - mae: 0.0428 - batch_ndcg: 0.7254 - val_loss: 263.9864 - val_mae: 0.0309 - val_batch_ndcg: 0.3823
# Epoch 4/4
# 38/38 [==============================] - 1s 14ms/step - loss: 292.0697 - mae: 0.0416 - batch_ndcg: 0.7324 - val_loss: 260.1891 - val_mae: 0.0303 - val_batch_ndcg: 0.3786
# Epoch 1/4
# 38/38 [==============================] - 1s 14ms/step - loss: 391.2622 - mae: 0.0590 - batch_ndcg: 0.6455 - val_loss: 279.3459 - val_mae: 0.0323 - val_batch_ndcg: 0.3705
# Epoch 2/4
# 38/38 [==============================] - 1s 14ms/step - loss: 304.3217 - mae: 0.0433 - batch_ndcg: 0.7178 - val_loss: 265.9070 - val_mae: 0.0309 - val_batch_ndcg: 0.3748
# Epoch 3/4
# 38/38 [==============================] - 1s 14ms/step - loss: 295.1089 - mae: 0.0418 - batch_ndcg: 0.7285 - val_loss: 263.1653 - val_mae: 0.0311 - val_batch_ndcg: 0.3748
# Epoch 4/4
# 38/38 [==============================] - 1s 15ms/step - loss: 289.2682 - mae: 0.0412 - batch_ndcg: 0.7387 - val_loss: 259.2262 - val_mae: 0.0306 - val_batch_ndcg: 0.3796
# Epoch 1/4
# 38/38 [==============================] - 1s 15ms/step - loss: 392.7969 - mae: 0.0592 - batch_ndcg: 0.6520 - val_loss: 284.6946 - val_mae: 0.0339 - val_batch_ndcg: 0.3626
# Epoch 2/4
# 38/38 [==============================] - 1s 14ms/step - loss: 301.5600 - mae: 0.0434 - batch_ndcg: 0.7224 - val_loss: 267.6988 - val_mae: 0.0326 - val_batch_ndcg: 0.3732
# Epoch 3/4
# 38/38 [==============================] - 1s 14ms/step - loss: 295.4659 - mae: 0.0423 - batch_ndcg: 0.7313 - val_loss: 259.2808 - val_mae: 0.0308 - val_batch_ndcg: 0.3791
# Epoch 4/4
# 38/38 [==============================] - 1s 15ms/step - loss: 289.6248 - mae: 0.0414 - batch_ndcg: 0.7375 - val_loss: 257.2728 - val_mae: 0.0303 - val_batch_ndcg: 0.3851
# Epoch 1/4
# 38/38 [==============================] - 1s 15ms/step - loss: 403.3900 - mae: 0.0570 - batch_ndcg: 0.6452 - val_loss: 282.1380 - val_mae: 0.0318 - val_batch_ndcg: 0.3632
# Epoch 2/4
# 38/38 [==============================] - 1s 15ms/step - loss: 306.9589 - mae: 0.0438 - batch_ndcg: 0.7164 - val_loss: 270.2734 - val_mae: 0.0316 - val_batch_ndcg: 0.3712
# Epoch 3/4
# 38/38 [==============================] - 1s 14ms/step - loss: 291.9517 - mae: 0.0418 - batch_ndcg: 0.7293 - val_loss: 261.4966 - val_mae: 0.0302 - val_batch_ndcg: 0.3868
# Epoch 4/4
# 38/38 [==============================] - 1s 15ms/step - loss: 291.3763 - mae: 0.0413 - batch_ndcg: 0.7377 - val_loss: 256.4781 - val_mae: 0.0294 - val_batch_ndcg: 0.3760
# Epoch 1/4
# 38/38 [==============================] - 1s 15ms/step - loss: 392.2019 - mae: 0.0577 - batch_ndcg: 0.6442 - val_loss: 280.5889 - val_mae: 0.0332 - val_batch_ndcg: 0.3656
# Epoch 2/4
# 38/38 [==============================] - 1s 14ms/step - loss: 306.4084 - mae: 0.0439 - batch_ndcg: 0.7221 - val_loss: 264.5113 - val_mae: 0.0314 - val_batch_ndcg: 0.3748
# Epoch 3/4
# 38/38 [==============================] - 1s 14ms/step - loss: 292.0352 - mae: 0.0418 - batch_ndcg: 0.7276 - val_loss: 257.2674 - val_mae: 0.0300 - val_batch_ndcg: 0.3779
# Epoch 4/4
# 38/38 [==============================] - 1s 15ms/step - loss: 287.8723 - mae: 0.0410 - batch_ndcg: 0.7359 - val_loss: 256.3657 - val_mae: 0.0303 - val_batch_ndcg: 0.3798
# Epoch 1/4
# 38/38 [==============================] - 1s 14ms/step - loss: 388.4041 - mae: 0.0578 - batch_ndcg: 0.6413 - val_loss: 280.3281 - val_mae: 0.0330 - val_batch_ndcg: 0.3615
# Epoch 2/4
# 38/38 [==============================] - 1s 14ms/step - loss: 305.0461 - mae: 0.0439 - batch_ndcg: 0.7252 - val_loss: 267.0872 - val_mae: 0.0323 - val_batch_ndcg: 0.3745
# Epoch 3/4
# 38/38 [==============================] - 1s 15ms/step - loss: 286.8289 - mae: 0.0413 - batch_ndcg: 0.7276 - val_loss: 259.1739 - val_mae: 0.0302 - val_batch_ndcg: 0.3834
# Epoch 4/4
# 38/38 [==============================] - 1s 14ms/step - loss: 285.3528 - mae: 0.0408 - batch_ndcg: 0.7338 - val_loss: 253.8282 - val_mae: 0.0294 - val_batch_ndcg: 0.3849
# Epoch 1/4
# 38/38 [==============================] - 1s 14ms/step - loss: 380.2939 - mae: 0.0571 - batch_ndcg: 0.6503 - val_loss: 277.2209 - val_mae: 0.0328 - val_batch_ndcg: 0.3727
# Epoch 2/4
# 38/38 [==============================] - 1s 15ms/step - loss: 301.8881 - mae: 0.0434 - batch_ndcg: 0.7287 - val_loss: 264.7533 - val_mae: 0.0320 - val_batch_ndcg: 0.3765
# Epoch 3/4
# 38/38 [==============================] - 1s 15ms/step - loss: 298.2850 - mae: 0.0429 - batch_ndcg: 0.7348 - val_loss: 260.2911 - val_mae: 0.0306 - val_batch_ndcg: 0.3799
# Epoch 4/4
# 38/38 [==============================] - 1s 14ms/step - loss: 285.7592 - mae: 0.0408 - batch_ndcg: 0.7395 - val_loss: 256.7964 - val_mae: 0.0303 - val_batch_ndcg: 0.3841
# Epoch 1/4
# 38/38 [==============================] - 1s 15ms/step - loss: 383.2581 - mae: 0.0560 - batch_ndcg: 0.6505 - val_loss: 274.4408 - val_mae: 0.0315 - val_batch_ndcg: 0.3682
# Epoch 2/4
# 38/38 [==============================] - 1s 14ms/step - loss: 303.1288 - mae: 0.0439 - batch_ndcg: 0.7300 - val_loss: 262.5032 - val_mae: 0.0310 - val_batch_ndcg: 0.3752
# Epoch 3/4
# 38/38 [==============================] - 1s 15ms/step - loss: 290.7362 - mae: 0.0419 - batch_ndcg: 0.7345 - val_loss: 257.6902 - val_mae: 0.0302 - val_batch_ndcg: 0.3843
# Epoch 4/4
# 38/38 [==============================] - 1s 14ms/step - loss: 288.9911 - mae: 0.0413 - batch_ndcg: 0.7404 - val_loss: 254.8557 - val_mae: 0.0296 - val_batch_ndcg: 0.3881
# Epoch 1/4
# 38/38 [==============================] - 1s 15ms/step - loss: 378.9250 - mae: 0.0546 - batch_ndcg: 0.6495 - val_loss: 270.8059 - val_mae: 0.0307 - val_batch_ndcg: 0.3696
# Epoch 2/4
# 38/38 [==============================] - 1s 15ms/step - loss: 301.9884 - mae: 0.0432 - batch_ndcg: 0.7226 - val_loss: 260.8015 - val_mae: 0.0301 - val_batch_ndcg: 0.3720
# Epoch 3/4
# 38/38 [==============================] - 1s 15ms/step - loss: 295.3452 - mae: 0.0421 - batch_ndcg: 0.7370 - val_loss: 256.6138 - val_mae: 0.0297 - val_batch_ndcg: 0.3796
# Epoch 4/4
# 38/38 [==============================] - 1s 15ms/step - loss: 285.9911 - mae: 0.0406 - batch_ndcg: 0.7388 - val_loss: 253.7090 - val_mae: 0.0288 - val_batch_ndcg: 0.3836
# Epoch 1/4
# 38/38 [==============================] - 1s 15ms/step - loss: 372.1024 - mae: 0.0551 - batch_ndcg: 0.6506 - val_loss: 273.8399 - val_mae: 0.0318 - val_batch_ndcg: 0.3747
# Epoch 2/4
# 38/38 [==============================] - 1s 14ms/step - loss: 293.8875 - mae: 0.0419 - batch_ndcg: 0.7224 - val_loss: 262.2928 - val_mae: 0.0312 - val_batch_ndcg: 0.3771
# Epoch 3/4
# 38/38 [==============================] - 1s 14ms/step - loss: 288.3276 - mae: 0.0414 - batch_ndcg: 0.7389 - val_loss: 257.7834 - val_mae: 0.0300 - val_batch_ndcg: 0.3766
# Epoch 4/4
# 38/38 [==============================] - 1s 14ms/step - loss: 285.2621 - mae: 0.0407 - batch_ndcg: 0.7378 - val_loss: 253.7869 - val_mae: 0.0293 - val_batch_ndcg: 0.3862
# Epoch 1/4
# 38/38 [==============================] - 1s 15ms/step - loss: 384.7957 - mae: 0.0547 - batch_ndcg: 0.6471 - val_loss: 274.9433 - val_mae: 0.0319 - val_batch_ndcg: 0.3640
# Epoch 2/4
# 38/38 [==============================] - 1s 15ms/step - loss: 303.7791 - mae: 0.0433 - batch_ndcg: 0.7230 - val_loss: 263.7108 - val_mae: 0.0320 - val_batch_ndcg: 0.3732
# Epoch 3/4
# 38/38 [==============================] - 1s 15ms/step - loss: 290.1729 - mae: 0.0415 - batch_ndcg: 0.7327 - val_loss: 257.7779 - val_mae: 0.0303 - val_batch_ndcg: 0.3805
# Epoch 4/4
# 38/38 [==============================] - 1s 14ms/step - loss: 291.7576 - mae: 0.0417 - batch_ndcg: 0.7425 - val_loss: 253.9253 - val_mae: 0.0296 - val_batch_ndcg: 0.3792
# Epoch 1/4
# 38/38 [==============================] - 1s 15ms/step - loss: 369.3914 - mae: 0.0548 - batch_ndcg: 0.6460 - val_loss: 271.7082 - val_mae: 0.0308 - val_batch_ndcg: 0.3674
# Epoch 2/4
# 38/38 [==============================] - 1s 15ms/step - loss: 297.6127 - mae: 0.0426 - batch_ndcg: 0.7280 - val_loss: 263.5670 - val_mae: 0.0310 - val_batch_ndcg: 0.3775
# Epoch 3/4
# 38/38 [==============================] - 1s 14ms/step - loss: 287.4415 - mae: 0.0412 - batch_ndcg: 0.7351 - val_loss: 255.5907 - val_mae: 0.0298 - val_batch_ndcg: 0.3759
# Epoch 4/4
# 38/38 [==============================] - 1s 15ms/step - loss: 291.5381 - mae: 0.0417 - batch_ndcg: 0.7430 - val_loss: 254.1607 - val_mae: 0.0294 - val_batch_ndcg: 0.3883
# Epoch 1/4
# 38/38 [==============================] - 1s 15ms/step - loss: 363.5030 - mae: 0.0542 - batch_ndcg: 0.6540 - val_loss: 270.7193 - val_mae: 0.0316 - val_batch_ndcg: 0.3665
# Epoch 2/4
# 38/38 [==============================] - 1s 15ms/step - loss: 301.4885 - mae: 0.0438 - batch_ndcg: 0.7270 - val_loss: 256.8207 - val_mae: 0.0297 - val_batch_ndcg: 0.3839
# Epoch 3/4
# 38/38 [==============================] - 1s 14ms/step - loss: 289.0066 - mae: 0.0417 - batch_ndcg: 0.7360 - val_loss: 253.2456 - val_mae: 0.0299 - val_batch_ndcg: 0.3850
# Epoch 4/4
# 38/38 [==============================] - 1s 15ms/step - loss: 280.8720 - mae: 0.0404 - batch_ndcg: 0.7429 - val_loss: 249.4216 - val_mae: 0.0288 - val_batch_ndcg: 0.3863
# Epoch 1/4
# 38/38 [==============================] - 1s 15ms/step - loss: 366.0413 - mae: 0.0538 - batch_ndcg: 0.6493 - val_loss: 272.6833 - val_mae: 0.0327 - val_batch_ndcg: 0.3719
# Epoch 2/4
# 38/38 [==============================] - 1s 15ms/step - loss: 293.3613 - mae: 0.0423 - batch_ndcg: 0.7293 - val_loss: 259.2181 - val_mae: 0.0309 - val_batch_ndcg: 0.3790
# Epoch 3/4
# 38/38 [==============================] - 1s 15ms/step - loss: 289.3042 - mae: 0.0418 - batch_ndcg: 0.7363 - val_loss: 255.4626 - val_mae: 0.0303 - val_batch_ndcg: 0.3826
# Epoch 4/4
# 38/38 [==============================] - 1s 15ms/step - loss: 279.2842 - mae: 0.0403 - batch_ndcg: 0.7409 - val_loss: 251.2526 - val_mae: 0.0294 - val_batch_ndcg: 0.3909
# Epoch 1/4
# 38/38 [==============================] - 1s 15ms/step - loss: 368.8261 - mae: 0.0536 - batch_ndcg: 0.6573 - val_loss: 267.3750 - val_mae: 0.0307 - val_batch_ndcg: 0.3657
# Epoch 2/4
# 38/38 [==============================] - 1s 14ms/step - loss: 286.7889 - mae: 0.0411 - batch_ndcg: 0.7243 - val_loss: 254.9630 - val_mae: 0.0296 - val_batch_ndcg: 0.3806
# Epoch 3/4
# 38/38 [==============================] - 1s 14ms/step - loss: 284.3646 - mae: 0.0407 - batch_ndcg: 0.7400 - val_loss: 253.1064 - val_mae: 0.0302 - val_batch_ndcg: 0.3814
# Epoch 4/4
# 38/38 [==============================] - 1s 14ms/step - loss: 279.0746 - mae: 0.0401 - batch_ndcg: 0.7431 - val_loss: 249.6997 - val_mae: 0.0289 - val_batch_ndcg: 0.3810
# Epoch 1/4
# 38/38 [==============================] - 1s 15ms/step - loss: 368.1785 - mae: 0.0518 - batch_ndcg: 0.6518 - val_loss: 269.4189 - val_mae: 0.0295 - val_batch_ndcg: 0.3698
# Epoch 2/4
# 38/38 [==============================] - 1s 14ms/step - loss: 302.6188 - mae: 0.0429 - batch_ndcg: 0.7287 - val_loss: 258.0701 - val_mae: 0.0302 - val_batch_ndcg: 0.3742
# Epoch 3/4
# 38/38 [==============================] - 1s 15ms/step - loss: 287.1432 - mae: 0.0412 - batch_ndcg: 0.7371 - val_loss: 253.5728 - val_mae: 0.0296 - val_batch_ndcg: 0.3813
# Epoch 4/4
# ...
# Epoch 1/4
# 38/38 [==============================] - 1s 16ms/step - loss: 338.4274 - mae: 0.0491 - batch_ndcg: 0.6704 - val_loss: 255.4879 - val_mae: 0.0300 - val_batch_ndcg: 0.3723
# Epoch 2/4
# 38/38 [==============================] - 1s 16ms/step - loss: 285.5430 - mae: 0.0413 - batch_ndcg: 0.7377 - val_loss: 247.4267 - val_mae: 0.0295 - val_batch_ndcg: 0.3846
# Epoch 3/4
# 38/38 [==============================] - 1s 16ms/step - loss: 268.2078 - mae: 0.0386 - batch_ndcg: 0.7469 - val_loss: 243.1548 - val_mae: 0.0282 - val_batch_ndcg: 0.3861
# Epoch 4/4
# 38/38 [==============================] - 1s 15ms/step - loss: 271.3430 - mae: 0.0388 - batch_ndcg: 0.7554 - val_loss: 239.4503 - val_mae: 0.0275 - val_batch_ndcg: 0.3875
# Epoch 1/4
# 38/38 [==============================] - 1s 16ms/step - loss: 333.9721 - mae: 0.0480 - batch_ndcg: 0.6644 - val_loss: 254.9778 - val_mae: 0.0299 - val_batch_ndcg: 0.3801
# Epoch 2/4
# 38/38 [==============================] - 1s 17ms/step - loss: 275.3793 - mae: 0.0395 - batch_ndcg: 0.7354 - val_loss: 249.4646 - val_mae: 0.0294 - val_batch_ndcg: 0.3824
# Epoch 3/4
# 38/38 [==============================] - 1s 15ms/step - loss: 274.0363 - mae: 0.0395 - batch_ndcg: 0.7539 - val_loss: 244.1461 - val_mae: 0.0284 - val_batch_ndcg: 0.3898
# Epoch 4/4
# 38/38 [==============================] - 1s 16ms/step - loss: 273.7126 - mae: 0.0394 - batch_ndcg: 0.7603 - val_loss: 240.0056 - val_mae: 0.0282 - val_batch_ndcg: 0.3870
# Epoch 1/4
# 38/38 [==============================] - 1s 16ms/step - loss: 333.2955 - mae: 0.0484 - batch_ndcg: 0.6668 - val_loss: 254.9861 - val_mae: 0.0298 - val_batch_ndcg: 0.3774
# Epoch 2/4
# 38/38 [==============================] - 1s 16ms/step - loss: 283.3004 - mae: 0.0408 - batch_ndcg: 0.7387 - val_loss: 244.5276 - val_mae: 0.0284 - val_batch_ndcg: 0.3833
# Epoch 3/4
# 38/38 [==============================] - 1s 15ms/step - loss: 277.5766 - mae: 0.0401 - batch_ndcg: 0.7544 - val_loss: 240.3781 - val_mae: 0.0274 - val_batch_ndcg: 0.3910
# Epoch 4/4
# 38/38 [==============================] - 1s 15ms/step - loss: 270.3668 - mae: 0.0388 - batch_ndcg: 0.7621 - val_loss: 238.0667 - val_mae: 0.0270 - val_batch_ndcg: 0.3880
# Epoch 1/4
# 38/38 [==============================] - 1s 16ms/step - loss: 331.6641 - mae: 0.0477 - batch_ndcg: 0.6772 - val_loss: 254.2774 - val_mae: 0.0302 - val_batch_ndcg: 0.3702
# Epoch 2/4
# 38/38 [==============================] - 1s 15ms/step - loss: 279.6991 - mae: 0.0406 - batch_ndcg: 0.7434 - val_loss: 245.3564 - val_mae: 0.0282 - val_batch_ndcg: 0.3854
# Epoch 3/4
# 38/38 [==============================] - 1s 15ms/step - loss: 279.2966 - mae: 0.0403 - batch_ndcg: 0.7565 - val_loss: 240.5940 - val_mae: 0.0279 - val_batch_ndcg: 0.3852
# Epoch 4/4
# 38/38 [==============================] - 1s 16ms/step - loss: 273.9384 - mae: 0.0396 - batch_ndcg: 0.7587 - val_loss: 238.4066 - val_mae: 0.0275 - val_batch_ndcg: 0.3902
# Epoch 1/4
# 38/38 [==============================] - 1s 16ms/step - loss: 333.8451 - mae: 0.0482 - batch_ndcg: 0.6740 - val_loss: 251.7086 - val_mae: 0.0304 - val_batch_ndcg: 0.3728
# Epoch 2/4
# 38/38 [==============================] - 1s 15ms/step - loss: 284.8837 - mae: 0.0414 - batch_ndcg: 0.7468 - val_loss: 242.3338 - val_mae: 0.0280 - val_batch_ndcg: 0.3821
# Epoch 3/4
# 38/38 [==============================] - 1s 15ms/step - loss: 271.6473 - mae: 0.0393 - batch_ndcg: 0.7563 - val_loss: 240.9612 - val_mae: 0.0280 - val_batch_ndcg: 0.3927
# Epoch 4/4
# 38/38 [==============================] - 1s 15ms/step - loss: 269.3199 - mae: 0.0390 - batch_ndcg: 0.7648 - val_loss: 237.3388 - val_mae: 0.0273 - val_batch_ndcg: 0.3939
# Epoch 1/4
# 38/38 [==============================] - 1s 15ms/step - loss: 331.9218 - mae: 0.0468 - batch_ndcg: 0.6654 - val_loss: 250.7429 - val_mae: 0.0284 - val_batch_ndcg: 0.3754
# Epoch 2/4
# 38/38 [==============================] - 1s 15ms/step - loss: 284.7502 - mae: 0.0410 - batch_ndcg: 0.7471 - val_loss: 244.5686 - val_mae: 0.0278 - val_batch_ndcg: 0.3912
# Epoch 3/4
# 38/38 [==============================] - 1s 14ms/step - loss: 271.6598 - mae: 0.0390 - batch_ndcg: 0.7487 - val_loss: 239.9823 - val_mae: 0.0276 - val_batch_ndcg: 0.3916
# Epoch 4/4
# 38/38 [==============================] - 1s 15ms/step - loss: 266.4400 - mae: 0.0382 - batch_ndcg: 0.7618 - val_loss: 237.8085 - val_mae: 0.0265 - val_batch_ndcg: 0.3946
# Epoch 1/4
# 38/38 [==============================] - 1s 15ms/step - loss: 329.1326 - mae: 0.0473 - batch_ndcg: 0.6679 - val_loss: 251.2629 - val_mae: 0.0299 - val_batch_ndcg: 0.3763
# Epoch 2/4
# 38/38 [==============================] - 1s 15ms/step - loss: 279.1245 - mae: 0.0405 - batch_ndcg: 0.7483 - val_loss: 242.0439 - val_mae: 0.0276 - val_batch_ndcg: 0.3920
# Epoch 3/4
# 38/38 [==============================] - 1s 15ms/step - loss: 264.6982 - mae: 0.0384 - batch_ndcg: 0.7530 - val_loss: 239.3933 - val_mae: 0.0277 - val_batch_ndcg: 0.3889
# Epoch 4/4
# 38/38 [==============================] - 1s 15ms/step - loss: 266.5280 - mae: 0.0383 - batch_ndcg: 0.7640 - val_loss: 237.7751 - val_mae: 0.0277 - val_batch_ndcg: 0.3907
# Epoch 1/4
# 38/38 [==============================] - 1s 15ms/step - loss: 331.5008 - mae: 0.0472 - batch_ndcg: 0.6745 - val_loss: 252.2891 - val_mae: 0.0295 - val_batch_ndcg: 0.3761
# Epoch 2/4
# 38/38 [==============================] - 1s 15ms/step - loss: 275.1681 - mae: 0.0397 - batch_ndcg: 0.7416 - val_loss: 243.7873 - val_mae: 0.0282 - val_batch_ndcg: 0.3803
# Epoch 3/4
# 38/38 [==============================] - 1s 14ms/step - loss: 268.9561 - mae: 0.0388 - batch_ndcg: 0.7559 - val_loss: 241.1626 - val_mae: 0.0282 - val_batch_ndcg: 0.3909
# Epoch 4/4
# 38/38 [==============================] - 1s 15ms/step - loss: 266.5563 - mae: 0.0384 - batch_ndcg: 0.7617 - val_loss: 237.6890 - val_mae: 0.0277 - val_batch_ndcg: 0.3996
# Epoch 1/4
# 38/38 [==============================] - 1s 16ms/step - loss: 324.5772 - mae: 0.0470 - batch_ndcg: 0.6717 - val_loss: 249.2292 - val_mae: 0.0299 - val_batch_ndcg: 0.3784
# Epoch 2/4
# 38/38 [==============================] - 1s 15ms/step - loss: 279.7239 - mae: 0.0406 - batch_ndcg: 0.7463 - val_loss: 242.9455 - val_mae: 0.0284 - val_batch_ndcg: 0.3848
# Epoch 3/4
# 38/38 [==============================] - 1s 14ms/step - loss: 262.7517 - mae: 0.0380 - batch_ndcg: 0.7522 - val_loss: 238.2600 - val_mae: 0.0279 - val_batch_ndcg: 0.3896
# Epoch 4/4
# 38/38 [==============================] - 1s 15ms/step - loss: 268.8058 - mae: 0.0389 - batch_ndcg: 0.7671 - val_loss: 235.6369 - val_mae: 0.0269 - val_batch_ndcg: 0.3948
# Epoch 1/4
# 38/38 [==============================] - 1s 16ms/step - loss: 330.2193 - mae: 0.0473 - batch_ndcg: 0.6712 - val_loss: 248.5682 - val_mae: 0.0295 - val_batch_ndcg: 0.3817
# Epoch 2/4
# 38/38 [==============================] - 1s 15ms/step - loss: 276.2579 - mae: 0.0401 - batch_ndcg: 0.7487 - val_loss: 240.1207 - val_mae: 0.0275 - val_batch_ndcg: 0.3812
# Epoch 3/4
# 38/38 [==============================] - 1s 15ms/step - loss: 267.1290 - mae: 0.0386 - batch_ndcg: 0.7560 - val_loss: 236.2340 - val_mae: 0.0269 - val_batch_ndcg: 0.3949
# Epoch 4/4
# 38/38 [==============================] - 1s 15ms/step - loss: 262.2675 - mae: 0.0378 - batch_ndcg: 0.7653 - val_loss: 234.8430 - val_mae: 0.0267 - val_batch_ndcg: 0.3941
# Epoch 1/4
# 38/38 [==============================] - 1s 15ms/step - loss: 328.8896 - mae: 0.0465 - batch_ndcg: 0.6673 - val_loss: 248.9614 - val_mae: 0.0285 - val_batch_ndcg: 0.3826
# Epoch 2/4
# 38/38 [==============================] - 1s 15ms/step - loss: 273.0121 - mae: 0.0393 - batch_ndcg: 0.7416 - val_loss: 241.2100 - val_mae: 0.0276 - val_batch_ndcg: 0.3869
# Epoch 3/4
# 38/38 [==============================] - 1s 15ms/step - loss: 271.8502 - mae: 0.0390 - batch_ndcg: 0.7615 - val_loss: 237.9280 - val_mae: 0.0273 - val_batch_ndcg: 0.3905
# Epoch 4/4
# 38/38 [==============================] - 1s 15ms/step - loss: 266.4882 - mae: 0.0383 - batch_ndcg: 0.7660 - val_loss: 236.0072 - val_mae: 0.0276 - val_batch_ndcg: 0.3903
# Epoch 1/4
# 38/38 [==============================] - 1s 16ms/step - loss: 330.5288 - mae: 0.0467 - batch_ndcg: 0.6754 - val_loss: 249.9824 - val_mae: 0.0294 - val_batch_ndcg: 0.3795
# Epoch 2/4
# 38/38 [==============================] - 1s 15ms/step - loss: 280.9146 - mae: 0.0407 - batch_ndcg: 0.7477 - val_loss: 240.6083 - val_mae: 0.0275 - val_batch_ndcg: 0.3867
# Epoch 3/4
# 38/38 [==============================] - 1s 15ms/step - loss: 268.3518 - mae: 0.0389 - batch_ndcg: 0.7541 - val_loss: 237.0759 - val_mae: 0.0273 - val_batch_ndcg: 0.3857
# Epoch 4/4
# 38/38 [==============================] - 1s 15ms/step - loss: 256.1051 - mae: 0.0369 - batch_ndcg: 0.7671 - val_loss: 235.2427 - val_mae: 0.0267 - val_batch_ndcg: 0.3924
# Epoch 1/4
# 38/38 [==============================] - 1s 15ms/step - loss: 319.3720 - mae: 0.0458 - batch_ndcg: 0.6725 - val_loss: 248.6338 - val_mae: 0.0291 - val_batch_ndcg: 0.3825
# Epoch 2/4
# 38/38 [==============================] - 1s 15ms/step - loss: 267.3313 - mae: 0.0386 - batch_ndcg: 0.7463 - val_loss: 240.2572 - val_mae: 0.0282 - val_batch_ndcg: 0.3822
# Epoch 3/4
# 38/38 [==============================] - 1s 15ms/step - loss: 266.7067 - mae: 0.0386 - batch_ndcg: 0.7594 - val_loss: 235.6579 - val_mae: 0.0274 - val_batch_ndcg: 0.3900
# Epoch 4/4
# 38/38 [==============================] - 1s 15ms/step - loss: 258.0330 - mae: 0.0371 - batch_ndcg: 0.7663 - val_loss: 232.3025 - val_mae: 0.0260 - val_batch_ndcg: 0.3967
# Epoch 1/4
# 38/38 [==============================] - 1s 15ms/step - loss: 320.6270 - mae: 0.0462 - batch_ndcg: 0.6768 - val_loss: 246.2227 - val_mae: 0.0287 - val_batch_ndcg: 0.3751
# Epoch 2/4
# 38/38 [==============================] - 1s 15ms/step - loss: 271.2140 - mae: 0.0394 - batch_ndcg: 0.7496 - val_loss: 238.3948 - val_mae: 0.0281 - val_batch_ndcg: 0.3905
# Epoch 3/4
# 38/38 [==============================] - 1s 15ms/step - loss: 266.7856 - mae: 0.0388 - batch_ndcg: 0.7629 - val_loss: 235.9819 - val_mae: 0.0275 - val_batch_ndcg: 0.3935
# Epoch 4/4
# 38/38 [==============================] - 1s 15ms/step - loss: 261.1375 - mae: 0.0378 - batch_ndcg: 0.7728 - val_loss: 232.8194 - val_mae: 0.0271 - val_batch_ndcg: 0.3914
# Epoch 1/4
# 38/38 [==============================] - 1s 15ms/step - loss: 323.3228 - mae: 0.0459 - batch_ndcg: 0.6779 - val_loss: 245.8663 - val_mae: 0.0287 - val_batch_ndcg: 0.3804
# Epoch 2/4
# 38/38 [==============================] - 1s 15ms/step - loss: 271.8794 - mae: 0.0395 - batch_ndcg: 0.7478 - val_loss: 237.9029 - val_mae: 0.0278 - val_batch_ndcg: 0.3935
# Epoch 3/4
# 38/38 [==============================] - 1s 15ms/step - loss: 261.6147 - mae: 0.0378 - batch_ndcg: 0.7629 - val_loss: 235.2200 - val_mae: 0.0273 - val_batch_ndcg: 0.3886
# Epoch 4/4
# 38/38 [==============================] - 1s 15ms/step - loss: 260.0933 - mae: 0.0374 - batch_ndcg: 0.7687 - val_loss: 232.4799 - val_mae: 0.0269 - val_batch_ndcg: 0.4004
# Epoch 1/4
# 38/38 [==============================] - 1s 15ms/step - loss: 314.8082 - mae: 0.0456 - batch_ndcg: 0.6718 - val_loss: 242.1469 - val_mae: 0.0269 - val_batch_ndcg: 0.3810
# Epoch 2/4
# 38/38 [==============================] - 1s 14ms/step - loss: 268.8240 - mae: 0.0387 - batch_ndcg: 0.7544 - val_loss: 237.2588 - val_mae: 0.0282 - val_batch_ndcg: 0.3818
# Epoch 3/4
# 38/38 [==============================] - 1s 15ms/step - loss: 263.7632 - mae: 0.0383 - batch_ndcg: 0.7676 - val_loss: 234.9013 - val_mae: 0.0271 - val_batch_ndcg: 0.3952
# Epoch 4/4
# 38/38 [==============================] - 1s 15ms/step - loss: 255.7756 - mae: 0.0372 - batch_ndcg: 0.7690 - val_loss: 231.7262 - val_mae: 0.0261 - val_batch_ndcg: 0.4011
# Epoch 1/4
# 38/38 [==============================] - 1s 16ms/step - loss: 315.8045 - mae: 0.0456 - batch_ndcg: 0.6815 - val_loss: 244.3350 - val_mae: 0.0282 - val_batch_ndcg: 0.3752
# Epoch 2/4
# 38/38 [==============================] - 1s 15ms/step - loss: 266.8631 - mae: 0.0386 - batch_ndcg: 0.7528 - val_loss: 236.9005 - val_mae: 0.0274 - val_batch_ndcg: 0.3847
# Epoch 3/4
# 38/38 [==============================] - 1s 15ms/step - loss: 262.8448 - mae: 0.0381 - batch_ndcg: 0.7683 - val_loss: 233.5263 - val_mae: 0.0267 - val_batch_ndcg: 0.3927
# Epoch 4/4
# 38/38 [==============================] - 1s 15ms/step - loss: 258.8614 - mae: 0.0377 - batch_ndcg: 0.7696 - val_loss: 231.3824 - val_mae: 0.0261 - val_batch_ndcg: 0.3956
# Epoch 1/4
# 38/38 [==============================] - 1s 15ms/step - loss: 322.5657 - mae: 0.0456 - batch_ndcg: 0.6822 - val_loss: 244.4251 - val_mae: 0.0282 - val_batch_ndcg: 0.3814
# Epoch 2/4
# 38/38 [==============================] - 1s 15ms/step - loss: 265.6584 - mae: 0.0382 - batch_ndcg: 0.7513 - val_loss: 237.8936 - val_mae: 0.0270 - val_batch_ndcg: 0.3887
# Epoch 3/4
# 38/38 [==============================] - 1s 15ms/step - loss: 261.5964 - mae: 0.0378 - batch_ndcg: 0.7651 - val_loss: 233.8732 - val_mae: 0.0268 - val_batch_ndcg: 0.3916
# Epoch 4/4
# 38/38 [==============================] - 1s 15ms/step - loss: 258.4943 - mae: 0.0374 - batch_ndcg: 0.7707 - val_loss: 231.3956 - val_mae: 0.0254 - val_batch_ndcg: 0.3957
# Epoch 1/4
# 38/38 [==============================] - 1s 16ms/step - loss: 316.6632 - mae: 0.0455 - batch_ndcg: 0.6802 - val_loss: 242.6237 - val_mae: 0.0269 - val_batch_ndcg: 0.3825
# Epoch 2/4
# 38/38 [==============================] - 1s 15ms/step - loss: 275.4177 - mae: 0.0399 - batch_ndcg: 0.7632 - val_loss: 235.3942 - val_mae: 0.0276 - val_batch_ndcg: 0.3939
# Epoch 3/4
# 38/38 [==============================] - 1s 15ms/step - loss: 265.2143 - mae: 0.0385 - batch_ndcg: 0.7663 - val_loss: 233.3310 - val_mae: 0.0268 - val_batch_ndcg: 0.3925
# Epoch 4/4
# 38/38 [==============================] - 1s 15ms/step - loss: 259.3015 - mae: 0.0376 - batch_ndcg: 0.7771 - val_loss: 230.7089 - val_mae: 0.0261 - val_batch_ndcg: 0.4007
# Epoch 1/4
# 38/38 [==============================] - 1s 15ms/step - loss: 315.7600 - mae: 0.0451 - batch_ndcg: 0.6814 - val_loss: 242.2634 - val_mae: 0.0276 - val_batch_ndcg: 0.3854
# Epoch 2/4
# 38/38 [==============================] - 1s 14ms/step - loss: 261.2126 - mae: 0.0377 - batch_ndcg: 0.7518 - val_loss: 235.7911 - val_mae: 0.0269 - val_batch_ndcg: 0.3901
# Epoch 3/4
# 38/38 [==============================] - 1s 16ms/step - loss: 260.2018 - mae: 0.0377 - batch_ndcg: 0.7668 - val_loss: 231.8856 - val_mae: 0.0264 - val_batch_ndcg: 0.3954
# Epoch 4/4
# 38/38 [==============================] - 1s 15ms/step - loss: 259.4986 - mae: 0.0376 - batch_ndcg: 0.7747 - val_loss: 231.4774 - val_mae: 0.0264 - val_batch_ndcg: 0.3906
# Epoch 1/4
# 38/38 [==============================] - 1s 15ms/step - loss: 312.7382 - mae: 0.0447 - batch_ndcg: 0.6777 - val_loss: 242.9994 - val_mae: 0.0274 - val_batch_ndcg: 0.3761
# Epoch 2/4
# 38/38 [==============================] - 1s 15ms/step - loss: 264.5669 - mae: 0.0382 - batch_ndcg: 0.7548 - val_loss: 234.7083 - val_mae: 0.0271 - val_batch_ndcg: 0.3926
# Epoch 3/4
# 38/38 [==============================] - 1s 15ms/step - loss: 258.3630 - mae: 0.0374 - batch_ndcg: 0.7640 - val_loss: 230.7731 - val_mae: 0.0262 - val_batch_ndcg: 0.4031
# Epoch 4/4
# 38/38 [==============================] - 1s 14ms/step - loss: 254.6405 - mae: 0.0368 - batch_ndcg: 0.7758 - val_loss: 230.8310 - val_mae: 0.0266 - val_batch_ndcg: 0.3936
# Epoch 1/4
# 38/38 [==============================] - 1s 15ms/step - loss: 317.2249 - mae: 0.0453 - batch_ndcg: 0.6827 - val_loss: 240.3921 - val_mae: 0.0266 - val_batch_ndcg: 0.3817
# Epoch 2/4
# 38/38 [==============================] - 1s 16ms/step - loss: 266.0834 - mae: 0.0383 - batch_ndcg: 0.7570 - val_loss: 234.8623 - val_mae: 0.0268 - val_batch_ndcg: 0.3911
# Epoch 3/4
# 38/38 [==============================] - 1s 16ms/step - loss: 262.7997 - mae: 0.0380 - batch_ndcg: 0.7698 - val_loss: 232.7530 - val_mae: 0.0271 - val_batch_ndcg: 0.3914
# Epoch 4/4
# 38/38 [==============================] - 1s 16ms/step - loss: 250.4999 - mae: 0.0361 - batch_ndcg: 0.7690 - val_loss: 228.9309 - val_mae: 0.0259 - val_batch_ndcg: 0.3906
# CPU times: user 9min 57s, sys: 40.9 s, total: 10min 38s
# Wall time: 7min 48s

# %%
show_history(total_hist, 'loss', 'batch_ndcg')

# %%
pred = test_predictor(test_q, model, n_item, batch_size)
pred
# Out:
# array([[  27,   23,   10, ...,  690,  280, 1528],
#        [  33,   46,   22, ..., 1769,  528, 1021],
#        [ 128,  788,  167, ...,  541,   40,  515],
#        ...,
#        [ 104,  184,   68, ..., 2715,  315, 2587],
#        [ 420,  134,  104, ...,  559,  733,  174],
#        [  44,  127,  217, ...,  546,  215,  643]])

# %%
m_ndcg, m_recall, m_precision, map_k = evaluation(test_a, pred)
print(f'nDCG: {m_ndcg:.5f}',
      f'\nRecall: {m_recall:.5f}',
      f'\nPrecision: {m_precision:.5f}',
      f'\nMAP: {map_k:.5f}')
# Out:
# nDCG: 0.52445
# Recall: 0.20401
# Precision: 0.17194
# MAP: 0.13638

# %% [markdown]
# ### 3. Mult-DAE

# %%
def DAE(n_user: int,
        n_item: int,
        latent_dim = 200,
        activation = 'tanh',
        optimizer = 'adam',
        dropout_rate = 0.5,
        kernel_initializer = None,
        kernel_regularizer = None) -> Callable:

    if not kernel_initializer:
        kernel_initializer = RandomNormal(mean = 0.0, stddev = 0.05, seed = None)
    if not kernel_regularizer:
        kernel_regularizer = l2(0.0001)
    
    inputs = x = Input(shape = (n_item, ), name = 'input')
    x = Dropout(dropout_rate)(x)
    x = Dense(latent_dim, activation = activation, kernel_initializer = kernel_initializer, kernel_regularizer = kernel_regularizer, name = 'encoder')(x)
    outputs = Dense(n_item, activation = 'softmax', kernel_initializer = kernel_initializer, kernel_regularizer = kernel_regularizer, name = 'decoder')(x)
    model = Model(inputs = inputs, outputs = outputs)

    model.compile(optimizer = optimizer, loss = log_loss, metrics = batch_ndcg)
    return model

# %%
optimizer = Adam(learning_rate = 0.001, decay = 1e-5)
model = DAE(n_user, n_item, latent_dim = 200, optimizer = optimizer)
model.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 3706)]            0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 3706)              0
# _________________________________________________________________
# encoder (Dense)              (None, 200)               741400
# _________________________________________________________________
# decoder (Dense)              (None, 3706)              744906
# =================================================================
# Total params: 1,486,306
# Trainable params: 1,486,306
# Non-trainable params: 0
# _________________________________________________________________

# %%
# %%time
epochs = 100
early_stopping = EarlyStopping(monitor = 'val_batch_ndcg', mode = 'max', verbose = 1, patience = 10)
model_checkpoint = ModelCheckpoint(f'Mult-DAE.h5', monitor = 'val_batch_ndcg', mode = 'max', save_best_only = True)
hist = model.fit(x = train_gen, validation_data = valid_gen, epochs = epochs,
                 steps_per_epoch = steps_per_epoch, validation_steps = validation_steps,
                 verbose = 1, callbacks = [early_stopping, model_checkpoint])
# Out:
# Epoch 1/100
# 38/38 [==============================] - 1s 19ms/step - loss: 734.9910 - batch_ndcg: 0.5771 - val_loss: 131.7676 - val_batch_ndcg: 0.3630
# Epoch 2/100
# 38/38 [==============================] - 1s 15ms/step - loss: 677.7012 - batch_ndcg: 0.7495 - val_loss: 128.8355 - val_batch_ndcg: 0.3856
# Epoch 3/100
# 38/38 [==============================] - 1s 14ms/step - loss: 660.7924 - batch_ndcg: 0.7969 - val_loss: 126.8066 - val_batch_ndcg: 0.4001
# Epoch 4/100
# 38/38 [==============================] - 1s 14ms/step - loss: 644.5197 - batch_ndcg: 0.8220 - val_loss: 125.5522 - val_batch_ndcg: 0.4090
# Epoch 5/100
# 38/38 [==============================] - 1s 15ms/step - loss: 652.3369 - batch_ndcg: 0.8411 - val_loss: 124.7459 - val_batch_ndcg: 0.4106
# Epoch 6/100
# 38/38 [==============================] - 0s 13ms/step - loss: 625.7655 - batch_ndcg: 0.8533 - val_loss: 124.2407 - val_batch_ndcg: 0.4092
# Epoch 7/100
# 38/38 [==============================] - 1s 13ms/step - loss: 623.7264 - batch_ndcg: 0.8649 - val_loss: 123.8743 - val_batch_ndcg: 0.4080
# Epoch 8/100
# 38/38 [==============================] - 1s 14ms/step - loss: 622.0500 - batch_ndcg: 0.8728 - val_loss: 123.5909 - val_batch_ndcg: 0.4076
# Epoch 9/100
# 38/38 [==============================] - 1s 14ms/step - loss: 635.7405 - batch_ndcg: 0.8796 - val_loss: 123.4070 - val_batch_ndcg: 0.4058
# Epoch 10/100
# 38/38 [==============================] - 0s 13ms/step - loss: 617.1548 - batch_ndcg: 0.8856 - val_loss: 123.3088 - val_batch_ndcg: 0.4053
# Epoch 11/100
# 38/38 [==============================] - 1s 13ms/step - loss: 622.2331 - batch_ndcg: 0.8919 - val_loss: 123.2616 - val_batch_ndcg: 0.4010
# Epoch 12/100
# 38/38 [==============================] - 0s 13ms/step - loss: 632.1287 - batch_ndcg: 0.8972 - val_loss: 123.2165 - val_batch_ndcg: 0.4011
# Epoch 13/100
# 38/38 [==============================] - 0s 13ms/step - loss: 597.1644 - batch_ndcg: 0.9008 - val_loss: 123.1757 - val_batch_ndcg: 0.3986
# Epoch 14/100
# 38/38 [==============================] - 0s 13ms/step - loss: 609.8717 - batch_ndcg: 0.9049 - val_loss: 123.2069 - val_batch_ndcg: 0.3944
# Epoch 15/100
# 38/38 [==============================] - 1s 14ms/step - loss: 632.1593 - batch_ndcg: 0.9107 - val_loss: 123.1626 - val_batch_ndcg: 0.3935
# Epoch 00015: early stopping
# CPU times: user 11.1 s, sys: 879 ms, total: 11.9 s
# Wall time: 8.81 s

# %%
pred = test_predictor(test_q, model, n_item, batch_size)
pred
# Out:
# array([[ 608,  726,  171, ...,    9, 1531,  221],
#        [  22,  738,  676, ...,  662,  624,  578],
#        [ 128,  501,  164, ...,  437, 1712,  244],
#        ...,
#        [ 104,  669,  184, ...,  132,   51,  246],
#        [ 609,  217,  132, ..., 1001, 1253,  766],
#        [  44,  127,  217, ...,  985,  212,  321]])

# %%
m_ndcg, m_recall, m_precision, map_k = evaluation(test_a, pred)
print(f'nDCG: {m_ndcg:.5f}',
      f'\nRecall: {m_recall:.5f}',
      f'\nPrecision: {m_precision:.5f}',
      f'\nMAP: {map_k:.5f}')
# Out:
# nDCG: 0.58602
# Recall: 0.28013
# Precision: 0.19901
# MAP: 0.17573
