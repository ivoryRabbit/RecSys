# %% [markdown]
# <a href="https://colab.research.google.com/github/ivoryRabbit/RecSys/blob/master/9_Mult_VAE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Mult-VAE
#
# - [Variational Autoencoders for Collaborative Filtering](https://arxiv.org/pdf/1802.05814.pdf)
#
# ## Experiment

# %%
import glob
import numpy as np
import pandas as pd
from typing import Callable, Tuple, List
from tqdm.notebook import tqdm

import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

from sklearn.model_selection import train_test_split

import tensorflow as tf
import tensorflow.keras.backend as K

from tensorflow.keras.layers import Layer, Input, Dense, Dropout, Reshape
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2

from tensorflow.keras.utils import get_file
import zipfile

# %%
def load_data(data_size : str) -> pd.DataFrame:
    ''' load Movie Lens data '''

    if data_size == '1m':
        fname = 'ml-1m.zip'
        data = 'ml-1m/ratings.dat'
    elif data_size == '10m':
        fname = 'ml-10m.zip'
        data = 'ml-10M100K/ratings.dat'
    elif data_size == '20m':
        fname = 'ml-20m.zip'
        data = 'ml-20m/ratings.csv'
    elif data_size == '25m':
        fname = 'ml-25m.zip'
        data = 'ml-25m/ratings.csv'
    if not glob.glob(data):
        origin = f'http://files.grouplens.org/datasets/movielens/{fname}'
        file = get_file(fname, origin)
        zip_ref = zipfile.ZipFile(file, 'r')
        zip_ref.extractall()

    col_names = ['user_id', 'movie_id', 'rating', 'timestamp']
    if data_size in ['20m', '25m']:
        ratings = pd.read_csv(data, names = col_names, engine = 'python')
    else:
        ratings = pd.read_csv(data, sep = '|', delimiter = '::', names = col_names, engine = 'python')
    print(ratings.shape)
    return ratings

# %%
ratings = load_data('1m')
ratings.head()
# Out:
# (1000209, 4)
#    user_id  movie_id  rating  timestamp
# 0        1      1193       5  978300760
# 1        1       661       3  978302109
# 2        1       914       3  978301968
# 3        1      3408       4  978300275
# 4        1      2355       5  978824291

# %%
user_list = ratings.user_id.unique()
user_idx_map = {e: i for i, e in enumerate(user_list)}
n_user = len(user_list)
print(f'# of user = {n_user}')

item_list = ratings.movie_id.unique()
item_idx_map = {e: i for i, e in enumerate(item_list)}
n_item = len(item_list)
print(f'# of item = {n_item}')
# Out:
# # of user = 6040
# # of item = 3706

# %%
ratings = ratings.assign(
    user_id = ratings.user_id.map(user_idx_map),
    movie_id = ratings.movie_id.map(item_idx_map)
)
ratings.head()
# Out:
#    user_id  movie_id  rating  timestamp
# 0        0         0       5  978300760
# 1        0         1       3  978302109
# 2        0         2       3  978301968
# 3        0         3       4  978300275
# 4        0         4       5  978824291

# %%
def binarizer(df: pd.DataFrame, threshold = 4) -> pd.DataFrame:
    df = df.assign(rating = np.where(df.rating >= threshold, 1, 0))
    return df[df.rating > 0.0].reset_index(drop = True)

def make_warm(df: pd.DataFrame, threshold = 5) -> pd.DataFrame: # remove cold starters
    positive = df.groupby('user_id')['movie_id'].count()
    positive = positive.index[positive >= threshold]
    return df[df.user_id.isin(positive)].reset_index(drop = True)

def train_valid_test_split(df: pd.DataFrame, size: float) -> pd.DataFrame:
    train_user, test_user = train_test_split(df.user_id.unique(), test_size = 2 * size, random_state = 777)
    valid_user, test_user = train_test_split(test_user, test_size = 0.5, random_state = 777)
    train, valid, test = map(lambda x: df[df.user_id.isin(x)], (train_user, valid_user, test_user))
    train, valid, test = map(lambda df: df.reset_index(drop = True), (train, valid, test))
    return train, valid, test

def query_relev_split(df: pd.DataFrame, size: float) -> pd.DataFrame:
    timeorder = df.groupby('user_id')['timestamp'].rank(method = 'first', ascending = True)
    seen_cnts = df.groupby('user_id')['movie_id'].transform('count')
    df = df.assign(seen_cnts = seen_cnts, timeorder = timeorder)
    query = df[df.timeorder < df.seen_cnts * (1-size)]
    relev = df[df.timeorder >= df.seen_cnts * (1-size)]
    relev = relev[relev.user_id.isin(query.user_id.unique())]
    query, relev = map(lambda df: df.drop(columns = ['timeorder', 'seen_cnts']), (query, relev))
    query, relev = map(lambda df: df.reset_index(drop = True), (query, relev))
    return query, relev

def list_agg(df: pd.DataFrame) -> pd.DataFrame:
    return df.groupby('user_id', as_index = False)[['movie_id']].agg(list)

# %%
data = binarizer(ratings)
data = make_warm(data)
data.head()
# Out:
#    user_id  movie_id  rating  timestamp
# 0        0         0       1  978300760
# 1        0         3       1  978300275
# 2        0         4       1  978824291
# 3        0         6       1  978302039
# 4        0         7       1  978300719

# %%
train, valid, test = train_valid_test_split(data, size = 0.1)
valid_q, valid_r = query_relev_split(valid, size = 0.2)
test_q, test_r = query_relev_split(test, size = 0.2)

# %%
def train_generator(train: pd.DataFrame, 
                    n_item: int,
                    batch_size: int) -> np.ndarray:

    train = list_agg(train)
    
    n_data = train.index.size
    ids = np.arange(n_data)
    profile = train['movie_id']

    n_batch = int(np.ceil(n_data / batch_size))
    while True:
        np.random.shuffle(ids)
        for batch_step in range(n_batch):     
            lower = batch_size * batch_step
            upper = batch_size + lower
            
            batch_id = ids[lower: upper]
            batch = np.zeros(shape = (batch_id.size, n_item), dtype = np.float32)
            for i, idx in enumerate(batch_id):
                batch[i, profile[idx]] = 1.0
            
            yield batch

# %%
def valid_generator(query: pd.DataFrame,
                    relev: pd.DataFrame,
                    n_item: int,
                    batch_size: int) -> Tuple[np.ndarray]:

    query = list_agg(query)
    relev = list_agg(relev)

    n_data = query.index.size
    ids = np.arange(n_data)
    profile_q = query['movie_id']
    profile_r = relev['movie_id']

    n_batch = int(np.ceil(n_data / batch_size))
    while True:
        np.random.shuffle(ids)
        for batch_step in range(n_batch):
            lower = batch_size * batch_step
            upper = batch_size + lower
            
            batch_id = ids[lower: upper]
            batch_q = np.zeros(shape = (batch_id.size, n_item), dtype = np.float32)
            batch_r = np.zeros(shape = (batch_id.size, n_item), dtype = np.float32)
            for i, idx in enumerate(batch_id):
                batch_q[i, profile_q[idx]] = 1.0 # seen
                batch_r[i, profile_r[idx]] = 1.0 # unseen

            yield batch_q, batch_r

# %%
def rmse(true: tf.Tensor, pred: tf.Tensor) -> tf.Tensor:
    rmse = K.sqrt(K.mean(K.square(true - pred), axis = 1))
    return K.mean(rmse, axis = 0)

def binary_cross_entropy(true: tf.Tensor, pred: tf.Tensor) -> tf.Tensor:
    ce = K.sum(K.binary_crossentropy(true, pred), axis = 1)
    return K.mean(ce, axis = 0)

def multinomial(true: tf.Tensor, pred: tf.Tensor) -> tf.Tensor:
    ll = -K.sum(true * K.log(pred), axis = 1)
    return K.mean(ll, axis = 0)

def batch_ndcg(query: tf.Tensor, 
               relev: tf.Tensor,
               pred: tf.Tensor, 
               weight: tf.Tensor,
               k = 100) -> tf.Tensor: # only for validation

    rec = tf.where(query == 1.0, -1.0, pred) # leave only unseen-data
    rec = tf.argsort(rec, axis = 1, direction = 'DESCENDING')[:, :k]
    shape = tf.shape(rec)

    row = tf.repeat(tf.range(shape[0]), shape[1])
    row = tf.expand_dims(row, axis = 1)
    col = tf.reshape(rec, shape = [-1])
    col = tf.expand_dims(col, axis = 1)
    loc = tf.concat([row, col], axis = 1)

    top_k = tf.reshape(tf.gather_nd(relev, loc), shape = shape)
    ideal = tf.sort(relev, axis = 1, direction = 'DESCENDING')[:, :k]
    weight = weight[:shape[1]]

    dcg = tf.reduce_sum(top_k * weight, axis = 1)
    idcg = tf.reduce_sum(ideal * weight, axis = 1)
    return tf.reduce_mean(dcg / idcg, axis = 0)

# %%
class Encoder(tf.keras.layers.Layer):
    def __init__(self, units):
        super(Encoder, self).__init__()
        self.units = units

    def build(self, input_shape):
        self.encoder_layer = Dense(2 * self.units,
                                   activation = 'tanh',
                                   kernel_initializer = 'glorot_uniform',
                                   bias_initializer = 'zeros',
                                   kernel_regularizer = l2(1e-3),
                                   name = 'mean')
        self.reshape_layer = Reshape((2, self.units))
   
    def call(self, inputs):
        x = self.encoder_layer(inputs)
        x = self.reshape_layer(x)
        return x[:, 0], x[:, 1]

# %%
class Sampling(tf.keras.layers.Layer):
    def call(self, inputs, training = False):
        mean, log_var = inputs
        if training:
            return mean + K.exp(0.5 * log_var) * K.random_normal(tf.shape(mean))
        return mean

# %%
class Decoder(tf.keras.layers.Layer):
    def __init__(self, units, likelihood):
        super(Decoder, self).__init__()
        self.units = units
        self.likelihood = likelihood
        
        dist_map = {'multinomial': 'softmax', 'logistic': 'sigmoid', 'gaussian': 'linear'}
        self.last_activation = dist_map[self.likelihood]

    def build(self, input_shape):
        self.decoder_layer = Dense(self.units,
                                   activation = self.last_activation, 
                                   kernel_initializer = 'glorot_uniform',
                                   bias_initializer = 'zeros',
                                   kernel_regularizer = l2(1e-3),
                                   name = 'decoder')

    def call(self, inputs):
        return self.decoder_layer(inputs)

# %%
class VAE(tf.keras.models.Model):
    def __init__(self, input_dim, latent_dim, dropout_rate, anneal_rate, likelihood = 'multinomial'):
        super(VAE, self).__init__()
        self.input_dim = input_dim
        self.latent_dim = latent_dim
        self.dropout_rate = dropout_rate
        self.anneal_rate = anneal_rate
        self.likelihood = likelihood

        self.dropout= Dropout(self.dropout_rate)
        self.encoder = Encoder(self.latent_dim)
        self.sampler = Sampling()
        self.decoder = Decoder(self.input_dim, self.likelihood)

        _ = self.call(Input(shape = (self.input_dim, )), training = True)
        self.build(input_shape = (None, self.input_dim))

    def call(self, inputs, training = False):
        x = self.dropout(inputs) if training else inputs
        mean, log_var = self.encoder(x)
        z = self.sampler([mean, log_var], training)
        if training:
            return self.decoder(z), mean, log_var
        return self.decoder(z)

    def kld_loss(self, mean, log_var):
        kl = -0.5 * K.sum(1 + log_var - K.exp(log_var) - K.square(mean), axis = 1)
        return K.mean(kl, axis = 0)
        
    def train_step(self, inputs):
        with tf.GradientTape() as tape:
            outputs, mean, log_var = self(inputs, training = True)
            ll_loss = self.loss(inputs, outputs)
            kl_loss = self.anneal_rate * self.kld_loss(mean, log_var)
            loss = ll_loss + kl_loss
        grads = tape.gradient(loss, self.trainable_variables)
        self.optimizer.apply_gradients(zip(grads, self.trainable_variables))
        return {'loss': loss}

    def test_step(self, data):
        query, relev = data
        pred = self(query)

        weight = tf.range(2, self.input_dim, dtype = 'float32')
        weight = tf.math.reciprocal(tf.math.log(weight))
        ndcg = batch_ndcg(query, relev, pred, weight)
        return {'ndcg': ndcg}

# %%
def show_history(hist, loss: str, metric: str) -> None:
    fig, (ax1, ax2) = plt.subplots(2, 1, figsize = (8, 6))

    ax1.plot(hist.history[f'{loss}'])
    ax1.set_title(loss, fontsize = 20)
    ax1.set_ylabel(loss)
    ax1.set_xlabel('epoch')

    ax2.plot(hist.history[f'val_{metric}'])
    ax2.set_title(metric, fontsize = 20)
    ax2.set_ylabel(metric)
    ax2.set_xlabel('epoch')
    plt.tight_layout()

# %%
def test_predictor(query: pd.DataFrame, 
                   model: Callable,
                   n_item: int, 
                   batch_size: int, 
                   N = 100) -> float:

    query = list_agg(query)

    n_data = query.index.size
    ids = np.arange(n_data)
    profile = query['movie_id']

    pred = []
    n_batch = int(np.ceil(n_data / batch_size))
    for batch_step in range(n_batch):
        lower = batch_size * batch_step
        upper = batch_size + lower

        batch_id = ids[lower: upper]
        batch = np.zeros(shape = (batch_id.size, n_item))
        for i, idx in enumerate(batch_id):
            batch[i, profile[idx]] = 1.0

        pred_batch = model.predict(batch, verbose = 0)
        
        rec = np.argsort(np.where(batch == 1.0, -1.0, pred_batch), axis = 1)[:, :-N-1:-1]
        pred.append(rec)
    pred = np.concatenate(pred)
    pred = [{'user_id': query.at[i, 'user_id'], 'movie_id': pred[i]} for i in range(n_data)]
    return pd.DataFrame(pred)

# %%
class evaluate:
    def __init__(self, true: pd.DataFrame, pred: pd.DataFrame):
        self.true = true
        self.pred = pred
        self.max_K = 10000
        self.idcg = np.cumsum([1.0 / np.log(i+2) for i in range(self.max_K)])

    def _recall(self, gt: List, rec: List, K = None) -> float:
        K = K if K else self.max_K
        res = [r for r in rec[:K] if r in gt]
        return len(res) / np.min([K, len(gt)])
    
    def _precision(self, gt: List, rec: List, K = None) -> float:
        K = K if K else self.max_K
        res = [r for r in rec[:K] if r in gt]
        return len(res) / len(rec[:K])

    def _AP(self, gt: List, rec: List, K = None) -> float: # Average Precision
        K = K if K else self.max_K
        res = 0.0
        for i, r in enumerate(rec[:K]):
            if r in gt:
                res += self._precision(gt, rec[:K], i+1)
        return res / np.min([K, len(gt)])

    def _RR(self, gt: List, rec: List, K = None) -> float: # Reciprocal Rank
        K = K if K else self.max_K
        for i, r in enumerate(rec[:K]):
            if r in gt:
                return  1.0 / (i+1)
        return 0

    def _nDCG(self, gt: List, rec: List, K = None) -> float: # normalized Discounted Cumulative Gain
        K = K if K else self.max_K
        dcg = 0.0
        for i, r in enumerate(rec[:K]):
            if r in gt:
                dcg += 1.0 / np.log(i+2)
        idcg = self.idcg[min([len(gt), K])-1]
        return dcg / idcg
    
    def __call__(self, K = None):
        self.K = K
        self.recall = 0
        self.precision = 0
        self.MAP = 0
        self.MRR = 0
        self.nDCG = 0
        n = self.true.index.size
        for gt, rec in zip(tqdm(self.true.movie_id), self.pred.movie_id):
            self.recall += self._recall(gt, rec, K) / n
            self.precision += self._precision(gt, rec, K) / n
            self.MAP += self._AP(gt, rec, K) / n
            self.MRR += self._RR(gt, rec, K) / n
            self.nDCG += self._nDCG(gt, rec, K) / n

    def print_all(self):
        K = '@' + str(self.K) if self.K else ''
        print(f'{"Recall":>12}{K} : {self.recall:.5f}',
              f'\n{"Precision":>12}{K} : {self.precision:.5f}',
              f'\n{"MAP":>12}{K} : {self.MAP:.5f}',
              f'\n{"MRR":>12}{K} : {self.MRR:.5f}',
              f'\n{"nDCG":>12}{K} : {self.nDCG:.5f}')

# %%
epochs = 100
batch_size = 128

train_gen = train_generator(train, n_item, batch_size)
valid_gen = valid_generator(valid_q, valid_r, n_item, batch_size)

steps_per_epoch = train.user_id.nunique() // batch_size + 1
validation_steps = valid.user_id.nunique() // batch_size + 1

# %% [markdown]
# ## 1. Multinomial

# %%
model = VAE(n_item, latent_dim = 256, dropout_rate = 0.5, anneal_rate = 0.2)
model.compile(optimizer = Adam(lr = 1e-4), loss = multinomial)

model.summary()
# Out:
# Model: "vae"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dropout (Dropout)            (None, 3706)              0
# _________________________________________________________________
# encoder (Encoder)            ((None, 256), (None, 256) 1897984
# _________________________________________________________________
# sampling (Sampling)          (None, 256)               0
# _________________________________________________________________
# decoder (Decoder)            (None, 3706)              952442
# =================================================================
# Total params: 2,850,426
# Trainable params: 2,850,426
# Non-trainable params: 0
# _________________________________________________________________

# %%
# %%time
early_stopping = EarlyStopping(monitor = 'val_ndcg', mode = 'max', verbose = 1, patience = epochs // 5)
model_checkpoint = ModelCheckpoint('mult-VAE.h5', monitor = 'val_ndcg', mode = 'max', save_best_only = True)

hist = model.fit(x = train_gen, validation_data = valid_gen, epochs = epochs,
                 steps_per_epoch = steps_per_epoch, validation_steps = validation_steps, 
                 verbose = 1, callbacks = [early_stopping, model_checkpoint])
show_history(hist, 'loss', 'ndcg')
# Out:
# Epoch 1/100
# 38/38 [==============================] - 2s 18ms/step - loss: 787.3390 - val_ndcg: 0.0613
# Epoch 2/100
# 38/38 [==============================] - 0s 8ms/step - loss: 763.0801 - val_ndcg: 0.1150
# Epoch 3/100
# 38/38 [==============================] - 0s 8ms/step - loss: 732.8196 - val_ndcg: 0.1572
# Epoch 4/100
# 38/38 [==============================] - 0s 8ms/step - loss: 718.9969 - val_ndcg: 0.1717
# Epoch 5/100
# 38/38 [==============================] - 0s 8ms/step - loss: 713.1920 - val_ndcg: 0.1462
# Epoch 6/100
# 38/38 [==============================] - 0s 8ms/step - loss: 714.3530 - val_ndcg: 0.1598
# Epoch 7/100
# 38/38 [==============================] - 0s 8ms/step - loss: 713.8882 - val_ndcg: 0.1773
# Epoch 8/100
# 38/38 [==============================] - 0s 8ms/step - loss: 710.5278 - val_ndcg: 0.1611
# Epoch 9/100
# 38/38 [==============================] - 0s 8ms/step - loss: 702.7628 - val_ndcg: 0.1691
# Epoch 10/100
# 38/38 [==============================] - 0s 8ms/step - loss: 699.4007 - val_ndcg: 0.1642
# Epoch 11/100
# 38/38 [==============================] - 0s 8ms/step - loss: 704.4849 - val_ndcg: 0.1793
# Epoch 12/100
# 38/38 [==============================] - 0s 8ms/step - loss: 699.0362 - val_ndcg: 0.1866
# Epoch 13/100
# 38/38 [==============================] - 0s 8ms/step - loss: 698.1555 - val_ndcg: 0.1848
# Epoch 14/100
# 38/38 [==============================] - 0s 8ms/step - loss: 696.8418 - val_ndcg: 0.1573
# Epoch 15/100
# 38/38 [==============================] - 0s 8ms/step - loss: 690.4426 - val_ndcg: 0.1966
# Epoch 16/100
# 38/38 [==============================] - 0s 8ms/step - loss: 689.2918 - val_ndcg: 0.1848
# Epoch 17/100
# 38/38 [==============================] - 0s 8ms/step - loss: 694.4861 - val_ndcg: 0.1921
# Epoch 18/100
# 38/38 [==============================] - 0s 8ms/step - loss: 686.9496 - val_ndcg: 0.1786
# Epoch 19/100
# 38/38 [==============================] - 0s 8ms/step - loss: 686.4853 - val_ndcg: 0.1944
# Epoch 20/100
# 38/38 [==============================] - 0s 7ms/step - loss: 685.4304 - val_ndcg: 0.1993
# Epoch 21/100
# 38/38 [==============================] - 0s 8ms/step - loss: 681.3103 - val_ndcg: 0.1669
# Epoch 22/100
# 38/38 [==============================] - 0s 8ms/step - loss: 686.5021 - val_ndcg: 0.1831
# Epoch 23/100
# 38/38 [==============================] - 0s 7ms/step - loss: 680.2589 - val_ndcg: 0.1839
# Epoch 24/100
# 38/38 [==============================] - 0s 8ms/step - loss: 681.5305 - val_ndcg: 0.1902
# Epoch 25/100
# 38/38 [==============================] - 0s 8ms/step - loss: 673.8990 - val_ndcg: 0.1875
# Epoch 26/100
# 38/38 [==============================] - 0s 7ms/step - loss: 676.6586 - val_ndcg: 0.2233
# Epoch 27/100
# 38/38 [==============================] - 0s 8ms/step - loss: 676.9109 - val_ndcg: 0.1937
# Epoch 28/100
# 38/38 [==============================] - 0s 8ms/step - loss: 673.7272 - val_ndcg: 0.1927
# Epoch 29/100
# 38/38 [==============================] - 0s 8ms/step - loss: 675.4515 - val_ndcg: 0.1845
# Epoch 30/100
# 38/38 [==============================] - 0s 8ms/step - loss: 669.1424 - val_ndcg: 0.1852
# Epoch 31/100
# 38/38 [==============================] - 0s 8ms/step - loss: 674.1547 - val_ndcg: 0.1877
# Epoch 32/100
# 38/38 [==============================] - 0s 9ms/step - loss: 674.1707 - val_ndcg: 0.2016
# Epoch 33/100
# 38/38 [==============================] - 0s 8ms/step - loss: 672.9198 - val_ndcg: 0.1938
# Epoch 34/100
# 38/38 [==============================] - 0s 8ms/step - loss: 669.5079 - val_ndcg: 0.1980
# Epoch 35/100
# 38/38 [==============================] - 0s 7ms/step - loss: 666.6585 - val_ndcg: 0.1773
# Epoch 36/100
# 38/38 [==============================] - 0s 8ms/step - loss: 667.1676 - val_ndcg: 0.1896
# Epoch 37/100
# 38/38 [==============================] - 0s 8ms/step - loss: 666.5258 - val_ndcg: 0.2156
# Epoch 38/100
# 38/38 [==============================] - 0s 8ms/step - loss: 662.9432 - val_ndcg: 0.2225
# Epoch 39/100
# 38/38 [==============================] - 0s 8ms/step - loss: 667.2517 - val_ndcg: 0.2187
# Epoch 40/100
# 38/38 [==============================] - 0s 8ms/step - loss: 668.7777 - val_ndcg: 0.2463
# Epoch 41/100
# 38/38 [==============================] - 0s 8ms/step - loss: 666.5055 - val_ndcg: 0.2117
# Epoch 42/100
# 38/38 [==============================] - 0s 9ms/step - loss: 663.4549 - val_ndcg: 0.2228
# Epoch 43/100
# 38/38 [==============================] - 0s 8ms/step - loss: 661.7046 - val_ndcg: 0.2169
# Epoch 44/100
# 38/38 [==============================] - 0s 8ms/step - loss: 665.1818 - val_ndcg: 0.2036
# Epoch 45/100
# 38/38 [==============================] - 0s 8ms/step - loss: 669.8169 - val_ndcg: 0.2069
# Epoch 46/100
# 38/38 [==============================] - 0s 9ms/step - loss: 666.8325 - val_ndcg: 0.2063
# Epoch 47/100
# 38/38 [==============================] - 0s 8ms/step - loss: 659.9567 - val_ndcg: 0.1881
# Epoch 48/100
# 38/38 [==============================] - 0s 11ms/step - loss: 660.6926 - val_ndcg: 0.2026
# Epoch 49/100
# 38/38 [==============================] - 0s 9ms/step - loss: 661.5541 - val_ndcg: 0.2007
# Epoch 50/100
# 38/38 [==============================] - 0s 7ms/step - loss: 659.8110 - val_ndcg: 0.2055
# Epoch 51/100
# 38/38 [==============================] - 0s 8ms/step - loss: 659.0610 - val_ndcg: 0.1931
# Epoch 52/100
# 38/38 [==============================] - 0s 8ms/step - loss: 659.9448 - val_ndcg: 0.2162
# Epoch 53/100
# 38/38 [==============================] - 0s 8ms/step - loss: 656.9207 - val_ndcg: 0.2115
# Epoch 54/100
# 38/38 [==============================] - 0s 8ms/step - loss: 658.6176 - val_ndcg: 0.2067
# Epoch 55/100
# 38/38 [==============================] - 0s 9ms/step - loss: 655.4308 - val_ndcg: 0.2041
# Epoch 56/100
# 38/38 [==============================] - 0s 8ms/step - loss: 659.9725 - val_ndcg: 0.2102
# Epoch 57/100
# 38/38 [==============================] - 0s 7ms/step - loss: 658.5868 - val_ndcg: 0.2090
# Epoch 58/100
# 38/38 [==============================] - 0s 8ms/step - loss: 657.7614 - val_ndcg: 0.1840
# Epoch 59/100
# 38/38 [==============================] - 0s 8ms/step - loss: 657.5533 - val_ndcg: 0.1708
# Epoch 60/100
# 38/38 [==============================] - 0s 8ms/step - loss: 658.3910 - val_ndcg: 0.1890
# Epoch 00060: early stopping
# CPU times: user 25.8 s, sys: 2.32 s, total: 28.1 s
# Wall time: 20 s

# %%
true = list_agg(test_r)
true.head(5)
# Out:
#    user_id                                           movie_id
# 0        2              [177, 179, 183, 84, 4, 198, 199, 207]
# 1        8  [59, 438, 93, 123, 463, 525, 30, 288, 534, 322...
# 2       41  [175, 182, 563, 184, 1176, 116, 128, 1037, 104...
# 3       78                             [1258, 305, 500, 2230]
# 4       91  [558, 1176, 195, 587, 592, 74, 1904, 186, 647,...

# %%
pred = test_predictor(test_q, model, n_item, batch_size, N = 100)
pred.head(5)
# Out:
#    user_id                                           movie_id
# 0        2  [92, 48, 97, 132, 22, 217, 210, 711, 151, 23, ...
# 1        8  [244, 184, 134, 92, 171, 44, 5, 124, 68, 315, ...
# 2       41  [62, 132, 155, 856, 189, 160, 758, 775, 86, 11...
# 3       78  [104, 38, 68, 48, 128, 97, 92, 184, 132, 44, 2...
# 4       91  [9, 612, 8, 741, 44, 64, 596, 124, 609, 1523, ...

# %%
scores = evaluate(true, pred)

scores(K = 20)
scores.print_all()

scores(K = 100)
scores.print_all()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=604.0), HTML(value='')))
#       Recall@20 : 0.13380
#    Precision@20 : 0.07988
#          MAP@20 : 0.04607
#          MRR@20 : 0.23511
#         nDCG@20 : 0.11726
# HBox(children=(FloatProgress(value=0.0, max=604.0), HTML(value='')))
#       Recall@100 : 0.37268
#    Precision@100 : 0.05659
#          MAP@100 : 0.05935
#          MRR@100 : 0.24312
#         nDCG@100 : 0.20928

# %% [markdown]
# ## 2. Logistic

# %%
model = VAE(n_item, latent_dim = 256, dropout_rate = 0.5, anneal_rate = 0.2, likelihood = 'logistic')
model.compile(optimizer = Adam(lr = 1e-4), loss = binary_cross_entropy)

model.summary()
# Out:
# Model: "vae_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dropout_1 (Dropout)          (None, 3706)              0
# _________________________________________________________________
# encoder_1 (Encoder)          ((None, 256), (None, 256) 1897984
# _________________________________________________________________
# sampling_1 (Sampling)        (None, 256)               0
# _________________________________________________________________
# decoder_1 (Decoder)          (None, 3706)              952442
# =================================================================
# Total params: 2,850,426
# Trainable params: 2,850,426
# Non-trainable params: 0
# _________________________________________________________________

# %%
# %%time
early_stopping = EarlyStopping(monitor = 'val_ndcg', mode = 'max', verbose = 1, patience = epochs // 5)
model_checkpoint = ModelCheckpoint('logi-VAE.h5', monitor = 'val_ndcg', mode = 'max', save_best_only = True)

hist = model.fit(x = train_gen, validation_data = valid_gen, epochs = epochs,
                 steps_per_epoch = steps_per_epoch, validation_steps = validation_steps, 
                 verbose = 1, callbacks = [early_stopping, model_checkpoint])
show_history(hist, 'loss', 'ndcg')
# Out:
# Epoch 1/100
# 38/38 [==============================] - 1s 12ms/step - loss: 2533.5521 - val_ndcg: 0.0357
# Epoch 2/100
# 38/38 [==============================] - 0s 8ms/step - loss: 1972.1579 - val_ndcg: 0.1243
# Epoch 3/100
# 38/38 [==============================] - 0s 8ms/step - loss: 1327.6024 - val_ndcg: 0.1500
# Epoch 4/100
# 38/38 [==============================] - 0s 8ms/step - loss: 977.6530 - val_ndcg: 0.1527
# Epoch 5/100
# 38/38 [==============================] - 0s 8ms/step - loss: 802.7238 - val_ndcg: 0.1443
# Epoch 6/100
# 38/38 [==============================] - 0s 8ms/step - loss: 704.3648 - val_ndcg: 0.1408
# Epoch 7/100
# 38/38 [==============================] - 0s 8ms/step - loss: 641.3409 - val_ndcg: 0.1299
# Epoch 8/100
# 38/38 [==============================] - 0s 8ms/step - loss: 597.9730 - val_ndcg: 0.1547
# Epoch 9/100
# 38/38 [==============================] - 0s 8ms/step - loss: 568.2261 - val_ndcg: 0.1350
# Epoch 10/100
# 38/38 [==============================] - 0s 8ms/step - loss: 550.0606 - val_ndcg: 0.1421
# Epoch 11/100
# 38/38 [==============================] - 0s 8ms/step - loss: 525.1051 - val_ndcg: 0.1508
# Epoch 12/100
# 38/38 [==============================] - 0s 8ms/step - loss: 519.9629 - val_ndcg: 0.1568
# Epoch 13/100
# 38/38 [==============================] - 0s 8ms/step - loss: 501.6888 - val_ndcg: 0.1510
# Epoch 14/100
# 38/38 [==============================] - 0s 11ms/step - loss: 495.9933 - val_ndcg: 0.1210
# Epoch 15/100
# 38/38 [==============================] - 0s 8ms/step - loss: 484.4755 - val_ndcg: 0.1382
# Epoch 16/100
# 38/38 [==============================] - 0s 8ms/step - loss: 480.1727 - val_ndcg: 0.1258
# Epoch 17/100
# 38/38 [==============================] - 0s 8ms/step - loss: 473.1100 - val_ndcg: 0.1526
# Epoch 18/100
# 38/38 [==============================] - 0s 8ms/step - loss: 468.2037 - val_ndcg: 0.1498
# Epoch 19/100
# 38/38 [==============================] - 0s 8ms/step - loss: 468.9971 - val_ndcg: 0.1202
# Epoch 20/100
# 38/38 [==============================] - 0s 8ms/step - loss: 459.5676 - val_ndcg: 0.1490
# Epoch 21/100
# 38/38 [==============================] - 0s 8ms/step - loss: 461.9920 - val_ndcg: 0.1574
# Epoch 22/100
# 38/38 [==============================] - 0s 8ms/step - loss: 454.8375 - val_ndcg: 0.1439
# Epoch 23/100
# 38/38 [==============================] - 0s 8ms/step - loss: 449.7713 - val_ndcg: 0.1595
# Epoch 24/100
# 38/38 [==============================] - 0s 8ms/step - loss: 450.2022 - val_ndcg: 0.1479
# Epoch 25/100
# 38/38 [==============================] - 0s 8ms/step - loss: 444.3620 - val_ndcg: 0.1479
# Epoch 26/100
# 38/38 [==============================] - 0s 8ms/step - loss: 440.3531 - val_ndcg: 0.1605
# Epoch 27/100
# 38/38 [==============================] - 0s 9ms/step - loss: 439.8910 - val_ndcg: 0.1487
# Epoch 28/100
# 38/38 [==============================] - 0s 8ms/step - loss: 441.1584 - val_ndcg: 0.1434
# Epoch 29/100
# 38/38 [==============================] - 0s 11ms/step - loss: 438.4231 - val_ndcg: 0.1438
# Epoch 30/100
# 38/38 [==============================] - 0s 8ms/step - loss: 435.2977 - val_ndcg: 0.1384
# Epoch 31/100
# 38/38 [==============================] - 0s 8ms/step - loss: 433.7380 - val_ndcg: 0.1356
# Epoch 32/100
# 38/38 [==============================] - 0s 8ms/step - loss: 433.3448 - val_ndcg: 0.1472
# Epoch 33/100
# 38/38 [==============================] - 0s 8ms/step - loss: 427.0718 - val_ndcg: 0.1547
# Epoch 34/100
# 38/38 [==============================] - 0s 8ms/step - loss: 429.8281 - val_ndcg: 0.1345
# Epoch 35/100
# 38/38 [==============================] - 0s 8ms/step - loss: 425.9316 - val_ndcg: 0.1624
# Epoch 36/100
# 38/38 [==============================] - 0s 8ms/step - loss: 425.1168 - val_ndcg: 0.1407
# Epoch 37/100
# 38/38 [==============================] - 0s 8ms/step - loss: 427.1006 - val_ndcg: 0.1302
# Epoch 38/100
# 38/38 [==============================] - 0s 8ms/step - loss: 423.4592 - val_ndcg: 0.1277
# Epoch 39/100
# 38/38 [==============================] - 0s 8ms/step - loss: 422.6119 - val_ndcg: 0.1456
# Epoch 40/100
# 38/38 [==============================] - 0s 8ms/step - loss: 418.6466 - val_ndcg: 0.1476
# Epoch 41/100
# 38/38 [==============================] - 0s 8ms/step - loss: 417.7268 - val_ndcg: 0.1471
# Epoch 42/100
# 38/38 [==============================] - 0s 8ms/step - loss: 417.1016 - val_ndcg: 0.1407
# Epoch 43/100
# 38/38 [==============================] - 0s 8ms/step - loss: 416.7241 - val_ndcg: 0.1567
# Epoch 44/100
# 38/38 [==============================] - 0s 10ms/step - loss: 419.0231 - val_ndcg: 0.1524
# Epoch 45/100
# 38/38 [==============================] - 0s 8ms/step - loss: 412.9475 - val_ndcg: 0.1506
# Epoch 46/100
# 38/38 [==============================] - 0s 8ms/step - loss: 415.4751 - val_ndcg: 0.1803
# Epoch 47/100
# 38/38 [==============================] - 0s 8ms/step - loss: 412.1147 - val_ndcg: 0.1532
# Epoch 48/100
# 38/38 [==============================] - 0s 8ms/step - loss: 413.4438 - val_ndcg: 0.1450
# Epoch 49/100
# 38/38 [==============================] - 0s 8ms/step - loss: 412.7812 - val_ndcg: 0.1642
# Epoch 50/100
# 38/38 [==============================] - 0s 8ms/step - loss: 414.7142 - val_ndcg: 0.1506
# Epoch 51/100
# 38/38 [==============================] - 0s 8ms/step - loss: 408.9989 - val_ndcg: 0.1451
# Epoch 52/100
# 38/38 [==============================] - 0s 8ms/step - loss: 408.9977 - val_ndcg: 0.1409
# Epoch 53/100
# 38/38 [==============================] - 0s 8ms/step - loss: 410.3335 - val_ndcg: 0.1415
# Epoch 54/100
# 38/38 [==============================] - 0s 8ms/step - loss: 407.9128 - val_ndcg: 0.1387
# Epoch 55/100
# 38/38 [==============================] - 0s 8ms/step - loss: 409.2224 - val_ndcg: 0.1436
# Epoch 56/100
# 38/38 [==============================] - 0s 8ms/step - loss: 404.3056 - val_ndcg: 0.1626
# Epoch 57/100
# 38/38 [==============================] - 0s 9ms/step - loss: 403.9413 - val_ndcg: 0.1237
# Epoch 58/100
# 38/38 [==============================] - 0s 9ms/step - loss: 407.8558 - val_ndcg: 0.1619
# Epoch 59/100
# 38/38 [==============================] - 0s 9ms/step - loss: 406.2002 - val_ndcg: 0.1547
# Epoch 60/100
# 38/38 [==============================] - 0s 12ms/step - loss: 406.7381 - val_ndcg: 0.1554
# Epoch 61/100
# 38/38 [==============================] - 0s 8ms/step - loss: 400.4770 - val_ndcg: 0.1414
# Epoch 62/100
# 38/38 [==============================] - 0s 8ms/step - loss: 402.1515 - val_ndcg: 0.1577
# Epoch 63/100
# 38/38 [==============================] - 0s 8ms/step - loss: 399.0788 - val_ndcg: 0.1393
# Epoch 64/100
# 38/38 [==============================] - 0s 8ms/step - loss: 403.0037 - val_ndcg: 0.1309
# Epoch 65/100
# 38/38 [==============================] - 0s 8ms/step - loss: 403.4846 - val_ndcg: 0.1330
# Epoch 66/100
# 38/38 [==============================] - 0s 8ms/step - loss: 401.6659 - val_ndcg: 0.1387
# Epoch 00066: early stopping
# CPU times: user 27.9 s, sys: 2.39 s, total: 30.3 s
# Wall time: 21.4 s

# %%
true = list_agg(test_r)
true.head(5)
# Out:
#    user_id                                           movie_id
# 0        2              [177, 179, 183, 84, 4, 198, 199, 207]
# 1        8  [59, 438, 93, 123, 463, 525, 30, 288, 534, 322...
# 2       41  [175, 182, 563, 184, 1176, 116, 128, 1037, 104...
# 3       78                             [1258, 305, 500, 2230]
# 4       91  [558, 1176, 195, 587, 592, 74, 1904, 186, 647,...

# %%
pred = test_predictor(test_q, model, n_item, batch_size, N = 100)
pred.head(5)
# Out:
#    user_id                                           movie_id
# 0        2  [48, 132, 38, 128, 97, 51, 23, 167, 669, 92, 2...
# 1        8  [44, 124, 127, 97, 669, 92, 22, 5, 134, 244, 1...
# 2       41  [104, 48, 132, 38, 128, 51, 167, 23, 669, 92, ...
# 3       78  [104, 44, 124, 48, 132, 38, 127, 128, 64, 97, ...
# 4       91  [104, 44, 124, 48, 127, 64, 51, 23, 97, 669, 2...

# %%
scores = evaluate(true, pred)

scores(K = 20)
scores.print_all()

scores(K = 100)
scores.print_all()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=604.0), HTML(value='')))
#       Recall@20 : 0.10512
#    Precision@20 : 0.06573
#          MAP@20 : 0.03170
#          MRR@20 : 0.17493
#         nDCG@20 : 0.08931
# HBox(children=(FloatProgress(value=0.0, max=604.0), HTML(value='')))
#       Recall@100 : 0.25933
#    Precision@100 : 0.04270
#          MAP@100 : 0.03849
#          MRR@100 : 0.18231
#         nDCG@100 : 0.14910

# %% [markdown]
# ### 3. Mult-DAE

# %%
class DAE(tf.keras.models.Model):
    def __init__(self, input_dim, latent_dim, dropout_rate):
        super(DAE, self).__init__()
        self.input_dim = input_dim
        self.latent_dim = latent_dim
        self.dropout_rate = dropout_rate

        self.dropout = Dropout(self.dropout_rate)
        self.encoder = Dense(self.latent_dim, 
                             activation = 'selu',
                             kernel_initializer = 'glorot_uniform',
                             bias_initializer = 'zeros',
                             kernel_regularizer = l2(1e-3),
                             name = 'encoder')
        self.decoder = Dense(self.input_dim,
                             activation = 'softmax',
                             kernel_initializer = 'glorot_uniform',
                             bias_initializer = 'zeros',
                             kernel_regularizer = l2(1e-3),
                             name = 'decoder')

        _ = self.call(Input(shape = (self.input_dim, )), training = True)
        self.build(input_shape = (None, self.input_dim))

    def call(self, inputs, training = False):
        x = self.dropout(inputs) if training else inputs
        h = self.encoder(x)
        return self.decoder(h)

    def train_step(self, inputs):
        with tf.GradientTape() as tape:
            outputs = self(inputs, training = True)
            loss = self.loss(inputs, outputs)
        grads = tape.gradient(loss, self.trainable_variables)
        self.optimizer.apply_gradients(zip(grads, self.trainable_variables))
        return {'loss': loss}

    def test_step(self, data):
        query, relev = data
        pred = self(query)

        weight = tf.range(2, self.input_dim, dtype = 'float32')
        weight = tf.math.reciprocal(tf.math.log(weight))
        ndcg = batch_ndcg(query, relev, pred, weight)
        return {'ndcg': ndcg}

# %%
model = DAE(n_item, latent_dim = 256, dropout_rate = 0.5)
model.compile(optimizer = Adam(lr = 1e-4), loss = multinomial)

model.summary()
# Out:
# Model: "dae"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dropout_2 (Dropout)          (None, 3706)              0
# _________________________________________________________________
# encoder (Dense)              (None, 256)               948992
# _________________________________________________________________
# decoder (Dense)              (None, 3706)              952442
# =================================================================
# Total params: 1,901,434
# Trainable params: 1,901,434
# Non-trainable params: 0
# _________________________________________________________________

# %%
# %%time
early_stopping = EarlyStopping(monitor = 'val_ndcg', mode = 'max', verbose = 1, patience = epochs // 5)
model_checkpoint = ModelCheckpoint('mult-DAE.h5', monitor = 'val_ndcg', mode = 'max', save_best_only = True)

hist = model.fit(x = train_gen, validation_data = valid_gen, epochs = epochs,
                 steps_per_epoch = steps_per_epoch, validation_steps = validation_steps, 
                 verbose = 1, callbacks = [early_stopping, model_checkpoint])
show_history(hist, 'loss', 'ndcg')
# Out:
# Epoch 1/100
# 38/38 [==============================] - 1s 11ms/step - loss: 775.6773 - val_ndcg: 0.0914
# Epoch 2/100
# 38/38 [==============================] - 0s 8ms/step - loss: 733.7047 - val_ndcg: 0.1317
# Epoch 3/100
# 38/38 [==============================] - 0s 8ms/step - loss: 713.3307 - val_ndcg: 0.1508
# Epoch 4/100
# 38/38 [==============================] - 0s 8ms/step - loss: 703.7286 - val_ndcg: 0.1608
# Epoch 5/100
# 38/38 [==============================] - 0s 8ms/step - loss: 703.5279 - val_ndcg: 0.1826
# Epoch 6/100
# 38/38 [==============================] - 0s 8ms/step - loss: 690.9452 - val_ndcg: 0.1752
# Epoch 7/100
# 38/38 [==============================] - 0s 11ms/step - loss: 684.8971 - val_ndcg: 0.1691
# Epoch 8/100
# 38/38 [==============================] - 0s 8ms/step - loss: 689.0752 - val_ndcg: 0.1865
# Epoch 9/100
# 38/38 [==============================] - 0s 8ms/step - loss: 677.8217 - val_ndcg: 0.1836
# Epoch 10/100
# 38/38 [==============================] - 0s 8ms/step - loss: 671.6151 - val_ndcg: 0.1650
# Epoch 11/100
# 38/38 [==============================] - 0s 8ms/step - loss: 673.5546 - val_ndcg: 0.1863
# Epoch 12/100
# 38/38 [==============================] - 0s 8ms/step - loss: 670.5484 - val_ndcg: 0.2060
# Epoch 13/100
# 38/38 [==============================] - 0s 8ms/step - loss: 673.4048 - val_ndcg: 0.1656
# Epoch 14/100
# 38/38 [==============================] - 0s 7ms/step - loss: 669.8081 - val_ndcg: 0.1871
# Epoch 15/100
# 38/38 [==============================] - 0s 7ms/step - loss: 662.4356 - val_ndcg: 0.1782
# Epoch 16/100
# 38/38 [==============================] - 0s 8ms/step - loss: 658.6689 - val_ndcg: 0.2109
# Epoch 17/100
# 38/38 [==============================] - 0s 8ms/step - loss: 666.3651 - val_ndcg: 0.1947
# Epoch 18/100
# 38/38 [==============================] - 0s 7ms/step - loss: 653.2398 - val_ndcg: 0.1946
# Epoch 19/100
# 38/38 [==============================] - 0s 8ms/step - loss: 655.4747 - val_ndcg: 0.1987
# Epoch 20/100
# 38/38 [==============================] - 0s 7ms/step - loss: 654.6328 - val_ndcg: 0.1982
# Epoch 21/100
# 38/38 [==============================] - 0s 8ms/step - loss: 656.3535 - val_ndcg: 0.2064
# Epoch 22/100
# 38/38 [==============================] - 0s 8ms/step - loss: 655.5223 - val_ndcg: 0.1732
# Epoch 23/100
# 38/38 [==============================] - 0s 8ms/step - loss: 652.6249 - val_ndcg: 0.2116
# Epoch 24/100
# 38/38 [==============================] - 0s 8ms/step - loss: 647.3600 - val_ndcg: 0.1891
# Epoch 25/100
# 38/38 [==============================] - 0s 8ms/step - loss: 645.1961 - val_ndcg: 0.2108
# Epoch 26/100
# 38/38 [==============================] - 0s 10ms/step - loss: 647.4510 - val_ndcg: 0.2111
# Epoch 27/100
# 38/38 [==============================] - 0s 7ms/step - loss: 650.8266 - val_ndcg: 0.1979
# Epoch 28/100
# 38/38 [==============================] - 0s 7ms/step - loss: 646.6672 - val_ndcg: 0.2084
# Epoch 29/100
# 38/38 [==============================] - 0s 7ms/step - loss: 652.6546 - val_ndcg: 0.2350
# Epoch 30/100
# 38/38 [==============================] - 0s 8ms/step - loss: 639.9419 - val_ndcg: 0.1959
# Epoch 31/100
# 38/38 [==============================] - 0s 7ms/step - loss: 648.1417 - val_ndcg: 0.2168
# Epoch 32/100
# 38/38 [==============================] - 0s 7ms/step - loss: 646.3080 - val_ndcg: 0.1945
# Epoch 33/100
# 38/38 [==============================] - 0s 7ms/step - loss: 637.5481 - val_ndcg: 0.2196
# Epoch 34/100
# 38/38 [==============================] - 0s 8ms/step - loss: 647.0419 - val_ndcg: 0.2025
# Epoch 35/100
# 38/38 [==============================] - 0s 8ms/step - loss: 635.6492 - val_ndcg: 0.2165
# Epoch 36/100
# 38/38 [==============================] - 0s 8ms/step - loss: 639.1374 - val_ndcg: 0.2073
# Epoch 37/100
# 38/38 [==============================] - 0s 7ms/step - loss: 644.4656 - val_ndcg: 0.2013
# Epoch 38/100
# 38/38 [==============================] - 0s 7ms/step - loss: 634.2978 - val_ndcg: 0.2110
# Epoch 39/100
# 38/38 [==============================] - 0s 8ms/step - loss: 637.5426 - val_ndcg: 0.2232
# Epoch 40/100
# 38/38 [==============================] - 0s 7ms/step - loss: 637.0206 - val_ndcg: 0.2308
# Epoch 41/100
# 38/38 [==============================] - 0s 7ms/step - loss: 642.6783 - val_ndcg: 0.1971
# Epoch 42/100
# 38/38 [==============================] - 0s 7ms/step - loss: 633.7125 - val_ndcg: 0.2219
# Epoch 43/100
# 38/38 [==============================] - 0s 8ms/step - loss: 640.2019 - val_ndcg: 0.1998
# Epoch 44/100
# 38/38 [==============================] - 0s 7ms/step - loss: 631.1015 - val_ndcg: 0.2157
# Epoch 45/100
# 38/38 [==============================] - 0s 10ms/step - loss: 639.3938 - val_ndcg: 0.2020
# Epoch 46/100
# 38/38 [==============================] - 0s 8ms/step - loss: 635.8149 - val_ndcg: 0.2234
# Epoch 47/100
# 38/38 [==============================] - 0s 8ms/step - loss: 632.2494 - val_ndcg: 0.2289
# Epoch 48/100
# 38/38 [==============================] - 0s 7ms/step - loss: 628.2591 - val_ndcg: 0.2074
# Epoch 49/100
# 38/38 [==============================] - 0s 7ms/step - loss: 641.3924 - val_ndcg: 0.2089
# Epoch 00049: early stopping
# CPU times: user 18.5 s, sys: 1.81 s, total: 20.3 s
# Wall time: 15.2 s

# %%
true = list_agg(test_r)
true.head(5)
# Out:
#    user_id                                           movie_id
# 0        2              [177, 179, 183, 84, 4, 198, 199, 207]
# 1        8  [59, 438, 93, 123, 463, 525, 30, 288, 534, 322...
# 2       41  [175, 182, 563, 184, 1176, 116, 128, 1037, 104...
# 3       78                             [1258, 305, 500, 2230]
# 4       91  [558, 1176, 195, 587, 592, 74, 1904, 186, 647,...

# %%
pred = test_predictor(test_q, model, n_item, batch_size, N = 100)
pred.head(5)
# Out:
#    user_id                                           movie_id
# 0        2  [92, 48, 22, 97, 132, 711, 84, 60, 273, 189, 2...
# 1        8  [244, 184, 134, 92, 171, 124, 68, 315, 5, 44, ...
# 2       41  [62, 856, 155, 189, 160, 132, 112, 86, 758, 77...
# 3       78  [104, 68, 38, 406, 113, 128, 92, 184, 132, 97,...
# 4       91  [9, 596, 8, 64, 1523, 612, 682, 741, 44, 124, ...

# %%
scores = evaluate(true, pred)

scores(K = 20)
scores.print_all()

scores(K = 100)
scores.print_all()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=604.0), HTML(value='')))
#       Recall@20 : 0.13878
#    Precision@20 : 0.08171
#          MAP@20 : 0.04747
#          MRR@20 : 0.23392
#         nDCG@20 : 0.12053
# HBox(children=(FloatProgress(value=0.0, max=604.0), HTML(value='')))
#       Recall@100 : 0.37953
#    Precision@100 : 0.05596
#          MAP@100 : 0.06129
#          MRR@100 : 0.24178
#         nDCG@100 : 0.21274
