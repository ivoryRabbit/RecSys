# %%
import os, sys
from google.colab import drive
drive.mount('/content/drive')

my_path = '/content/notebooks'
try: os.symlink('/content/drive/My Drive/Colab Notebooks/my_env', my_path)
except: print('\nAlready linked...')
sys.path.insert(0, my_path)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import glob
import numpy as np
import pandas as pd
from tqdm.notebook import tqdm

import tensorflow as tf
import tensorflow.keras.backend as K
from tensorflow.keras.layers import Input, Dense, Embedding, Flatten, Dropout, Activation, BatchNormalization, LeakyReLU, concatenate
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.optimizers import Adam, RMSprop
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.optimizers.schedules import ExponentialDecay
from tensorflow.keras.initializers import TruncatedNormal
from tensorflow.keras.regularizers import l2

from bokeh.plotting import output_notebook, figure, show
from bokeh.layouts import row, column
from bokeh.resources import INLINE
from bokeh.models import ColumnDataSource
from bokeh.models.widgets import DataTable, TableColumn
output_notebook(INLINE)

# %%
display(glob.glob('drive/My Drive/RecSys/data/ml-25m/*'))
base_path = 'drive/My Drive/RecSys/'
# Out:
# ['drive/My Drive/RecSys/data/ml-25m/README.txt',
#  'drive/My Drive/RecSys/data/ml-25m/links.csv',
#  'drive/My Drive/RecSys/data/ml-25m/tags.csv',
#  'drive/My Drive/RecSys/data/ml-25m/ratings.csv',
#  'drive/My Drive/RecSys/data/ml-25m/genome-tags.csv',
#  'drive/My Drive/RecSys/data/ml-25m/genome-scores.csv',
#  'drive/My Drive/RecSys/data/ml-25m/movies.csv',
#  'drive/My Drive/RecSys/data/ml-25m/ratings_v1.csv',
#  'drive/My Drive/RecSys/data/ml-25m/movies_v1.csv',
#  'drive/My Drive/RecSys/data/ml-25m/valid.csv',
#  'drive/My Drive/RecSys/data/ml-25m/train.csv',
#  'drive/My Drive/RecSys/data/ml-25m/test_a.csv',
#  'drive/My Drive/RecSys/data/ml-25m/test_q.csv',
#  'drive/My Drive/RecSys/data/ml-25m/movies_v2.csv']

# %%
ratings = pd.read_csv(base_path + 'data/ml-25m/ratings_v1.csv')

train = pd.read_csv(base_path + 'data/ml-25m/train.csv')
valid = pd.read_csv(base_path + 'data/ml-25m/valid.csv')

test_q = pd.read_csv(base_path + 'data/ml-25m/test_q.csv')
test_a = pd.read_csv(base_path + 'data/ml-25m/test_a.csv')

# %%
print(valid.shape)
valid.head(3)
# Out:
# (2491865, 4)
#    userId  movieId  rating  timestamp
# 0       8      963     5.0  859381992
# 1       8      195     4.0  859382015
# 2       8     1079     5.0  859382042

# %% [markdown]
# ## 1. Preprocessing
#
# Remove all unseen data in validation and test sets for memory efficiency

# %%
seen_data = train.movieId.unique()

# %%
def remove_unseen(df):
    df = df[df.movieId.isin(seen_data)]
    df = df.reset_index(drop = True)
    return df

# %%
valid, test_q = map(remove_unseen, (valid, test_q))

# %%
print(valid.shape)
valid.head(3)
# Out:
# (2490440, 4)
#    userId  movieId  rating  timestamp
# 0       8      963     5.0  859381992
# 1       8      195     4.0  859382015
# 2       8     1079     5.0  859382042

# %%
def remove_invalid(df_q, df_a):
    exist_a = df_a.userId.unique()
    return df_q[df_q.userId.isin(exist_a)]

# %%
test_q = remove_invalid(test_q, test_a)
print(test_q.shape)
test_q.head(3)
# Out:
# (2166301, 4)
#    userId  movieId  rating   timestamp
# 0       9     1209     3.0  1227570828
# 1       9     1210     3.0  1227570836
# 2       9     1211     3.5  1227570841

# %% [markdown]
# ## 2. U-AutoRec

# %%
idx_item_map = train.movieId.unique()
item_idx_map = {e: i for i, e in enumerate(idx_item_map)}
n_item = idx_item_map.shape[0]
print(n_item)
# Out:
# 56946

# %%
def embedd_movie_idx(df):
    return df.assign(movieId = lambda x: x.movieId.map(item_idx_map))

# %%
train, valid, test_q = map(embedd_movie_idx, (train, valid, test_q))

# %%
def make_interaction(df, user_based = True):
    if user_based:
        return df.groupby('userId', as_index = False)[['movieId', 'rating']].agg(list)
    else:
        return df.groupby('movieId', as_index = False)[['userId', 'rating']].agg(list)

# %%
def generate_batch(df, n_item, epochs = 10, batch_size = 256, predict = False):
    n_user = df.index.size
    for _ in range(epochs + 1):
        if not predict:
            df = df.sample(frac = 1).reset_index(drop = True) # At fit_generator, shuffle does not work if steps_per_epoch != None
        idx = 0
        while idx < n_user:
            batchId = idx % batch_size
            if batchId == 0:
                batch = np.zeros(shape = (batch_size, n_item))
            movieId = df.at[idx, 'movieId']
            rating = df.at[idx, 'rating']
            idx += 1

            batch[batchId, movieId] = rating
            if batchId == batch_size - 1:
                if not predict:
                    yield batch, batch
                else:
                    yield batch
            if idx == n_user:
                batch = batch[:n_user % batch_size]
                if not predict:
                    yield batch, batch
                else:
                    yield batch

# %%
def masked_mse(y_true, y_pred, masked_value = 0):
    mask_true = K.cast_to_floatx(K.not_equal(y_true, masked_value))
    masked_se = K.square(mask_true * (y_true - y_pred))
    masked_mse = K.sum(masked_se, axis = -1) / K.maximum(K.sum(mask_true, axis = -1), 1)
    return masked_mse

# %%
def masked_rmse_clip(y_true, y_pred, masked_value = 0):
    mask_true = K.cast_to_floatx(K.not_equal(y_true, masked_value))
    y_pred = K.clip(y_pred, 1, 5)
    masked_se = K.square(mask_true * (y_true - y_pred))
    masked_mse = K.sum(masked_se, axis = -1) / K.maximum(K.sum(mask_true, axis = -1), 1)
    return K.sqrt(masked_mse)

# %%
def build_AutoRec(n_item, latent_dim, first_activation, last_activation, reg):
    inputs = x = Input(shape = (n_item, ), name = 'input')
    x = Dense(latent_dim, activation = first_activation, kernel_regularizer = l2(reg), name = 'encoder')(x)
    outputs = Dense(n_item, activation = last_activation, kernel_regularizer = l2(reg), name = 'decoder')(x)
    model = Model(inputs = inputs, outputs = outputs)
    model.compile(optimizer = 'nadam', loss = masked_mse, metrics = [masked_rmse_clip])
    return model

# %%
AutoRec = build_AutoRec(n_item, latent_dim = 500, first_activation = 'elu', last_activation = 'elu', reg = 0.001)
AutoRec.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 56946)]           0
# _________________________________________________________________
# encoder (Dense)              (None, 500)               28473500
# _________________________________________________________________
# decoder (Dense)              (None, 56946)             28529946
# =================================================================
# Total params: 57,003,446
# Trainable params: 57,003,446
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = 100
batch_size = 256

steps_per_epoch = train.userId.unique().shape[0] // batch_size + 1
validation_steps = valid.userId.unique().shape[0] // batch_size + 1

train_gen = make_interaction(train)
train_gen = generate_batch(train_gen, n_item, epochs, batch_size)

valid_gen = make_interaction(valid)
valid_gen = generate_batch(valid_gen, n_item, epochs, batch_size)

# %%
# %%time
early_stopping = EarlyStopping(monitor = 'val_loss', mode = 'min', verbose = 5, patience = 5)
model_checkpoint = ModelCheckpoint(base_path + 'model/AutoRec.h5', monitor = 'val_loss', mode = 'min', save_best_only = True)

hist = AutoRec.fit(x = train_gen, epochs = epochs, steps_per_epoch = steps_per_epoch, 
                   validation_data = valid_gen, validation_steps = validation_steps, validation_batch_size = batch_size, 
                   verbose = 1)
# Out:
# Epoch 1/100
# 508/508 [==============================] - 65s 128ms/step - loss: 1.8028 - masked_rmse_clip: 1.0386 - val_loss: 1.4935 - val_masked_rmse_clip: 0.9681
# Epoch 2/100
# 508/508 [==============================] - 65s 128ms/step - loss: 1.4492 - masked_rmse_clip: 0.9538 - val_loss: 1.4008 - val_masked_rmse_clip: 0.9358
# Epoch 3/100
# 508/508 [==============================] - 65s 129ms/step - loss: 1.3709 - masked_rmse_clip: 0.9260 - val_loss: 1.3339 - val_masked_rmse_clip: 0.9164
# Epoch 4/100
# 508/508 [==============================] - 65s 129ms/step - loss: 1.3060 - masked_rmse_clip: 0.9081 - val_loss: 1.2792 - val_masked_rmse_clip: 0.9025
# Epoch 5/100
# 508/508 [==============================] - 65s 128ms/step - loss: 1.2591 - masked_rmse_clip: 0.8974 - val_loss: 1.2319 - val_masked_rmse_clip: 0.8910
# Epoch 6/100
# 508/508 [==============================] - 65s 128ms/step - loss: 1.2236 - masked_rmse_clip: 0.8907 - val_loss: 1.2122 - val_masked_rmse_clip: 0.8883
# Epoch 7/100
# 508/508 [==============================] - 65s 128ms/step - loss: 1.1983 - masked_rmse_clip: 0.8858 - val_loss: 1.1870 - val_masked_rmse_clip: 0.8837
# Epoch 8/100
# 508/508 [==============================] - 65s 129ms/step - loss: 1.1763 - masked_rmse_clip: 0.8816 - val_loss: 1.1838 - val_masked_rmse_clip: 0.8931
# Epoch 9/100
# 508/508 [==============================] - 66s 129ms/step - loss: 1.1613 - masked_rmse_clip: 0.8787 - val_loss: 1.1525 - val_masked_rmse_clip: 0.8768
# Epoch 10/100
# 508/508 [==============================] - 65s 128ms/step - loss: 1.1479 - masked_rmse_clip: 0.8752 - val_loss: 1.1384 - val_masked_rmse_clip: 0.8725
# Epoch 11/100
# 508/508 [==============================] - 65s 128ms/step - loss: 1.1344 - masked_rmse_clip: 0.8718 - val_loss: 1.1254 - val_masked_rmse_clip: 0.8704
# Epoch 12/100
# 508/508 [==============================] - 65s 128ms/step - loss: 1.1231 - masked_rmse_clip: 0.8689 - val_loss: 1.1239 - val_masked_rmse_clip: 0.8713
# Epoch 13/100
# 508/508 [==============================] - 65s 128ms/step - loss: 1.1112 - masked_rmse_clip: 0.8659 - val_loss: 1.1055 - val_masked_rmse_clip: 0.8635
# Epoch 14/100
# 508/508 [==============================] - 65s 128ms/step - loss: 1.0974 - masked_rmse_clip: 0.8619 - val_loss: 1.0829 - val_masked_rmse_clip: 0.8585
# Epoch 15/100
# 508/508 [==============================] - 65s 128ms/step - loss: 1.0825 - masked_rmse_clip: 0.8581 - val_loss: 1.0927 - val_masked_rmse_clip: 0.8619
# Epoch 16/100
# 508/508 [==============================] - 65s 128ms/step - loss: 1.0699 - masked_rmse_clip: 0.8546 - val_loss: 1.0636 - val_masked_rmse_clip: 0.8552
# Epoch 17/100
# 508/508 [==============================] - 65s 128ms/step - loss: 1.0556 - masked_rmse_clip: 0.8512 - val_loss: 1.0512 - val_masked_rmse_clip: 0.8512
# Epoch 18/100
# 508/508 [==============================] - 65s 128ms/step - loss: 1.0428 - masked_rmse_clip: 0.8484 - val_loss: 1.0509 - val_masked_rmse_clip: 0.8518
# Epoch 19/100
# 508/508 [==============================] - 65s 128ms/step - loss: 1.0334 - masked_rmse_clip: 0.8464 - val_loss: 1.0331 - val_masked_rmse_clip: 0.8485
# Epoch 20/100
# 508/508 [==============================] - 65s 128ms/step - loss: 1.0266 - masked_rmse_clip: 0.8452 - val_loss: 1.0265 - val_masked_rmse_clip: 0.8467
# Epoch 21/100
# 508/508 [==============================] - 65s 128ms/step - loss: 1.0212 - masked_rmse_clip: 0.8439 - val_loss: 1.0231 - val_masked_rmse_clip: 0.8448
# Epoch 22/100
# 508/508 [==============================] - 65s 128ms/step - loss: 1.0176 - masked_rmse_clip: 0.8435 - val_loss: 1.0219 - val_masked_rmse_clip: 0.8469
# Epoch 23/100
# 508/508 [==============================] - 66s 129ms/step - loss: 1.0145 - masked_rmse_clip: 0.8428 - val_loss: 1.0192 - val_masked_rmse_clip: 0.8442
# Epoch 24/100
# 508/508 [==============================] - 65s 128ms/step - loss: 1.0113 - masked_rmse_clip: 0.8422 - val_loss: 1.0123 - val_masked_rmse_clip: 0.8428
# Epoch 25/100
# 508/508 [==============================] - 65s 128ms/step - loss: 1.0086 - masked_rmse_clip: 0.8420 - val_loss: 1.0169 - val_masked_rmse_clip: 0.8468
# Epoch 26/100
# 508/508 [==============================] - 65s 128ms/step - loss: 1.0057 - masked_rmse_clip: 0.8412 - val_loss: 1.0123 - val_masked_rmse_clip: 0.8438
# Epoch 27/100
# 508/508 [==============================] - 65s 128ms/step - loss: 1.0024 - masked_rmse_clip: 0.8408 - val_loss: 1.0021 - val_masked_rmse_clip: 0.8426
# Epoch 28/100
# 508/508 [==============================] - 65s 129ms/step - loss: 1.0002 - masked_rmse_clip: 0.8403 - val_loss: 1.0056 - val_masked_rmse_clip: 0.8441
# Epoch 29/100
# 508/508 [==============================] - 65s 128ms/step - loss: 0.9971 - masked_rmse_clip: 0.8396 - val_loss: 0.9956 - val_masked_rmse_clip: 0.8372
# Epoch 30/100
# 508/508 [==============================] - 65s 128ms/step - loss: 0.9943 - masked_rmse_clip: 0.8389 - val_loss: 0.9962 - val_masked_rmse_clip: 0.8395
# Epoch 31/100
# 508/508 [==============================] - 65s 129ms/step - loss: 0.9924 - masked_rmse_clip: 0.8386 - val_loss: 0.9944 - val_masked_rmse_clip: 0.8399
# Epoch 32/100
# 508/508 [==============================] - 65s 128ms/step - loss: 0.9898 - masked_rmse_clip: 0.8380 - val_loss: 0.9969 - val_masked_rmse_clip: 0.8419
# Epoch 33/100
# 508/508 [==============================] - 65s 128ms/step - loss: 0.9870 - masked_rmse_clip: 0.8374 - val_loss: 0.9890 - val_masked_rmse_clip: 0.8391
# Epoch 34/100
# 508/508 [==============================] - 65s 129ms/step - loss: 0.9850 - masked_rmse_clip: 0.8369 - val_loss: 0.9896 - val_masked_rmse_clip: 0.8367
# Epoch 35/100
# 508/508 [==============================] - 65s 128ms/step - loss: 0.9827 - masked_rmse_clip: 0.8364 - val_loss: 0.9871 - val_masked_rmse_clip: 0.8370
# Epoch 36/100
# 508/508 [==============================] - 65s 128ms/step - loss: 0.9806 - masked_rmse_clip: 0.8358 - val_loss: 0.9822 - val_masked_rmse_clip: 0.8371
# Epoch 37/100
# 508/508 [==============================] - 65s 128ms/step - loss: 0.9783 - masked_rmse_clip: 0.8350 - val_loss: 0.9865 - val_masked_rmse_clip: 0.8397
# Epoch 38/100
# 508/508 [==============================] - 65s 129ms/step - loss: 0.9762 - masked_rmse_clip: 0.8346 - val_loss: 0.9733 - val_masked_rmse_clip: 0.8351
# Epoch 39/100
# 508/508 [==============================] - 65s 128ms/step - loss: 0.9741 - masked_rmse_clip: 0.8340 - val_loss: 0.9771 - val_masked_rmse_clip: 0.8354
# Epoch 40/100
# 508/508 [==============================] - 65s 129ms/step - loss: 0.9725 - masked_rmse_clip: 0.8336 - val_loss: 0.9808 - val_masked_rmse_clip: 0.8373
# Epoch 41/100
# 508/508 [==============================] - 65s 128ms/step - loss: 0.9702 - masked_rmse_clip: 0.8330 - val_loss: 0.9695 - val_masked_rmse_clip: 0.8320
# Epoch 42/100
# 508/508 [==============================] - 65s 128ms/step - loss: 0.9685 - masked_rmse_clip: 0.8326 - val_loss: 0.9735 - val_masked_rmse_clip: 0.8357
# Epoch 43/100
# 508/508 [==============================] - 65s 129ms/step - loss: 0.9665 - masked_rmse_clip: 0.8321 - val_loss: 0.9676 - val_masked_rmse_clip: 0.8311
# Epoch 44/100
# 508/508 [==============================] - 65s 128ms/step - loss: 0.9644 - masked_rmse_clip: 0.8316 - val_loss: 0.9673 - val_masked_rmse_clip: 0.8316
# Epoch 45/100
# 508/508 [==============================] - 65s 128ms/step - loss: 0.9627 - masked_rmse_clip: 0.8311 - val_loss: 0.9668 - val_masked_rmse_clip: 0.8331
# Epoch 46/100
# 508/508 [==============================] - 65s 128ms/step - loss: 0.9610 - masked_rmse_clip: 0.8307 - val_loss: 0.9671 - val_masked_rmse_clip: 0.8326
# Epoch 47/100
# 508/508 [==============================] - 65s 129ms/step - loss: 0.9600 - masked_rmse_clip: 0.8302 - val_loss: 0.9631 - val_masked_rmse_clip: 0.8330
# Epoch 48/100
# 508/508 [==============================] - 65s 128ms/step - loss: 0.9571 - masked_rmse_clip: 0.8298 - val_loss: 0.9606 - val_masked_rmse_clip: 0.8307
# Epoch 49/100
# 508/508 [==============================] - 65s 128ms/step - loss: 0.9563 - masked_rmse_clip: 0.8294 - val_loss: 0.9567 - val_masked_rmse_clip: 0.8301
# Epoch 50/100
# 508/508 [==============================] - 65s 128ms/step - loss: 0.9539 - masked_rmse_clip: 0.8289 - val_loss: 0.9609 - val_masked_rmse_clip: 0.8323
# Epoch 51/100
# 508/508 [==============================] - 65s 129ms/step - loss: 0.9523 - masked_rmse_clip: 0.8284 - val_loss: 0.9551 - val_masked_rmse_clip: 0.8302
# Epoch 52/100
# 508/508 [==============================] - 65s 128ms/step - loss: 0.9508 - masked_rmse_clip: 0.8279 - val_loss: 0.9535 - val_masked_rmse_clip: 0.8289
# Epoch 53/100
# 508/508 [==============================] - 65s 127ms/step - loss: 0.9492 - masked_rmse_clip: 0.8276 - val_loss: 0.9549 - val_masked_rmse_clip: 0.8296
# Epoch 54/100
# 508/508 [==============================] - 65s 128ms/step - loss: 0.9477 - masked_rmse_clip: 0.8272 - val_loss: 0.9472 - val_masked_rmse_clip: 0.8261
# Epoch 55/100
# 508/508 [==============================] - 65s 128ms/step - loss: 0.9464 - masked_rmse_clip: 0.8267 - val_loss: 0.9480 - val_masked_rmse_clip: 0.8266
# Epoch 56/100
# 508/508 [==============================] - 65s 129ms/step - loss: 0.9448 - masked_rmse_clip: 0.8262 - val_loss: 0.9522 - val_masked_rmse_clip: 0.8314
# Epoch 57/100
# 508/508 [==============================] - 65s 129ms/step - loss: 0.9431 - masked_rmse_clip: 0.8260 - val_loss: 0.9481 - val_masked_rmse_clip: 0.8286
# Epoch 58/100
# 508/508 [==============================] - 65s 128ms/step - loss: 0.9416 - masked_rmse_clip: 0.8254 - val_loss: 0.9436 - val_masked_rmse_clip: 0.8268
# Epoch 59/100
# 508/508 [==============================] - 65s 128ms/step - loss: 0.9398 - masked_rmse_clip: 0.8251 - val_loss: 0.9426 - val_masked_rmse_clip: 0.8252
# Epoch 60/100
# 508/508 [==============================] - 65s 128ms/step - loss: 0.9389 - masked_rmse_clip: 0.8246 - val_loss: 0.9388 - val_masked_rmse_clip: 0.8261
# Epoch 61/100
# 508/508 [==============================] - 65s 128ms/step - loss: 0.9373 - masked_rmse_clip: 0.8243 - val_loss: 0.9419 - val_masked_rmse_clip: 0.8268
# Epoch 62/100
# 508/508 [==============================] - 65s 128ms/step - loss: 0.9364 - masked_rmse_clip: 0.8240 - val_loss: 0.9424 - val_masked_rmse_clip: 0.8267
# Epoch 63/100
# 508/508 [==============================] - 65s 128ms/step - loss: 0.9348 - masked_rmse_clip: 0.8237 - val_loss: 0.9383 - val_masked_rmse_clip: 0.8261
# Epoch 64/100
# 508/508 [==============================] - 65s 128ms/step - loss: 0.9343 - masked_rmse_clip: 0.8235 - val_loss: 0.9369 - val_masked_rmse_clip: 0.8243
# Epoch 65/100
# 508/508 [==============================] - 65s 128ms/step - loss: 0.9324 - masked_rmse_clip: 0.8230 - val_loss: 0.9337 - val_masked_rmse_clip: 0.8232
# Epoch 66/100
# 508/508 [==============================] - 65s 128ms/step - loss: 0.9310 - masked_rmse_clip: 0.8228 - val_loss: 0.9344 - val_masked_rmse_clip: 0.8245
# Epoch 67/100
# 508/508 [==============================] - 65s 128ms/step - loss: 0.9302 - masked_rmse_clip: 0.8224 - val_loss: 0.9363 - val_masked_rmse_clip: 0.8245
# Epoch 68/100
# 508/508 [==============================] - 65s 128ms/step - loss: 0.9291 - masked_rmse_clip: 0.8222 - val_loss: 0.9318 - val_masked_rmse_clip: 0.8239
# Epoch 69/100
# 508/508 [==============================] - 65s 128ms/step - loss: 0.9282 - masked_rmse_clip: 0.8220 - val_loss: 0.9332 - val_masked_rmse_clip: 0.8239
# Epoch 70/100
# 508/508 [==============================] - 65s 128ms/step - loss: 0.9271 - masked_rmse_clip: 0.8217 - val_loss: 0.9301 - val_masked_rmse_clip: 0.8230
# Epoch 71/100
# 508/508 [==============================] - 65s 128ms/step - loss: 0.9263 - masked_rmse_clip: 0.8216 - val_loss: 0.9311 - val_masked_rmse_clip: 0.8231
# Epoch 72/100
# 508/508 [==============================] - 65s 128ms/step - loss: 0.9249 - masked_rmse_clip: 0.8211 - val_loss: 0.9273 - val_masked_rmse_clip: 0.8227
# Epoch 73/100
# 508/508 [==============================] - 65s 127ms/step - loss: 0.9243 - masked_rmse_clip: 0.8211 - val_loss: 0.9339 - val_masked_rmse_clip: 0.8261
# Epoch 74/100
# 508/508 [==============================] - 65s 129ms/step - loss: 0.9231 - masked_rmse_clip: 0.8209 - val_loss: 0.9251 - val_masked_rmse_clip: 0.8218
# Epoch 75/100
# 508/508 [==============================] - 65s 128ms/step - loss: 0.9225 - masked_rmse_clip: 0.8207 - val_loss: 0.9234 - val_masked_rmse_clip: 0.8224
# Epoch 76/100
# 508/508 [==============================] - 65s 129ms/step - loss: 0.9215 - masked_rmse_clip: 0.8205 - val_loss: 0.9205 - val_masked_rmse_clip: 0.8202
# Epoch 77/100
# 508/508 [==============================] - 65s 128ms/step - loss: 0.9204 - masked_rmse_clip: 0.8202 - val_loss: 0.9277 - val_masked_rmse_clip: 0.8230
# Epoch 78/100
# 508/508 [==============================] - 65s 128ms/step - loss: 0.9199 - masked_rmse_clip: 0.8200 - val_loss: 0.9263 - val_masked_rmse_clip: 0.8226
# Epoch 79/100
# 508/508 [==============================] - 65s 128ms/step - loss: 0.9191 - masked_rmse_clip: 0.8198 - val_loss: 0.9199 - val_masked_rmse_clip: 0.8204
# Epoch 80/100
# 508/508 [==============================] - 65s 129ms/step - loss: 0.9180 - masked_rmse_clip: 0.8197 - val_loss: 0.9239 - val_masked_rmse_clip: 0.8218
# Epoch 81/100
# 508/508 [==============================] - 65s 127ms/step - loss: 0.9174 - masked_rmse_clip: 0.8195 - val_loss: 0.9221 - val_masked_rmse_clip: 0.8228
# Epoch 82/100
# 508/508 [==============================] - 65s 128ms/step - loss: 0.9168 - masked_rmse_clip: 0.8195 - val_loss: 0.9162 - val_masked_rmse_clip: 0.8192
# Epoch 83/100
# 508/508 [==============================] - 65s 128ms/step - loss: 0.9160 - masked_rmse_clip: 0.8193 - val_loss: 0.9232 - val_masked_rmse_clip: 0.8223
# Epoch 84/100
# 508/508 [==============================] - 65s 128ms/step - loss: 0.9152 - masked_rmse_clip: 0.8189 - val_loss: 0.9188 - val_masked_rmse_clip: 0.8218
# Epoch 85/100
# 508/508 [==============================] - 65s 128ms/step - loss: 0.9146 - masked_rmse_clip: 0.8188 - val_loss: 0.9200 - val_masked_rmse_clip: 0.8210
# Epoch 86/100
# 508/508 [==============================] - 65s 128ms/step - loss: 0.9136 - masked_rmse_clip: 0.8188 - val_loss: 0.9175 - val_masked_rmse_clip: 0.8200
# Epoch 87/100
# 508/508 [==============================] - 65s 128ms/step - loss: 0.9131 - masked_rmse_clip: 0.8183 - val_loss: 0.9203 - val_masked_rmse_clip: 0.8215
# Epoch 88/100
# 508/508 [==============================] - 65s 128ms/step - loss: 0.9120 - masked_rmse_clip: 0.8182 - val_loss: 0.9179 - val_masked_rmse_clip: 0.8207
# Epoch 89/100
# 508/508 [==============================] - 65s 128ms/step - loss: 0.9118 - masked_rmse_clip: 0.8180 - val_loss: 0.9165 - val_masked_rmse_clip: 0.8194
# Epoch 90/100
# 508/508 [==============================] - 65s 128ms/step - loss: 0.9110 - masked_rmse_clip: 0.8180 - val_loss: 0.9191 - val_masked_rmse_clip: 0.8203
# Epoch 91/100
# 508/508 [==============================] - 65s 128ms/step - loss: 0.9104 - masked_rmse_clip: 0.8177 - val_loss: 0.9134 - val_masked_rmse_clip: 0.8193
# Epoch 92/100
# 508/508 [==============================] - 65s 128ms/step - loss: 0.9097 - masked_rmse_clip: 0.8176 - val_loss: 0.9142 - val_masked_rmse_clip: 0.8190
# Epoch 93/100
# 508/508 [==============================] - 65s 128ms/step - loss: 0.9092 - masked_rmse_clip: 0.8174 - val_loss: 0.9130 - val_masked_rmse_clip: 0.8185
# Epoch 94/100
# 508/508 [==============================] - 65s 128ms/step - loss: 0.9087 - masked_rmse_clip: 0.8173 - val_loss: 0.9089 - val_masked_rmse_clip: 0.8170
# Epoch 95/100
# 508/508 [==============================] - 65s 127ms/step - loss: 0.9077 - masked_rmse_clip: 0.8170 - val_loss: 0.9151 - val_masked_rmse_clip: 0.8207
# Epoch 96/100
# 508/508 [==============================] - 65s 128ms/step - loss: 0.9075 - masked_rmse_clip: 0.8170 - val_loss: 0.9106 - val_masked_rmse_clip: 0.8187
# Epoch 97/100
# 508/508 [==============================] - 65s 128ms/step - loss: 0.9072 - masked_rmse_clip: 0.8168 - val_loss: 0.9129 - val_masked_rmse_clip: 0.8179
# Epoch 98/100
# 508/508 [==============================] - 65s 128ms/step - loss: 0.9061 - masked_rmse_clip: 0.8166 - val_loss: 0.9134 - val_masked_rmse_clip: 0.8188
# Epoch 99/100
# 508/508 [==============================] - 65s 128ms/step - loss: 0.9061 - masked_rmse_clip: 0.8168 - val_loss: 0.9158 - val_masked_rmse_clip: 0.8215
# Epoch 100/100
# 508/508 [==============================] - ETA: 0s - loss: 0.9052 - masked_rmse_clip: 0.8165WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 64 batches). You may need to use the repeat() function when building your dataset.
# 508/508 [==============================] - 62s 122ms/step - loss: 0.9052 - masked_rmse_clip: 0.8165 - val_loss: 0.9035 - val_masked_rmse_clip: 0.8154

# %%
AutoRec.save(base_path + 'model/AutoRec.h5')

# %%
AutoRec = load_model(base_path + 'model/AutoRec.h5', compile = False)

# %%
p1 = figure(plot_width = 500, plot_height = 300, title = 'MSE', 
           background_fill_color = '#FAFAFA', toolbar_location = None)
p1.xaxis.axis_label = 'epochs'
p1.xaxis.axis_label_text_font_style = 'bold'
p1.yaxis.axis_label = 'loss'
p1.yaxis.axis_label_text_font_style = 'bold'

p2 = figure(plot_width = 500, plot_height = 300, title = 'RMSE', 
           background_fill_color = '#fafafa', toolbar_location = None)
p2.xaxis.axis_label = 'epochs'
p2.xaxis.axis_label_text_font_style = 'bold'
p2.yaxis.axis_label = 'loss'
p2.yaxis.axis_label_text_font_style = 'bold'

X = [i+1 for i in range(epochs)]
Y1 = hist.history['loss']
Y2 = hist.history['val_loss']
Z1 = hist.history['masked_rmse_clip']
Z2 = hist.history['val_masked_rmse_clip']

X, Y1, Y2, Z1, Z2 = map(lambda L: np.take(L, range(9, epochs, 5)), (X, Y1, Y2, Z1, Z2))
source = ColumnDataSource(dict(epoch = X, mse = Y1, val_mse = Y2, rmse_clip = Z1, val_rmse_clip = Z2))

p1.line(x = 'epoch', y = 'mse', source = source, line_width = 2, line_color = 'salmon', legend_label = 'mse')
p1.line(x = 'epoch', y = 'val_mse', source = source, line_width = 2, line_color = 'skyblue', legend_label = 'val_mse')
p1.xaxis.ticker = X

p2.line(x = 'epoch', y = 'rmse_clip', source = source, line_width = 2, line_color = 'salmon', legend_label = 'rmse')
#p2.scatter(x = 'epoch', y = 'rmse_clip', source = source, color = 'black', size = 5, alpha = 0.2)
p2.line(x = 'epoch', y = 'val_rmse_clip', source = source, line_width = 2, line_color = 'skyblue', legend_label = 'val_rmse')
#p2.scatter(x = 'epoch', y = 'val_rmse_clip', source = source, color = 'black', size = 5, alpha = 0.2)
p2.xaxis.ticker = X

columns = [TableColumn(field = 'epoch', title = 'epoch'),
           TableColumn(field = 'mse', title = 'loss'),
           TableColumn(field = 'val_mse', title = 'val_loss'),
           TableColumn(field = 'rmse_clip', title = 'clip_rmse'),
           TableColumn(field = 'val_rmse_clip', title = 'val_clip_rmse')]
table = DataTable(source = source, columns = columns, width = 1000, height = 300)

show(column(row(p1, p2), table))
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# pd.DataFrame(hist.history).to_csv(base_path + 'model/AutoRec_history.csv')
